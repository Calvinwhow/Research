# %%
path_1 = '/Users/cu135/Dropbox (Partners HealthCare)/studies/atrophy_seeds_2023/metadata/bl_adas_scores.csv'
path_2 = '/Users/cu135/Dropbox (Partners HealthCare)/studies/atrophy_seeds_2023/metadata/master_list_z_only.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df2
# Out:
#     subject  CerebellumSBM  CerebellumCSF  CerebellumGM  CerebellumWM  \
# 0         1              0   -4497.364934    980.567621   2977.241279
# 1         2              0   -2201.458697 -18138.572720 -11183.039810
# 2         3              0    5422.499148  -5613.118199   9831.510960
# 3         4              0   10039.542490   4899.249983   6559.417793
# 4         5              0    -807.610765 -10722.003290  -7145.779641
# 5         6              0   -2512.170377  -1056.173682   2425.407108
# 6         7              0   -3810.571029   2017.963719   2364.859302
# 7         8              0   -1377.764614   -301.016853   1047.897930
# 8         9              0   21528.922020  10057.371230  15527.412260
# 9        10              0    -331.479770  -6104.352219    580.351404
# 10       11              0    9869.486016  11122.342400   -895.478236
# 11       12              0    4717.085594  16826.353680  13884.914220
# ...

# %%
merged_df = pd.merge(df1, df2, on='subject', how='inner')
merged_df
# Out:
#           PTID  SITEID VISCODE  USERDATE  EXAMDATE    Q1  Q2  Q3  Q4  Q5  ...  \
# 0   024_S_1393      12      bl   8/20/14   4/20/07  5.00   0   1   9   0  ...
# 1   941_S_1202     127      bl   8/20/14   2/12/07  3.67   0   0   6   0  ...
# 2   009_S_1199     105      bl   8/20/14   1/26/07  6.33   0   0   7   1  ...
# 3   141_S_1152      19      bl   8/20/14    1/8/07  4.00   0   1   9   1  ...
# 4   126_S_1077     113      bl   8/20/14  12/19/06  5.67   0   1   7   0  ...
# 5   005_S_0929       1      bl   8/20/14   11/8/06  3.67   0   0   7   0  ...
# 6   029_S_0871      14      bl   8/20/14   1/11/07  3.67   0   0   6   0  ...
# 7   002_S_0816     101      bl   8/20/14   9/11/06  5.00   0   0   8   0  ...
# 8   016_S_0769     111      bl   8/20/14   8/31/06  3.33   0   1   3   1  ...
# 9   062_S_0768      30      bl   8/20/14   8/23/06  5.33   1   0   4   1  ...
# 10  137_S_0722     124      bl   8/20/14    9/1/06  3.67   0   1   5   0  ...
# ...

# %%
merged_df.to_csv('/Users/cu135/Dropbox (Partners HealthCare)/studies/atrophy_seeds_2023/metadata/bl_adacorrelation_to_baseline_scores.csv')
