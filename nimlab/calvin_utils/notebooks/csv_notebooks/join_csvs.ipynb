# %%
path_1 = '/Users/cu135/Dropbox (Partners HealthCare)/resources/datasets/BWH_PD_DBS_STN/study_metadata/master_list.csv'
path_2 = '/Volumes/One Touch/BWH_PD_DBS_MixedTarget/study_metadata/surgical_info_list.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df2
# Out:
#      Unnamed: 0    record_id  Subject              neurologist   surgeon  \
# 0             0  CbctDbs0001        1           Jordan Paulson  Cosgrove
# 1             1  CbctDbs0002        2           Jordan Paulson  Cosgrove
# 2             2  CbctDbs0003        3             Nutan Sharma  Cosgrove
# 3             3  CbctDbs0004        4  Sarva Harini (Columbia)  Cosgrove
# 4             4  CbctDbs0005        5             Sharma Nutan  Cosgrove
# ..          ...          ...      ...                      ...       ...
# 325         325  CbctDbs0326      326                      NaN       NaN
# 326         326  CbctDbs0327      327                      NaN       NaN
# 327         327  CbctDbs0328      328                      NaN       NaN
# 328         328  CbctDbs0329      329                      NaN       NaN
# 329         329  CbctDbs0330      330                      NaN       NaN
#
#              condition stimulation_site surgical_date  medical_record_number  \
# ...

# %%
merged_df = pd.merge(df1, df2, on='Subject', how='inner')
merged_df
# Out:
#     Subject  Subiculum T Connectivity  Z-Scored Subiculum T Connectivity  \
# 0        39                      8.18                             -1.750
# 1        40                     39.90                              2.470
# 2        41                     18.90                             -0.316
# 3        48                     18.00                             -0.441
# 4        45                      4.12                             -2.280
# ..      ...                       ...                                ...
# 92      238                     28.90                              1.010
# 93      215                    -13.70                             -4.650
# 94      223                     17.00                             -0.575
# 95      214                     14.10                             -0.958
# 96       37                     35.00                              1.810
#
#     Subiculum R Connectivity  Subiculum RFz Connectivity    record_id_x  \
# ...

# %%
merged_df.to_csv('/Users/cu135/Dropbox (Partners HealthCare)/resources/datasets/BWH_PD_DBS_STN/study_metadata/master_list.csv')
