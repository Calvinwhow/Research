# %%
path_to_csv = '/Users/cu135/Dropbox (Partners HealthCare)/studies/atrophy_seeds_2023/metadata/roi_values.csv'

# %%
import pandas as pd

df = pd.read_csv(path_to_csv)
df
# Out:
#                                              subject  \
# 0  /Users/cu135/Dropbox (Partners HealthCare)/stu...
# 1  /Users/cu135/Dropbox (Partners HealthCare)/stu...
# 2  /Users/cu135/Dropbox (Partners HealthCare)/stu...
# 3  /Users/cu135/Dropbox (Partners HealthCare)/stu...
# 4  /Users/cu135/Dropbox (Partners HealthCare)/stu...
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/MNI Lobes/mni_Cerebellum.nii  \
# 0                                        1505.740371
# 1                                        1834.647957
# 2                                           0.000000
# 3                                       11441.559620
# 4                                           0.000000
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/MNI_structures/subcortex/subcortex_mask_2mm.nii  \
# 0                                        4918.534584
# 1                                        6402.782608
# 2                                           0.000000
# 3                                       -7488.142494
# 4                                           2.000000
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/MNI Lobes/mni_Frontal_Lobe.nii  \
# 0                                       11500.925660
# 1                                      -11917.766050
# 2                                        -260.507399
# 3                                        4810.739465
# 4                                           2.000000
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/MNI Lobes/mni_Parietal_Lobe.nii  \
# 0                                       12473.948450
# 1                                       -9106.605698
# 2                                        -264.464561
# 3                                        2113.948102
# 4                                           2.000000
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/MNI Lobes/mni_Insula.nii  \
# 0                                        8981.397494
# 1                                       -2124.655628
# 2                                        -123.657639
# 3                                        6717.142093
# 4                                           2.000000
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/MNI Lobes/mni_Temporal_Lobe.nii  \
# 0                                        8981.397494
# 1                                       -2124.655628
# 2                                        -123.657639
# 3                                        6717.142093
# 4                                           2.000000
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/MNI Lobes/mni_Occipital_Lobe.nii  \
# 0                                        6213.051342
# 1                                       -2762.779551
# 2                                         -60.121377
# 3                                       12042.369710
# 4                                           1.000000
#
#    /Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/memory/hippocampus_2mm.nii
# 0                                       4.919718e+02
# 1                                      -2.367481e+02
# 2                                      -2.840000e-16
# 3                                       3.973534e+02
# 4                                       2.000000e+00

# %%
import subprocess
import pandas as pd

def process_rois(df):
    for index, row in df.iterrows():
        save_path = row['subject']
        for col in df.columns[1:]:  # Skip the 'subject' column
            if 'Unnamed' in col:  # Skip unnamed columns
                continue
            roi_path = col
            if pd.notna(row[col]):  # Check if the cell is not empty
                value_to_multiply = row[col]  # The value to multiply with
                output_path = f"{save_path}/{roi_path.split('/')[-1]}"
                command = f"fslmaths \"{roi_path}\" -mul {value_to_multiply} \"{output_path}\""
                subprocess.run(command, shell=True)

# process_rois(df)  # Uncomment and run this line in your Jupyter notebook

# %%
process_rois(df)
