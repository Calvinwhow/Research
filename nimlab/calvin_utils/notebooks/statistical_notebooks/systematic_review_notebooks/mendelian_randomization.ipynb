# %% [markdown]
# # Run An Mendelian Randomization
#
# ### Authors: Calvin Howard.
#
# #### Last updated: July 6, 2023
#
# Use this to run/test a statistical model on a spreadsheet.
#
# Notes:
# - To best use this notebook, you must understand MR and its 3 critical assumptions.

# %% [markdown]
# # 00 - Import CSV with All Data
# **The CSV is expected to be in this format**
# - ID and absolute paths to niftis are critical
# ```
# +-----+----------------------------+--------------+--------------+--------------+
# | ID  | Nifti_File_Path            | Covariate_1  | Covariate_2  | Covariate_3  |
# +-----+----------------------------+--------------+--------------+--------------+
# | 1   | /path/to/file1.nii.gz      | 0.5          | 1.2          | 3.4          |
# | 2   | /path/to/file2.nii.gz      | 0.7          | 1.4          | 3.1          |
# | 3   | /path/to/file3.nii.gz      | 0.6          | 1.5          | 3.5          |
# | 4   | /path/to/file4.nii.gz      | 0.9          | 1.1          | 3.2          |
# | ... | ...                        | ...          | ...          | ...          |
# +-----+----------------------------+--------------+--------------+--------------+
# ```

# %% [markdown]
# Prep Output Direction

# %%
# Specify where you want to save your results to
out_dir = '/Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Research/2023/subiculum_cognition_and_age/figures/Figures/odds_ratios'

# %% [markdown]
# Import Data

# %%
# Specify the path to your CSV file containing NIFTI paths
input_csv_path = '/Users/cu135/Dropbox (Partners HealthCare)/studies/cognition_2023/metadata/master_list_proper_subjects.xlsx'
sheet = 'master_list_proper_subjects'

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=input_csv_path, output_dir=out_dir, sheet=sheet)
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()
# Out:
#      subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 0        101  62.0                                 -0.392857
# 1        102  77.0                                 -0.666667
# 2        103  76.0                                 -1.447368
# 3        104  65.0                                 -2.372549
# 4        105  50.0                                 -0.192982
# ..       ...   ...                                       ...
# 194      211  58.7                                       NaN
# 195      152  69.4                                       NaN
# 196      208  79.2                                       NaN
# 197      223  71.1                                       NaN
# 198      214  76.6                                       NaN
#
#      Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                             0.314066
# 1                                             0.013999
# 2                                            -0.841572
# 3                                            -1.855477
# 4                                             0.533109
# ..                                                 ...
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
#
#      Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                  0.314066                     -21.428571
# 1                                  0.013999                     -36.363636
# 2                                 -0.841572                     -78.947368
# 3                                 -1.855477                    -129.411765
# 4                                  0.533109                     -10.526316
# ..                                      ...                            ...
# 194                                     NaN                            NaN
# 195                                     NaN                            NaN
# 196                                     NaN                            NaN
# 197                                     NaN                            NaN
# 198                                     NaN                            NaN
#
#      Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                                -1.282630                          -1.282630
# 1                                -1.760917                          -1.760917
# 2                                -0.595369                          -0.595369
# 3                                -0.945206                          -0.945206
# 4                                -1.151973                          -1.151973
# ..                                     ...                                ...
# 194                              -0.415745                          -0.189000
# 195                              -0.701419                          -0.455000
# 196                              -0.929958                          -0.669000
# 197                              -0.829972                          -0.575000
# 198                              -1.244199                          -0.958000
#
#      Subiculum_Connectivity_T  Amnesia_Lesion_T_Map  ...  \
# 0                   56.864683              0.447264  ...
# 1                   52.970984              0.436157  ...
# 2                   62.459631              0.497749  ...
# 3                   59.611631              0.432617  ...
# 4                   57.928350              0.193389  ...
# ..                        ...                   ...  ...
# 194                 19.900000                   NaN  ...
# 195                 17.900000                   NaN  ...
# 196                 16.300000                   NaN  ...
# 197                 17.000000                   NaN  ...
# 198                 14.100000                   NaN  ...
#
#      Abs_Cognitive_Improve  Cognitive_Improve  Z_Scored_Cognitive_Baseline  \
# 0                     -6.0                 No                     1.518764
# 1                     -8.0                 No                     0.465551
# 2                    -15.0                 No                    -0.061056
# 3                    -22.0                 No                    -0.412127
# 4                     -2.0                 No                    -0.061056
# ..                     ...                ...                          ...
# 194                    NaN                Yes                          NaN
# 195                    NaN                Yes                          NaN
# 196                    NaN                Yes                          NaN
# 197                    NaN                Yes                          NaN
# 198                    NaN                Yes                          NaN
#
#      Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                        -1.518764
# 1                                        -0.465551
# 2                                         0.061056
# 3                                         0.412127
# 4                                         0.061056
# ..                                             ...
# 194                                            NaN
# 195                                            NaN
# 196                                            NaN
# 197                                            NaN
# 198                                            NaN
#
#      Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                           0.72                                 0.28
# 1                           0.48                                 0.52
# 2                           0.36                                 0.64
# 3                           0.28                                 0.72
# 4                           0.36                                 0.64
# ..                           ...                                  ...
# 194                          NaN                                  NaN
# 195                          NaN                                  NaN
# 196                          NaN                                  NaN
# 197                          NaN                                  NaN
# 198                          NaN                                  NaN
#
#      ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0         12.222658      14.493929            -1.714513            -1.227368
# 1         14.020048      15.257338            -1.155843            -1.022243
# 2         15.118727      17.376384            -0.814348            -0.452865
# 3         13.112424      15.287916            -1.437954            -1.014027
# 4         15.086568      12.951426            -0.824344            -1.641831
# ..              ...            ...                  ...                  ...
# 194             NaN            NaN                  NaN                  NaN
# 195             NaN            NaN                  NaN                  NaN
# 196             NaN            NaN                  NaN                  NaN
# 197             NaN            NaN                  NaN                  NaN
# 198             NaN            NaN                  NaN                  NaN
#
# [199 rows x 48 columns]

# %% [markdown]
# # 01 - Preprocess Your Data

# %% [markdown]
# **Handle NANs**
# - Set drop_nans=True is you would like to remove NaNs from data
# - Provide a column name or a list of column names to remove NaNs from

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T',
#        'Amnesia_Lesion_T_Map', 'Memory_Network_T', 'Z_Scored_Memory_Network_R',
#        'Memory_Network_R', 'Subiculum_Grey_Matter', 'Subiculum_White_Matter',
#        'Subiculum_CSF', 'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Age_Group', 'Age_And_Disease',
#        'Age_Disease_and_Cohort', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Cognitive_Outcome', 'StimMatch',
#        'Values_for_Prospective', 'Cognitive_Baseline', 'Cognitive_Score_1_Yr',
#        'Abs_Cognitive_Improve', 'Cognitive_Improve',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %%
drop_list = ['City', 'StimMatch', 'Cognitive_Improve', 'Age']

# %%
data_df = cal_palm.drop_nans_from_columns(columns_to_drop_from=drop_list)
display(data_df)
# Out:
#     subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 46        1  57.0                                 -2.609929
# 47        2  50.0                                  0.992806
# 48        3  62.0                                 -0.638889
# 49        4  50.0                                 -0.985714
# 50        6  60.0                                 -0.323944
# 51        7  73.0                                 -0.326241
# 52        9  64.0                                 -0.985714
# 53       11  62.0                                 -0.319444
# 54       12  54.0                                  0.000000
# 55       14  49.0                                  0.321678
# 56       15  46.0                                 -3.513889
# 57       17  52.0                                  0.000000
# 58       18  46.0                                  0.330935
# 59       19  64.0                                 -0.638889
# 60       21  58.0                                 -4.535211
# 61       22  57.0                                  0.000000
# 62       23  68.0                                 -0.652482
# 64       26  79.0                                  0.000000
# 65       27  61.0                                 -0.638889
# 66       28  56.0                                  1.000000
# 67       29  47.0                                  0.000000
# 68       30  58.0                                 -0.638889
# 69       31  64.0                                  0.666667
# 70       33  60.0                                 -0.643357
# 72       36  52.0                                 -1.286713
# 73       37  64.0                                 -0.992806
#
#     Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 46                                          -1.372562
# 47                                           1.331414
# 48                                           0.106772
# 49                                          -0.153533
# 50                                           0.343149
# 51                                           0.341424
# 52                                          -0.153533
# 53                                           0.346526
# 54                                           0.586280
# 55                                           0.827710
# 56                                          -2.051014
# 57                                           0.586280
# 58                                           0.834658
# 59                                           0.106772
# 60                                          -2.817552
# 61                                           0.586280
# 62                                           0.096569
# 64                                           0.586280
# 65                                           0.106772
# 66                                           1.336814
# 67                                           0.586280
# 68                                           0.106772
# 69                                           1.086636
# 70                                           0.103418
# 72                                          -0.379443
# 73                                          -0.158855
#
#     Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 46                               -1.372562                      -5.673759
# 47                                1.331414                       2.158273
# 48                                0.106772                      -1.388889
# 49                               -0.153533                      -2.142857
# 50                                0.343149                      -0.704225
# 51                                0.341424                      -0.709220
# 52                               -0.153533                      -2.142857
# 53                                0.346526                      -0.694444
# 54                                0.586280                       0.000000
# 55                                0.827710                       0.699301
# 56                               -2.051014                      -7.638889
# 57                                0.586280                       0.000000
# 58                                0.834658                       0.719424
# 59                                0.106772                      -1.388889
# 60                               -2.817552                      -9.859155
# 61                                0.586280                       0.000000
# 62                                0.096569                      -1.418440
# 64                                0.586280                       0.000000
# 65                                0.106772                      -1.388889
# 66                                1.336814                       2.173913
# 67                                0.586280                       0.000000
# 68                                0.106772                      -1.388889
# 69                                1.086636                       1.449275
# 70                                0.103418                      -1.398601
# 72                               -0.379443                      -2.797203
# 73                               -0.158855                      -2.158273
#
#     Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 46                               1.080695                           1.080695
# 47                              -0.930548                          -0.930548
# 48                               1.155469                           1.155469
# 49                              -0.228971                          -0.228971
# 50                               0.109572                           0.109572
# 51                               1.977842                           1.977842
# 52                              -0.407778                          -0.407778
# 53                              -1.093332                          -1.093332
# 54                               0.788134                           0.788134
# 55                              -0.455880                          -0.455880
# 56                               2.357590                           2.357590
# 57                               1.029012                           1.029012
# 58                              -1.003966                          -1.003966
# 59                               0.045394                           0.045394
# 60                               0.457907                           0.457907
# 61                              -0.408153                          -0.408153
# 62                              -1.041401                          -1.041401
# 64                               0.236757                           0.236757
# 65                              -0.572833                          -0.572833
# 66                               1.355046                           1.355046
# 67                               0.886242                           0.886242
# 68                              -0.590767                          -0.590767
# 69                              -1.065220                          -1.065220
# 70                              -1.108473                          -1.108473
# 72                              -0.775406                          -0.775406
# 73                              -0.690244                          -0.690244
#
#     Subiculum_Connectivity_T  Amnesia_Lesion_T_Map  ...  \
# 46                 30.376565             -0.113151  ...
# 47                 16.295870             -0.502484  ...
# 48                 30.900051             -0.398033  ...
# 49                 21.207602             -0.426115  ...
# 50                 23.577739             -0.454075  ...
# 51                 36.657479             -0.177886  ...
# 52                 19.955774             -0.494405  ...
# 53                 15.156220             -0.507962  ...
# 54                 28.328345             -0.220427  ...
# 55                 19.619016             -0.440579  ...
# 56                 39.316089              0.047449  ...
# 57                 30.014730             -0.372396  ...
# 58                 15.781874             -0.313833  ...
# 59                 23.128431             -0.345869  ...
# 60                 26.016428             -0.049282  ...
# 61                 19.953155             -0.496973  ...
# 62                 15.519790             -0.520786  ...
# 64                 24.468157             -0.276809  ...
# 65                 18.800226             -0.489221  ...
# 66                 32.297293             -0.413800  ...
# 67                 29.015201             -0.358253  ...
# 68                 18.674670             -0.553686  ...
# 69                 15.353030             -0.505577  ...
# 70                 15.050219             -0.659502  ...
# 72                 17.382020             -0.527690  ...
# 73                 17.978233             -0.243491  ...
#
#     Abs_Cognitive_Improve  Cognitive_Improve  Z_Scored_Cognitive_Baseline  \
# 46                   -8.0                  0                    -0.115295
# 47                    3.0                  1                    -0.935174
# 48                   -2.0                  0                     1.114522
# 49                   -3.0                  0                    -0.525235
# 50                   -1.0                  0                     0.294644
# 51                   -1.0                  0                    -0.115295
# 52                   -3.0                  0                    -0.525235
# 53                   -1.0                  0                     1.114522
# 54                    0.0                  1                    -2.164991
# 55                    1.0                  1                     0.704583
# 56                  -11.0                  0                     1.114522
# 57                    0.0                  1                     1.114522
# 58                    1.0                  1                    -0.935174
# 59                   -2.0                  0                     1.114522
# 60                  -14.0                  0                     0.294644
# 61                    0.0                  1                     0.704583
# 62                   -2.0                  0                    -0.115295
# 64                    0.0                  1                    -0.525235
# 65                   -2.0                  0                     1.114522
# 66                    3.0                  1                    -1.345113
# 67                    0.0                  1                    -0.115295
# 68                   -2.0                  0                     1.114522
# 69                    2.0                  1                    -1.345113
# 70                   -2.0                  0                     0.704583
# 72                   -4.0                  0                     0.704583
# 73                   -3.0                  0                    -0.935174
#
#     Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 46                                      -0.115295
# 47                                      -0.935174
# 48                                       1.114522
# 49                                      -0.525235
# 50                                       0.294644
# 51                                      -0.115295
# 52                                      -0.525235
# 53                                       1.114522
# 54                                      -2.164991
# 55                                       0.704583
# 56                                       1.114522
# 57                                       1.114522
# 58                                      -0.935174
# 59                                       1.114522
# 60                                       0.294644
# 61                                       0.704583
# 62                                      -0.115295
# 64                                      -0.525235
# 65                                       1.114522
# 66                                      -1.345113
# 67                                      -0.115295
# 68                                       1.114522
# 69                                      -1.345113
# 70                                       0.704583
# 72                                       0.704583
# 73                                      -0.935174
#
#     Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 46                        0.625                                0.625
# 47                        0.375                                0.375
# 48                        1.000                                1.000
# 49                        0.500                                0.500
# 50                        0.750                                0.750
# 51                        0.625                                0.625
# 52                        0.500                                0.500
# 53                        1.000                                1.000
# 54                        0.000                                0.000
# 55                        0.875                                0.875
# 56                        1.000                                1.000
# 57                        1.000                                1.000
# 58                        0.375                                0.375
# 59                        1.000                                1.000
# 60                        0.750                                0.750
# 61                        0.875                                0.875
# 62                        0.625                                0.625
# 64                        0.500                                0.500
# 65                        1.000                                1.000
# 66                        0.250                                0.250
# 67                        0.625                                0.625
# 68                        1.000                                1.000
# 69                        0.250                                0.250
# 70                        0.875                                0.875
# 72                        0.875                                0.875
# 73                        0.375                                0.375
#
#     ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 46       22.020300      20.467840             1.056258             0.508516
# 47       11.487188       4.942970            -0.759238            -1.629565
# 48       23.013479      22.145924             1.227443             0.739621
# 49       12.198485      18.933435            -0.636638             0.297198
# 50       17.634088      18.128314             0.300247             0.186317
# 51       24.162033      27.503198             1.425409             1.477423
# 52       10.782803      14.964053            -0.880646            -0.249464
# 53        9.653427      12.002916            -1.075306            -0.657271
# 54       21.521001      21.243697             0.970198             0.615367
# 55       10.881447      15.224677            -0.863644            -0.213571
# 56       23.430082      33.143996             1.299249             2.254272
# 57       23.655083      22.108570             1.338030             0.734477
# 58       10.294062       7.983811            -0.964886            -1.210781
# 59       18.597962      19.229600             0.466381             0.337986
# 60       19.765137      23.255821             0.667556             0.892476
# 61       16.167584      17.567719             0.047479             0.109112
# 62       10.938624       5.561032            -0.853789            -1.544445
# 64       18.644419      23.314943             0.474388             0.900618
# 65       14.809775      13.473033            -0.186554            -0.454807
# 66       24.395433      24.956701             1.465638             1.126720
# 67       21.855067      25.033790             1.027778             1.137337
# 68       13.873339      15.685024            -0.347959            -0.150172
# 69       10.930371      11.599140            -0.855211            -0.712879
# 70        6.780175       8.774895            -1.570542            -1.101833
# 72        9.841726      16.308768            -1.042851            -0.064270
# 73       11.101963      10.543942            -0.825635            -0.858200
#
# [26 rows x 48 columns]

# %% [markdown]
# **Drop Row Based on Value of Column**
#
# Define the column, condition, and value for dropping rows
# - column = 'your_column_name'
# - condition = 'above'  # Options: 'equal', 'above', 'below'

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T',
#        'Amnesia_Lesion_T_Map', 'Memory_Network_T', 'Z_Scored_Memory_Network_R',
#        'Memory_Network_R', 'Subiculum_Grey_Matter', 'Subiculum_White_Matter',
#        'Subiculum_CSF', 'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Age_Group', 'Age_And_Disease',
#        'Age_Disease_and_Cohort', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Cognitive_Outcome', 'StimMatch',
#        'Values_for_Prospective', 'Cognitive_Baseline', 'Cognitive_Score_1_Yr',
#        'Abs_Cognitive_Improve', 'Cognitive_Improve',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %% [markdown]
# Set the parameters for dropping rows

# %%
column = 'City'  # The column you'd like to evaluate
condition = 'not'  # The condition to check ('equal', 'above', 'below', 'not')
value = 'Wurzburg' # The value to drop if found

# %%
data_df, other_df = cal_palm.drop_rows_based_on_value(column, condition, value)
display(data_df)
# Out:
#     subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 46        1  57.0                                 -2.609929
# 47        2  50.0                                  0.992806
# 48        3  62.0                                 -0.638889
# 49        4  50.0                                 -0.985714
# 50        6  60.0                                 -0.323944
# 51        7  73.0                                 -0.326241
# 52        9  64.0                                 -0.985714
# 53       11  62.0                                 -0.319444
# 54       12  54.0                                  0.000000
# 55       14  49.0                                  0.321678
# 56       15  46.0                                 -3.513889
# 57       17  52.0                                  0.000000
# 58       18  46.0                                  0.330935
# 59       19  64.0                                 -0.638889
# 60       21  58.0                                 -4.535211
# 61       22  57.0                                  0.000000
# 62       23  68.0                                 -0.652482
# 63       24   NaN                                 -4.333333
# 64       26  79.0                                  0.000000
# 65       27  61.0                                 -0.638889
# 66       28  56.0                                  1.000000
# 67       29  47.0                                  0.000000
# 68       30  58.0                                 -0.638889
# 69       31  64.0                                  0.666667
# 70       33  60.0                                 -0.643357
# 71       34   NaN                                 -0.676471
# 72       36  52.0                                 -1.286713
# 73       37  64.0                                 -0.992806
# 74       38   NaN                                 -0.319444
# 75       39   NaN                                 -1.943662
# 76       43   NaN                                 -1.304965
# 77       44   NaN                                       NaN
#
#     Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 46                                          -1.372562
# 47                                           1.331414
# 48                                           0.106772
# 49                                          -0.153533
# 50                                           0.343149
# 51                                           0.341424
# 52                                          -0.153533
# 53                                           0.346526
# 54                                           0.586280
# 55                                           0.827710
# 56                                          -2.051014
# 57                                           0.586280
# 58                                           0.834658
# 59                                           0.106772
# 60                                          -2.817552
# 61                                           0.586280
# 62                                           0.096569
# 63                                          -2.666036
# 64                                           0.586280
# 65                                           0.106772
# 66                                           1.336814
# 67                                           0.586280
# 68                                           0.106772
# 69                                           1.086636
# 70                                           0.103418
# 71                                           0.078565
# 72                                          -0.379443
# 73                                          -0.158855
# 74                                           0.346526
# 75                                          -0.872505
# 76                                          -0.393141
# 77                                                NaN
#
#     Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 46                               -1.372562                      -5.673759
# 47                                1.331414                       2.158273
# 48                                0.106772                      -1.388889
# 49                               -0.153533                      -2.142857
# 50                                0.343149                      -0.704225
# 51                                0.341424                      -0.709220
# 52                               -0.153533                      -2.142857
# 53                                0.346526                      -0.694444
# 54                                0.586280                       0.000000
# 55                                0.827710                       0.699301
# 56                               -2.051014                      -7.638889
# 57                                0.586280                       0.000000
# 58                                0.834658                       0.719424
# 59                                0.106772                      -1.388889
# 60                               -2.817552                      -9.859155
# 61                                0.586280                       0.000000
# 62                                0.096569                      -1.418440
# 63                               -2.666036                      -9.420290
# 64                                0.586280                       0.000000
# 65                                0.106772                      -1.388889
# 66                                1.336814                       2.173913
# 67                                0.586280                       0.000000
# 68                                0.106772                      -1.388889
# 69                                1.086636                       1.449275
# 70                                0.103418                      -1.398601
# 71                                0.078565                      -1.470588
# 72                               -0.379443                      -2.797203
# 73                               -0.158855                      -2.158273
# 74                                0.346526                      -0.694444
# 75                               -0.872505                      -4.225352
# 76                               -0.393141                      -2.836879
# 77                                     NaN                            NaN
#
#     Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 46                               1.080695                           1.080695
# 47                              -0.930548                          -0.930548
# 48                               1.155469                           1.155469
# 49                              -0.228971                          -0.228971
# 50                               0.109572                           0.109572
# 51                               1.977842                           1.977842
# 52                              -0.407778                          -0.407778
# 53                              -1.093332                          -1.093332
# 54                               0.788134                           0.788134
# 55                              -0.455880                          -0.455880
# 56                               2.357590                           2.357590
# 57                               1.029012                           1.029012
# 58                              -1.003966                          -1.003966
# 59                               0.045394                           0.045394
# 60                               0.457907                           0.457907
# 61                              -0.408153                          -0.408153
# 62                              -1.041401                          -1.041401
# 63                               0.203795                           0.203795
# 64                               0.236757                           0.236757
# 65                              -0.572833                          -0.572833
# 66                               1.355046                           1.355046
# 67                               0.886242                           0.886242
# 68                              -0.590767                          -0.590767
# 69                              -1.065220                          -1.065220
# 70                              -1.108473                          -1.108473
# 71                               1.604971                           1.604971
# 72                              -0.775406                          -0.775406
# 73                              -0.690244                          -0.690244
# 74                              -1.171189                          -1.171189
# 75                              -0.179834                          -0.179834
# 76                              -0.372845                          -0.372845
# 77                              -1.191585                          -1.191585
#
#     Subiculum_Connectivity_T  Amnesia_Lesion_T_Map  ...  \
# 46                 30.376565             -0.113151  ...
# 47                 16.295870             -0.502484  ...
# 48                 30.900051             -0.398033  ...
# 49                 21.207602             -0.426115  ...
# 50                 23.577739             -0.454075  ...
# 51                 36.657479             -0.177886  ...
# 52                 19.955774             -0.494405  ...
# 53                 15.156220             -0.507962  ...
# 54                 28.328345             -0.220427  ...
# 55                 19.619016             -0.440579  ...
# 56                 39.316089              0.047449  ...
# 57                 30.014730             -0.372396  ...
# 58                 15.781874             -0.313833  ...
# 59                 23.128431             -0.345869  ...
# 60                 26.016428             -0.049282  ...
# 61                 19.953155             -0.496973  ...
# 62                 15.519790             -0.520786  ...
# 63                 24.237392             -0.434313  ...
# 64                 24.468157             -0.276809  ...
# 65                 18.800226             -0.489221  ...
# 66                 32.297293             -0.413800  ...
# 67                 29.015201             -0.358253  ...
# 68                 18.674670             -0.553686  ...
# 69                 15.353030             -0.505577  ...
# 70                 15.050219             -0.659502  ...
# 71                 34.047011             -0.277802  ...
# 72                 17.382020             -0.527690  ...
# 73                 17.978233             -0.243491  ...
# 74                 14.611144             -0.639372  ...
# 75                 21.551613             -0.293216  ...
# 76                 20.200341             -0.493639  ...
# 77                 14.468351             -0.463787  ...
#
#     Abs_Cognitive_Improve  Cognitive_Improve  Z_Scored_Cognitive_Baseline  \
# 46                   -8.0                 No                    -0.115295
# 47                    3.0                Yes                    -0.935174
# 48                   -2.0                 No                     1.114522
# 49                   -3.0                 No                    -0.525235
# 50                   -1.0                 No                     0.294644
# 51                   -1.0                 No                    -0.115295
# 52                   -3.0                 No                    -0.525235
# 53                   -1.0                 No                     1.114522
# 54                    0.0                Yes                    -2.164991
# 55                    1.0                Yes                     0.704583
# 56                  -11.0                 No                     1.114522
# 57                    0.0                Yes                     1.114522
# 58                    1.0                Yes                    -0.935174
# 59                   -2.0                 No                     1.114522
# 60                  -14.0                 No                     0.294644
# 61                    0.0                Yes                     0.704583
# 62                   -2.0                 No                    -0.115295
# 63                  -13.0                 No                    -1.345113
# 64                    0.0                Yes                    -0.525235
# 65                   -2.0                 No                     1.114522
# 66                    3.0                Yes                    -1.345113
# 67                    0.0                Yes                    -0.115295
# 68                   -2.0                 No                     1.114522
# 69                    2.0                Yes                    -1.345113
# 70                   -2.0                 No                     0.704583
# 71                   -2.0                 No                    -2.164991
# 72                   -4.0                 No                     0.704583
# 73                   -3.0                 No                    -0.935174
# 74                   -1.0                 No                     1.114522
# 75                   -6.0                 No                     0.294644
# 76                   -4.0                 No                    -0.115295
# 77                    0.0                Yes                     0.704583
#
#     Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 46                                      -0.115295
# 47                                      -0.935174
# 48                                       1.114522
# 49                                      -0.525235
# 50                                       0.294644
# 51                                      -0.115295
# 52                                      -0.525235
# 53                                       1.114522
# 54                                      -2.164991
# 55                                       0.704583
# 56                                       1.114522
# 57                                       1.114522
# 58                                      -0.935174
# 59                                       1.114522
# 60                                       0.294644
# 61                                       0.704583
# 62                                      -0.115295
# 63                                      -1.345113
# 64                                      -0.525235
# 65                                       1.114522
# 66                                      -1.345113
# 67                                      -0.115295
# 68                                       1.114522
# 69                                      -1.345113
# 70                                       0.704583
# 71                                      -2.164991
# 72                                       0.704583
# 73                                      -0.935174
# 74                                       1.114522
# 75                                       0.294644
# 76                                      -0.115295
# 77                                       0.704583
#
#     Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 46                        0.625                                0.625
# 47                        0.375                                0.375
# 48                        1.000                                1.000
# 49                        0.500                                0.500
# 50                        0.750                                0.750
# 51                        0.625                                0.625
# 52                        0.500                                0.500
# 53                        1.000                                1.000
# 54                        0.000                                0.000
# 55                        0.875                                0.875
# 56                        1.000                                1.000
# 57                        1.000                                1.000
# 58                        0.375                                0.375
# 59                        1.000                                1.000
# 60                        0.750                                0.750
# 61                        0.875                                0.875
# 62                        0.625                                0.625
# 63                        0.250                                0.250
# 64                        0.500                                0.500
# 65                        1.000                                1.000
# 66                        0.250                                0.250
# 67                        0.625                                0.625
# 68                        1.000                                1.000
# 69                        0.250                                0.250
# 70                        0.875                                0.875
# 71                        0.000                                0.000
# 72                        0.875                                0.875
# 73                        0.375                                0.375
# 74                        1.000                                1.000
# 75                        0.750                                0.750
# 76                        0.625                                0.625
# 77                        0.875                                0.875
#
#     ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 46       22.020300      20.467840             1.056258             0.508516
# 47       11.487188       4.942970            -0.759238            -1.629565
# 48       23.013479      22.145924             1.227443             0.739621
# 49       12.198485      18.933435            -0.636638             0.297198
# 50       17.634088      18.128314             0.300247             0.186317
# 51       24.162033      27.503198             1.425409             1.477423
# 52       10.782803      14.964053            -0.880646            -0.249464
# 53        9.653427      12.002916            -1.075306            -0.657271
# 54       21.521001      21.243697             0.970198             0.615367
# 55       10.881447      15.224677            -0.863644            -0.213571
# 56       23.430082      33.143996             1.299249             2.254272
# 57       23.655083      22.108570             1.338030             0.734477
# 58       10.294062       7.983811            -0.964886            -1.210781
# 59       18.597962      19.229600             0.466381             0.337986
# 60       19.765137      23.255821             0.667556             0.892476
# 61       16.167584      17.567719             0.047479             0.109112
# 62       10.938624       5.561032            -0.853789            -1.544445
# 63       18.524311      15.431603             0.453686            -0.185073
# 64       18.644419      23.314943             0.474388             0.900618
# 65       14.809775      13.473033            -0.186554            -0.454807
# 66       24.395433      24.956701             1.465638             1.126720
# 67       21.855067      25.033790             1.027778             1.137337
# 68       13.873339      15.685024            -0.347959            -0.150172
# 69       10.930371      11.599140            -0.855211            -0.712879
# 70        6.780175       8.774895            -1.570542            -1.101833
# 71       26.315090      28.409781             1.796511             1.602277
# 72        9.841726      16.308768            -1.042851            -0.064270
# 73       11.101963      10.543942            -0.825635            -0.858200
# 74        5.944940       9.801099            -1.714504            -0.960505
# 75       14.657576      16.050861            -0.212787            -0.099789
# 76       13.809253       9.428111            -0.359005            -1.011872
# 77       10.861661       3.594913            -0.867054            -1.815218
#
# [32 rows x 48 columns]

# %% [markdown]
# **Standardize Data**
# - Enter Columns you Don't want to standardize into a list

# %%
# Remove anything you don't want to standardize
cols_not_to_standardize = None # ['Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group', 'Z_Scored_Subiculum_T_By_Origin_Group_'] #['Age']

# %%
data_df = cal_palm.standardize_columns(cols_not_to_standardize)
data_df

# %%
# for col in data_df.columns:
#     if 'CSF' and 'eh' not in col:
#         data_df[col] = data_df[col] * -1

# %% [markdown]
# RCT Plotter

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tools import add_constant
import patsy

class MendelianRandomizationAnalysis:
    def __init__(self, data, outcome_cols, exposure_col, iv_col, covariate_cols=None):
        """
        Initializes the class with the data and variable specifications.
        """
        self.data = data
        self.outcome_cols = outcome_cols
        self.exposure_col = exposure_col
        self.iv_col = iv_col
        self.covariate_cols = covariate_cols if covariate_cols else []

    def label_encode_variables(self):
        """
        Label encode categorical variables if needed.
        """
        categorical_columns = self.data.select_dtypes(include=['object', 'category']).columns
        for col in categorical_columns:
            self.data[col] = pd.factorize(self.data[col])[0]

    def run_regression(self, y_col, X_cols):
        """
        Runs a regression and returns the model.
        """
        X = add_constant(self.data[X_cols])  # Add a constant term for the intercept
        y = self.data[y_col]
        model = sm.OLS(y, X).fit()
        return model

    def first_stage_regression(self):
        """
        First-stage regression of the IV analysis: regress exposure on IV.
        """
        return self.run_regression(self.exposure_col, [self.iv_col] + self.covariate_cols)

    def second_stage_regression(self, outcome_col, predicted_exposure):
        """
        Second-stage regression of the IV analysis: regress outcome on the predicted exposure.
        """
        return self.run_regression(outcome_col, [predicted_exposure] + self.covariate_cols)

    def mendelian_randomization(self):
        """
        Executes the two-stage least squares Mendelian Randomization.
        """
        self.label_encode_variables()
        first_stage_model = self.first_stage_regression()
        self.data['predicted_exposure'] = first_stage_model.predict()

        results = {}
        for outcome in self.outcome_cols:
            second_stage_model = self.second_stage_regression(outcome, 'predicted_exposure')
            results[outcome] = second_stage_model

        return results

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T',
#        'Amnesia_Lesion_T_Map', 'Memory_Network_T', 'Z_Scored_Memory_Network_R',
#        'Memory_Network_R', 'Subiculum_Grey_Matter', 'Subiculum_White_Matter',
#        'Subiculum_CSF', 'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Age_Group', 'Age_And_Disease',
#        'Age_Disease_and_Cohort', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Cognitive_Outcome', 'StimMatch',
#        'Values_for_Prospective', 'Cognitive_Baseline', 'Cognitive_Score_1_Yr',
#        'Abs_Cognitive_Improve', 'Cognitive_Improve',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %%
# Usage example:
# Assuming 'df' is a pandas DataFrame with the necessary data.
mr_analysis = MendelianRandomizationAnalysis(
    data=data_df,
    outcome_cols=['Percent_Cognitive_Improvement'],
    exposure_col='StimMatch',
    iv_col='Age',
    covariate_cols=None
)

mr_results = mr_analysis.mendelian_randomization()
for outcome, model in mr_results.items():
    print(f'Results for {outcome}:')
    print(model.summary())
# Out:
# Results for Percent_Cognitive_Improvement:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     Percent_Cognitive_Improvement   R-squared:                       0.004
# Model:                                       OLS   Adj. R-squared:                 -0.038
# Method:                            Least Squares   F-statistic:                   0.09291
# Date:                           Sat, 09 Mar 2024   Prob (F-statistic):              0.763
# Time:                                   12:32:34   Log-Likelihood:                -62.426
# No. Observations:                             26   AIC:                             128.9
# Df Residuals:                                 24   BIC:                             131.4
# Df Model:                                      1
# Covariance Type:                       nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -2.3266      3.176     -0.733      0.471      -8.882       4.229
# predicted_exposure     1.4587      4.786      0.305      0.763      -8.418      11.336
# ==============================================================================
# Omnibus:                       15.843   Durbin-Watson:                   2.298
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.993
# Skew:                          -1.523   Prob(JB):                     0.000204
# Kurtosis:                       5.531   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
