# %% [markdown]
# # Run Any Kind of OLS Regression (ANOVA, GLM, etc.)
#
# ### Authors: Calvin Howard.
#
# #### Last updated: July 6, 2023
#
# Use this to run/test a statistical model (e.g., regression or T-tests) on a spreadsheet.
#
# Notes:
# - To best use this notebook, you should be familar with GLM design and Contrast Matrix design. See this webpage to get started:
# [FSL's GLM page](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM)

# %% [markdown]
# # 00 - Import CSV with All Data
# **The CSV is expected to be in this format**
# - ID and absolute paths to niftis are critical
# ```
# +-----+----------------------------+--------------+--------------+--------------+
# | ID  | Nifti_File_Path            | Covariate_1  | Covariate_2  | Covariate_3  |
# +-----+----------------------------+--------------+--------------+--------------+
# | 1   | /path/to/file1.nii.gz      | 0.5          | 1.2          | 3.4          |
# | 2   | /path/to/file2.nii.gz      | 0.7          | 1.4          | 3.1          |
# | 3   | /path/to/file3.nii.gz      | 0.6          | 1.5          | 3.5          |
# | 4   | /path/to/file4.nii.gz      | 0.9          | 1.1          | 3.2          |
# | ... | ...                        | ...          | ...          | ...          |
# +-----+----------------------------+--------------+--------------+--------------+
# ```

# %% [markdown]
# Prep Output Direction

# %%
# Specify where you want to save your results to
out_dir = '/Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Research/2023/subiculum_cognition_and_age/figures/Figures/joint_distribution_calculus/analyses'

# %% [markdown]
# Import Data

# %%
# Specify the path to your CSV file containing NIFTI paths
input_csv_path = '/Users/cu135/Dropbox (Partners HealthCare)/studies/cognition_2023/metadata/master_list_proper_subjects.xlsx'

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=input_csv_path, output_dir=out_dir, sheet='master_list_proper_subjects')
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()
# Out:
#      subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 0        101  62.0                                 -0.392857
# 1        102  77.0                                 -0.666667
# 2        103  76.0                                 -1.447368
# 3        104  65.0                                 -2.372549
# 4        105  50.0                                 -0.192982
# ..       ...   ...                                       ...
# 194      211  58.7                                       NaN
# 195      152  69.4                                       NaN
# 196      208  79.2                                       NaN
# 197      223  71.1                                       NaN
# 198      214  76.6                                       NaN
#
#      Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                             0.314066
# 1                                             0.013999
# 2                                            -0.841572
# 3                                            -1.855477
# 4                                             0.533109
# ..                                                 ...
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
#
#      Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                  0.314066                     -21.428571
# 1                                  0.013999                     -36.363636
# 2                                 -0.841572                     -78.947368
# 3                                 -1.855477                    -129.411765
# 4                                  0.533109                     -10.526316
# ..                                      ...                            ...
# 194                                     NaN                            NaN
# 195                                     NaN                            NaN
# 196                                     NaN                            NaN
# 197                                     NaN                            NaN
# 198                                     NaN                            NaN
#
#      Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                                -1.282630                          -1.282630
# 1                                -1.760917                          -1.760917
# 2                                -0.595369                          -0.595369
# 3                                -0.945206                          -0.945206
# 4                                -1.151973                          -1.151973
# ..                                     ...                                ...
# 194                              -0.415745                          -0.189000
# 195                              -0.701419                          -0.455000
# 196                              -0.929958                          -0.669000
# 197                              -0.829972                          -0.575000
# 198                              -1.244199                          -0.958000
#
#      Subiculum_Connectivity_T  Amnesia_Lesion_T_Map  ...  Estimated_Outcome  \
# 0                   56.864683              0.447264  ...                NaN
# 1                   52.970984              0.436157  ...                NaN
# 2                   62.459631              0.497749  ...                NaN
# 3                   59.611631              0.432617  ...                NaN
# 4                   57.928350              0.193389  ...                NaN
# ..                        ...                   ...  ...                ...
# 194                 19.900000                   NaN  ...               GOOD
# 195                 17.900000                   NaN  ...            DECLINE
# 196                 16.300000                   NaN  ...            DECLINE
# 197                 17.000000                   NaN  ...            DECLINE
# 198                 14.100000                   NaN  ...            DECLINE
#
#      Cognitive_Baseline  Z_Scored_Cognitive_Baseline  \
# 0                    28                     1.518764
# 1                    22                     0.465551
# 2                    19                    -0.061056
# 3                    17                    -0.412127
# 4                    19                    -0.061056
# ..                  ...                          ...
# 194                 NaN                          NaN
# 195                 NaN                          NaN
# 196                 NaN                          NaN
# 197                 NaN                          NaN
# 198                 NaN                          NaN
#
#      Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                        -1.518764
# 1                                        -0.465551
# 2                                         0.061056
# 3                                         0.412127
# 4                                         0.061056
# ..                                             ...
# 194                                            NaN
# 195                                            NaN
# 196                                            NaN
# 197                                            NaN
# 198                                            NaN
#
#      Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                           0.72                                 0.28
# 1                           0.48                                 0.52
# 2                           0.36                                 0.64
# 3                           0.28                                 0.72
# 4                           0.36                                 0.64
# ..                           ...                                  ...
# 194                          NaN                                  NaN
# 195                          NaN                                  NaN
# 196                          NaN                                  NaN
# 197                          NaN                                  NaN
# 198                          NaN                                  NaN
#
#      ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0         12.222658      14.493929            -1.714513            -1.227368
# 1         14.020048      15.257338            -1.155843            -1.022243
# 2         15.118727      17.376384            -0.814348            -0.452865
# 3         13.112424      15.287916            -1.437954            -1.014027
# 4         15.086568      12.951426            -0.824344            -1.641831
# ..              ...            ...                  ...                  ...
# 194             NaN            NaN                  NaN                  NaN
# 195             NaN            NaN                  NaN                  NaN
# 196             NaN            NaN                  NaN                  NaN
# 197             NaN            NaN                  NaN                  NaN
# 198             NaN            NaN                  NaN                  NaN
#
# [199 rows x 44 columns]

# %% [markdown]
# # 01 - Preprocess Your Data

# %% [markdown]
# **Handle NANs**
# - Set drop_nans=True is you would like to remove NaNs from data
# - Provide a column name or a list of column names to remove NaNs from

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T',
#        'Amnesia_Lesion_T_Map', 'Memory_Network_T', 'Z_Scored_Memory_Network_R',
#        'Memory_Network_R', 'Subiculum_Grey_Matter', 'Subiculum_White_Matter',
#        'Subiculum_CSF', 'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Age_Group', 'Age_And_Disease',
#        'Age_Disease_and_Cohort', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Cognitive_Outcome',
#        'Estimated_Outcome', 'Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %%
drop_list = ['Age', 'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group', 'Z_Scored_Subiculum_T_By_Origin_Group_']

# %%
data_df = cal_palm.drop_nans_from_columns(columns_to_drop_from=drop_list)
display(data_df)
# Out:
#      subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 0        101  62.0                                 -0.392857
# 1        102  77.0                                 -0.666667
# 2        103  76.0                                 -1.447368
# 3        104  65.0                                 -2.372549
# 4        105  50.0                                 -0.192982
# ..       ...   ...                                       ...
# 160       86  57.0                                       NaN
# 161       87  65.0                                       NaN
# 162       88  65.0                                       NaN
# 163       89  67.0                                       NaN
# 164       91  45.0                                       NaN
#
#      Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                             0.314066
# 1                                             0.013999
# 2                                            -0.841572
# 3                                            -1.855477
# 4                                             0.533109
# ..                                                 ...
# 160                                           0.598787
# 161                                           0.598787
# 162                                           5.854050
# 163                                           0.598787
# 164                                           1.818759
#
#      Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                  0.314066                     -21.428571
# 1                                  0.013999                     -36.363636
# 2                                 -0.841572                     -78.947368
# 3                                 -1.855477                    -129.411765
# 4                                  0.533109                     -10.526316
# ..                                      ...                            ...
# 160                               -0.099428                       0.000000
# 161                               -0.099428                       0.000000
# 162                                2.637141                      15.384615
# 163                               -0.099428                       0.000000
# 164                                0.535847                       3.571429
#
#      Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                                -1.282630                          -1.282630
# 1                                -1.760917                          -1.760917
# 2                                -0.595369                          -0.595369
# 3                                -0.945206                          -0.945206
# 4                                -1.151973                          -1.151973
# ..                                     ...                                ...
# 160                              -0.087220                          -0.621000
# 161                               0.598397                           0.173000
# 162                               0.269872                          -0.207000
# 163                              -0.158639                          -0.694000
# 164                               0.469844                           0.019400
#
#      Subiculum_Connectivity_T  Amnesia_Lesion_T_Map  ...  Estimated_Outcome  \
# 0                   56.864683              0.447264  ...                NaN
# 1                   52.970984              0.436157  ...                NaN
# 2                   62.459631              0.497749  ...                NaN
# 3                   59.611631              0.432617  ...                NaN
# 4                   57.928350              0.193389  ...                NaN
# ..                        ...                   ...  ...                ...
# 160                 22.200000                   NaN  ...                NaN
# 161                 27.000000                   NaN  ...                NaN
# 162                 24.700000                   NaN  ...                NaN
# 163                 21.700000                   NaN  ...                NaN
# 164                 26.100000                   NaN  ...                NaN
#
#      Cognitive_Baseline  Z_Scored_Cognitive_Baseline  \
# 0                    28                     1.518764
# 1                    22                     0.465551
# 2                    19                    -0.061056
# 3                    17                    -0.412127
# 4                    19                    -0.061056
# ..                  ...                          ...
# 160                 NaN                          NaN
# 161                 NaN                          NaN
# 162                 NaN                          NaN
# 163                 NaN                          NaN
# 164                 NaN                          NaN
#
#      Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                        -1.518764
# 1                                        -0.465551
# 2                                         0.061056
# 3                                         0.412127
# 4                                         0.061056
# ..                                             ...
# 160                                            NaN
# 161                                            NaN
# 162                                            NaN
# 163                                            NaN
# 164                                            NaN
#
#      Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                           0.72                                 0.28
# 1                           0.48                                 0.52
# 2                           0.36                                 0.64
# 3                           0.28                                 0.72
# 4                           0.36                                 0.64
# ..                           ...                                  ...
# 160                          NaN                                  NaN
# 161                          NaN                                  NaN
# 162                          NaN                                  NaN
# 163                          NaN                                  NaN
# 164                          NaN                                  NaN
#
#      ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0         12.222658      14.493929            -1.714513            -1.227368
# 1         14.020048      15.257338            -1.155843            -1.022243
# 2         15.118727      17.376384            -0.814348            -0.452865
# 3         13.112424      15.287916            -1.437954            -1.014027
# 4         15.086568      12.951426            -0.824344            -1.641831
# ..              ...            ...                  ...                  ...
# 160             NaN            NaN                  NaN                  NaN
# 161             NaN            NaN                  NaN                  NaN
# 162             NaN            NaN                  NaN                  NaN
# 163             NaN            NaN                  NaN                  NaN
# 164             NaN            NaN                  NaN                  NaN
#
# [148 rows x 44 columns]

# %% [markdown]
# **Drop Row Based on Value of Column**
#
# Define the column, condition, and value for dropping rows
# - column = 'your_column_name'
# - condition = 'above'  # Options: 'equal', 'above', 'below'

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T',
#        'Amnesia_Lesion_T_Map', 'Memory_Network_T', 'Z_Scored_Memory_Network_R',
#        'Memory_Network_R', 'Subiculum_Grey_Matter', 'Subiculum_White_Matter',
#        'Subiculum_CSF', 'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Age_Group', 'Age_And_Disease',
#        'Age_Disease_and_Cohort', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Cognitive_Outcome',
#        'Estimated_Outcome', 'Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %% [markdown]
# Set the parameters for dropping rows

# %%
column = 'City'  # The column you'd like to evaluate
condition = 'not'  # The condition to check ('equal', 'above', 'below', 'not')
value = 'Toronto' # The value to drop if found

# %%
data_df, other_df = cal_palm.drop_rows_based_on_value(column, condition, value)
display(data_df)
# Out:
#     subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 0       101  62.0                                 -0.392857
# 1       102  77.0                                 -0.666667
# 2       103  76.0                                 -1.447368
# 3       104  65.0                                 -2.372549
# 4       105  50.0                                 -0.192982
# 5       106  66.0                                 -0.705128
# 6       107  64.0                                 -0.282051
# 7       108  60.0                                 -0.534722
# 8       109  72.0                                 -0.557971
# 9       110  72.0                                 -1.551282
# 10      111  62.0                                  0.763889
# 11      113  69.0                                 -1.100000
# 12      114  67.0                                 -0.295699
# 13      115  60.0                                 -0.885057
# 14      116  67.0                                 -0.675439
# 15      118  52.0                                 -0.057292
# 16      119  75.0                                 -1.489583
# 17      120  68.0                                 -0.509259
# 18      121  72.0                                 -0.079710
# 19      122  58.0                                 -2.566667
# 20      123  47.0                                  1.000000
# 21      124  61.0                                 -0.343750
# 22      125  73.0                                 -0.687500
# 23      126  69.0                                 -1.833333
# 24      127  74.0                                 -1.401961
# 25      128  72.0                                 -0.381944
# 26      129  69.0                                 -0.654762
# 27      130  66.0                                 -0.130952
# 28      131  68.0                                 -0.733333
# 29      133  74.0                                  0.114583
# 30      134  66.0                                  0.539216
# 31      135  57.0                                 -0.838095
# 32      137  57.0                                 -1.416667
# 33      138  72.0                                 -0.174603
# 34      139  58.0                                 -1.941176
# 35      140  73.0                                  0.333333
# 36      141  72.0                                  0.000000
# 37      142  77.0                                  0.101852
# 38      143  71.0                                  0.114583
# 39      144  79.0                                 -1.128205
# 40      145  74.0                                  0.101852
# 41      146  76.0                                 -1.000000
# 42      147  59.0                                 -0.087302
# 43      148  51.0                                 -3.807692
# 44      149  77.0                                 -1.650000
# 45      150  71.0                                  0.250000
#
#     Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                            0.314066
# 1                                            0.013999
# 2                                           -0.841572
# 3                                           -1.855477
# 4                                            0.533109
# 5                                           -0.028151
# 6                                            0.435498
# 7                                            0.158596
# 8                                            0.133118
# 9                                           -0.955451
# 10                                           1.581744
# 11                                          -0.460891
# 12                                           0.420542
# 13                                          -0.225336
# 14                                           0.004385
# 15                                           0.681812
# 16                                          -0.887835
# 17                                           0.186501
# 18                                           0.657244
# 19                                          -2.068210
# 20                                           1.840498
# 21                                           0.367883
# 22                                          -0.008833
# 23                                          -1.264551
# 24                                          -0.791810
# 25                                           0.326026
# 26                                           0.027045
# 27                                           0.601088
# 28                                          -0.059061
# 29                                           0.870170
# 30                                           1.335524
# 31                                          -0.173870
# 32                                          -0.807926
# 33                                           0.553251
# 34                                          -1.382736
# 35                                           1.109898
# 36                                           0.744598
# 37                                           0.856218
# 38                                           0.870170
# 39                                          -0.491801
# 40                                           0.856218
# 41                                          -0.351301
# 42                                           0.648924
# 43                                          -3.428250
# 44                                          -1.063636
# 45                                           1.018573
#
#     Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                 0.314066                     -21.428571
# 1                                 0.013999                     -36.363636
# 2                                -0.841572                     -78.947368
# 3                                -1.855477                    -129.411765
# 4                                 0.533109                     -10.526316
# 5                                -0.028151                     -38.461538
# 6                                 0.435498                     -15.384615
# 7                                 0.158596                     -29.166667
# 8                                 0.133118                     -30.434783
# 9                                -0.955451                     -84.615385
# 10                                1.581744                      41.666667
# 11                               -0.460891                     -60.000000
# 12                                0.420542                     -16.129032
# 13                               -0.225336                     -48.275862
# 14                                0.004385                     -36.842105
# 15                                0.681812                      -3.125000
# 16                               -0.887835                     -81.250000
# 17                                0.186501                     -27.777778
# 18                                0.657244                      -4.347826
# 19                               -2.068210                    -140.000000
# 20                                1.840498                      54.545455
# 21                                0.367883                     -18.750000
# 22                               -0.008833                     -37.500000
# 23                               -1.264551                    -100.000000
# 24                               -0.791810                     -76.470588
# 25                                0.326026                     -20.833333
# 26                                0.027045                     -35.714286
# 27                                0.601088                      -7.142857
# 28                               -0.059061                     -40.000000
# 29                                0.870170                       6.250000
# 30                                1.335524                      29.411765
# 31                               -0.173870                     -45.714286
# 32                               -0.807926                     -77.272727
# 33                                0.553251                      -9.523810
# 34                               -1.382736                    -105.882353
# 35                                1.109898                      18.181818
# 36                                0.744598                       0.000000
# 37                                0.856218                       5.555556
# 38                                0.870170                       6.250000
# 39                               -0.491801                     -61.538462
# 40                                0.856218                       5.555556
# 41                               -0.351301                     -54.545455
# 42                                0.648924                      -4.761905
# 43                               -3.428250                    -207.692308
# 44                               -1.063636                     -90.000000
# 45                                1.018573                      13.636364
#
#     Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                               -1.282630                          -1.282630
# 1                               -1.760917                          -1.760917
# 2                               -0.595369                          -0.595369
# 3                               -0.945206                          -0.945206
# 4                               -1.151973                          -1.151973
# 5                               -0.489205                          -0.489205
# 6                               -1.718309                          -1.718309
# 7                               -1.145694                          -1.145694
# 8                               -0.043697                          -0.043697
# 9                                0.240855                           0.240855
# 10                               2.004069                           2.004069
# 11                               0.301223                           0.301223
# 12                               0.015433                           0.015433
# 13                               0.472801                           0.472801
# 14                              -0.657659                          -0.657659
# 15                               0.643782                           0.643782
# 16                              -0.637257                          -0.637257
# 17                              -0.781964                          -0.781964
# 18                               0.481163                           0.481163
# 19                               0.190387                           0.190387
# 20                              -0.341607                          -0.341607
# 21                              -0.864253                          -0.864253
# 22                               0.536747                           0.536747
# 23                               1.081582                           1.081582
# 24                               0.009987                           0.009987
# 25                               1.010239                           1.010239
# 26                               1.271528                           1.271528
# 27                              -0.161232                          -0.161232
# 28                               0.576257                           0.576257
# 29                               0.938667                           0.938667
# 30                               0.609143                           0.609143
# 31                              -0.484585                          -0.484585
# 32                              -0.210108                          -0.210108
# 33                               1.634297                           1.634297
# 34                              -0.768437                          -0.768437
# 35                               0.660878                           0.660878
# 36                               1.169749                           1.169749
# 37                               0.328286                           0.328286
# 38                              -0.118729                          -0.118729
# 39                              -1.032653                          -1.032653
# 40                               2.183535                           2.183535
# 41                              -2.576474                          -2.576474
# 42                               0.262965                           0.262965
# 43                               1.035924                           1.035924
# 44                              -0.650900                          -0.650900
# 45                               0.759359                           0.759359
#
#     Subiculum_Connectivity_T  Amnesia_Lesion_T_Map  ...  Estimated_Outcome  \
# 0                  56.864683              0.447264  ...                NaN
# 1                  52.970984              0.436157  ...                NaN
# 2                  62.459631              0.497749  ...                NaN
# 3                  59.611631              0.432617  ...                NaN
# 4                  57.928350              0.193389  ...                NaN
# 5                  63.323903              0.513828  ...                NaN
# 6                  53.317851              0.249080  ...                NaN
# 7                  57.979468              0.247062  ...                NaN
# 8                  66.950749              0.514661  ...                NaN
# 9                  69.267271              0.530628  ...                NaN
# 10                 83.621480              0.514182  ...                NaN
# 11                 69.758721              0.497508  ...                NaN
# 12                 67.432125              0.461019  ...                NaN
# 13                 71.155530              0.227943  ...                NaN
# 14                 61.952527              0.485376  ...                NaN
# 15                 72.547473              0.247475  ...                NaN
# 16                 62.118622              0.503218  ...                NaN
# 17                 60.940570              0.284504  ...                NaN
# 18                 71.223601              0.483995  ...                NaN
# 19                 68.856418              0.512125  ...                NaN
# 20                 64.525483              0.507649  ...                NaN
# 21                 60.270662              0.460080  ...                NaN
# 22                 71.676110              0.479488  ...                NaN
# 23                 76.111573              0.477498  ...                NaN
# 24                 67.387791              0.501404  ...                NaN
# 25                 75.530777              0.511383  ...                NaN
# 26                 77.657909              0.496203  ...                NaN
# 27                 65.993904              0.510956  ...                NaN
# 28                 71.997755              0.458336  ...                NaN
# 29                 74.948112              0.503698  ...                NaN
# 30                 72.265483              0.402215  ...                NaN
# 31                 63.361510              0.481574  ...                NaN
# 32                 65.596015              0.486037  ...                NaN
# 33                 80.611188              0.471613  ...                NaN
# 34                 61.050691              0.520899  ...                NaN
# 35                 72.686647              0.415110  ...                NaN
# 36                 76.829337              0.503535  ...                NaN
# 37                 69.979040              0.521941  ...                NaN
# 38                 66.339918              0.569043  ...                NaN
# 39                 58.899731              0.470849  ...                NaN
# 40                 85.082502              0.420971  ...                NaN
# 41                 46.331586              0.469571  ...                NaN
# 42                 69.447270              0.530166  ...                NaN
# 43                 75.739873              0.489891  ...                NaN
# 44                 62.007555              0.480527  ...                NaN
# 45                 73.488381              0.461720  ...                NaN
#
#     Cognitive_Baseline  Z_Scored_Cognitive_Baseline  \
# 0                   28                     1.518764
# 1                   22                     0.465551
# 2                   19                    -0.061056
# 3                   17                    -0.412127
# 4                   19                    -0.061056
# 5                   13                    -1.114269
# 6                   13                    -1.114269
# 7                   24                     0.816622
# 8                   23                     0.641086
# 9                   13                    -1.114269
# 10                  12                    -1.289805
# 11                  15                    -0.763198
# 12                  31                     2.045371
# 13                  29                     1.694300
# 14                  19                    -0.061056
# 15                  32                     2.220907
# 16                  16                    -0.587663
# 17                  18                    -0.236591
# 18                  23                     0.641086
# 19                  15                    -0.763198
# 20                  22                     0.465551
# 21                  16                    -0.587663
# 22                  16                    -0.587663
# 23                  21                     0.290015
# 24                  17                    -0.412127
# 25                  24                     0.816622
# 26                  28                     1.518764
# 27                  14                    -0.938734
# 28                  20                     0.114480
# 29                  16                    -0.587663
# 30                  17                    -0.412127
# 31                  35                     2.747514
# 32                  22                     0.465551
# 33                  21                     0.290015
# 34                  17                    -0.412127
# 35                  22                     0.465551
# 36                  19                    -0.061056
# 37                  18                    -0.236591
# 38                  16                    -0.587663
# 39                  13                    -1.114269
# 40                  18                    -0.236591
# 41                  11                    -1.465341
# 42                  21                     0.290015
# 43                  13                    -1.114269
# 44                  10                    -1.640876
# 45                  22                     0.465551
#
#     Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                       -1.518764
# 1                                       -0.465551
# 2                                        0.061056
# 3                                        0.412127
# 4                                        0.061056
# 5                                        1.114269
# 6                                        1.114269
# 7                                       -0.816622
# 8                                       -0.641086
# 9                                        1.114269
# 10                                       1.289805
# 11                                       0.763198
# 12                                      -2.045371
# 13                                      -1.694300
# 14                                       0.061056
# 15                                      -2.220907
# 16                                       0.587663
# 17                                       0.236591
# 18                                      -0.641086
# 19                                       0.763198
# 20                                      -0.465551
# 21                                       0.587663
# 22                                       0.587663
# 23                                      -0.290015
# 24                                       0.412127
# 25                                      -0.816622
# 26                                      -1.518764
# 27                                       0.938734
# 28                                      -0.114480
# 29                                       0.587663
# 30                                       0.412127
# 31                                      -2.747514
# 32                                      -0.465551
# 33                                      -0.290015
# 34                                       0.412127
# 35                                      -0.465551
# 36                                       0.061056
# 37                                       0.236591
# 38                                       0.587663
# 39                                       1.114269
# 40                                       0.236591
# 41                                       1.465341
# 42                                      -0.290015
# 43                                       1.114269
# 44                                       1.640876
# 45                                      -0.465551
#
#     Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                          0.72                                 0.28
# 1                          0.48                                 0.52
# 2                          0.36                                 0.64
# 3                          0.28                                 0.72
# 4                          0.36                                 0.64
# 5                          0.12                                 0.88
# 6                          0.12                                 0.88
# 7                          0.56                                 0.44
# 8                          0.52                                 0.48
# 9                          0.12                                 0.88
# 10                         0.08                                 0.92
# 11                         0.20                                 0.80
# 12                         0.84                                 0.16
# 13                         0.76                                 0.24
# 14                         0.36                                 0.64
# 15                         0.88                                 0.12
# 16                         0.24                                 0.76
# 17                         0.32                                 0.68
# 18                         0.52                                 0.48
# 19                         0.20                                 0.80
# 20                         0.48                                 0.52
# 21                         0.24                                 0.76
# 22                         0.24                                 0.76
# 23                         0.44                                 0.56
# 24                         0.28                                 0.72
# 25                         0.56                                 0.44
# 26                         0.72                                 0.28
# 27                         0.16                                 0.84
# 28                         0.40                                 0.60
# 29                         0.24                                 0.76
# 30                         0.28                                 0.72
# 31                         1.00                                 0.00
# 32                         0.48                                 0.52
# 33                         0.44                                 0.56
# 34                         0.28                                 0.72
# 35                         0.48                                 0.52
# 36                         0.36                                 0.64
# 37                         0.32                                 0.68
# 38                         0.24                                 0.76
# 39                         0.12                                 0.88
# 40                         0.32                                 0.68
# 41                         0.04                                 0.96
# 42                         0.44                                 0.56
# 43                         0.12                                 0.88
# 44                         0.00                                 1.00
# 45                         0.48                                 0.52
#
#     ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0        12.222658      14.493929            -1.714513            -1.227368
# 1        14.020048      15.257338            -1.155843            -1.022243
# 2        15.118727      17.376384            -0.814348            -0.452865
# 3        13.112424      15.287916            -1.437954            -1.014027
# 4        15.086568      12.951426            -0.824344            -1.641831
# 5        15.816634      17.617107            -0.597423            -0.388183
# 6        15.524025      13.452311            -0.688373            -1.507246
# 7        16.546984      13.932696            -0.370413            -1.378169
# 8        19.669539      21.341523             0.600149             0.612551
# 9        18.295718      19.263977             0.173133             0.054323
# 10       17.022328      16.151031            -0.222665            -0.782112
# 11       16.225059      17.818822            -0.470475            -0.333983
# 12       15.295109      18.046377            -0.759525            -0.272840
# 13       18.623736      16.113043             0.275089            -0.792319
# 14       16.462336      18.503053            -0.396724            -0.150134
# 15       15.842273      19.964170            -0.589454             0.242462
# 16       17.332886      19.198042            -0.126137             0.036607
# 17       10.126563       9.630690            -2.366028            -2.534098
# 18       22.476761      23.985143             1.472698             1.322880
# 19       21.466327      23.582758             1.158632             1.214761
# 20       19.453283      21.676897             0.532931             0.702664
# 21       13.457540      15.819523            -1.330684            -0.871186
# 22       22.443084      24.738357             1.462230             1.525265
# 23       20.186102      22.065363             0.760708             0.807044
# 24       16.996513      18.394062            -0.230689            -0.179419
# 25       17.204945      18.264558            -0.165904            -0.214216
# 26       21.078380      22.489816             1.038049             0.921092
# 27       18.617648      20.415928             0.273197             0.363848
# 28       18.410547      19.822564             0.208825             0.204413
# 29       18.420784      19.612924             0.212007             0.148084
# 30       23.613479      26.048153             1.826016             1.877202
# 31       16.101986      17.647381            -0.508729            -0.380049
# 32       16.837360      18.171505            -0.280158            -0.239219
# 33       20.531868      22.371502             0.868180             0.889302
# 34       17.957341      19.952870             0.067958             0.239426
# 35       24.418011      27.143129             2.076083             2.171417
# 36       17.856530      19.670979             0.036624             0.163683
# 37       14.769545      16.131533            -0.922882            -0.787351
# 38       20.179952      19.975031             0.758797             0.245380
# 39       11.801552      14.042861            -1.845403            -1.348567
# 40       21.327670      22.294652             1.115534             0.868652
# 41       16.512422      18.197520            -0.381156            -0.232229
# 42       19.159295      19.553377             0.441553             0.132084
# 43       19.340269      21.114119             0.497804             0.551449
# 44       19.062652      20.569076             0.411514             0.404998
# 45       23.954833      26.691505             1.932117             2.050067
#
# [46 rows x 44 columns]

# %% [markdown]
# **Standardize Data**
# - Enter Columns you Don't want to standardize into a list

# %%
# Remove anything you don't want to standardize
cols_not_to_standardize = ['Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group', 'Z_Scored_Subiculum_T_By_Origin_Group_'] #['Age']

# %%
data_df = cal_palm.standardize_columns(cols_not_to_standardize)
data_df

# %% [markdown]
# # 02 - Define Your Formula
#
# This is the formula relating outcome to predictors, and takes the form:
# - y = B0 + B1 + B2 + B3 + . . . BN
#
# It is defined using the columns of your dataframe instead of the variables above:
# - 'Apples_Picked ~ hours_worked + owns_apple_picking_machine'
#
# ____
# **ANOVA**
# - Tests differences in means for one categorical variable.
# - formula = 'Outcome ~ C(Group1)'
#
# **2-Way ANOVA**
# - Tests differences in means for two categorical variables without interaction.
# - formula = 'Outcome ~ C(Group1) + C(Group2)'
#
# **2-Way ANOVA with Interaction**
# - Tests for interaction effects between two categorical variables.
# - formula = 'Outcome ~ C(Group1) * C(Group2)'
#
# **ANCOVA**
# - Similar to ANOVA, but includes a covariate to control for its effect.
# - formula = 'Outcome ~ C(Group1) + Covariate'
#
# **2-Way ANCOVA**
# - Extends ANCOVA with two categorical variables and their interaction, controlling for a covariate.
# - formula = 'Outcome ~ C(Group1) * C(Group2) + Covariate'
#
# **Multiple Regression**
# - Assesses the impact of multiple predictors on an outcome.
# - formula = 'Outcome ~ Predictor1 + Predictor2'
#
# **Simple Linear Regression**
# - Assesses the impact of a single predictor on an outcome.
# - formula = 'Outcome ~ Predictor'
#
# **MANOVA**
# - Assesses multiple dependent variables across groups.
# - Note: Not typically set up with a formula in statsmodels. Requires specialized functions.
#
# ____
# Use the printout below to design your formula.
# - Left of the "~" symbol is the thing to be predicted.
# - Right of the "~" symbol are the predictors.
# - ":" indicates an interaction between two things.
# - "*" indicates and interactions AND it accounts for the simple effects too.
# - "+" indicates that you want to add another predictor.

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T',
#        'Amnesia_Lesion_T_Map', 'Memory_Network_T', 'Z_Scored_Memory_Network_R',
#        'Memory_Network_R', 'Subiculum_Grey_Matter', 'Subiculum_White_Matter',
#        'Subiculum_CSF', 'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Age_Group', 'Age_And_Disease',
#        'Age_Disease_and_Cohort', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Cognitive_Outcome',
#        'Estimated_Outcome', 'Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %%
formula = "Z_Scored_Percent_Cognitive_Improvement ~ Age*Subiculum_Connectivity_T"

# %% [markdown]
# # 02 - Visualize Your Design Matrix
#
# This is the explanatory variable half of your regression formula
# _______________________________________________________
# Create Design Matrix: Use the create_design_matrix method. You can provide a list of formula variables which correspond to column names in your dataframe.
#
# - design_matrix = palm.create_design_matrix(formula_vars=["var1", "var2", "var1*var2"])
# - To include interaction terms, use * between variables, like "var1*var2".
# - By default, an intercept will be added unless you set intercept=False
# - **don't explicitly add the 'intercept' column. I'll do it for you.**

# %%
# Define the design matrix
outcome_matrix, design_matrix = cal_palm.define_design_matrix(formula, data_df)
design_matrix
# Out:
#     Intercept   Age  Subiculum_Connectivity_T  Age:Subiculum_Connectivity_T
# 0         1.0  62.0                 56.864683                   3525.610316
# 1         1.0  77.0                 52.970984                   4078.765733
# 2         1.0  76.0                 62.459631                   4746.931951
# 3         1.0  65.0                 59.611631                   3874.756046
# 4         1.0  50.0                 57.928350                   2896.417494
# 5         1.0  66.0                 63.323903                   4179.377605
# 6         1.0  64.0                 53.317851                   3412.342461
# 7         1.0  60.0                 57.979468                   3478.768094
# 8         1.0  72.0                 66.950749                   4820.453925
# 9         1.0  72.0                 69.267271                   4987.243531
# 10        1.0  62.0                 83.621480                   5184.531741
# 11        1.0  69.0                 69.758721                   4813.351727
# 12        1.0  67.0                 67.432125                   4517.952372
# 13        1.0  60.0                 71.155530                   4269.331799
# 14        1.0  67.0                 61.952527                   4150.819278
# 15        1.0  52.0                 72.547473                   3772.468621
# 16        1.0  75.0                 62.118622                   4658.896618
# 17        1.0  68.0                 60.940570                   4143.958750
# 18        1.0  72.0                 71.223601                   5128.099294
# 19        1.0  58.0                 68.856418                   3993.672218
# 20        1.0  47.0                 64.525483                   3032.697710
# 21        1.0  61.0                 60.270662                   3676.510361
# 22        1.0  73.0                 71.676110                   5232.356049
# 23        1.0  69.0                 76.111573                   5251.698505
# 24        1.0  74.0                 67.387791                   4986.696505
# 25        1.0  72.0                 75.530777                   5438.215949
# 26        1.0  69.0                 77.657909                   5358.395710
# 27        1.0  66.0                 65.993904                   4355.597654
# 28        1.0  68.0                 71.997755                   4895.847373
# 29        1.0  74.0                 74.948112                   5546.160316
# 30        1.0  66.0                 72.265483                   4769.521849
# 31        1.0  57.0                 63.361510                   3611.606057
# 32        1.0  57.0                 65.596015                   3738.972848
# 33        1.0  72.0                 80.611188                   5804.005569
# 34        1.0  58.0                 61.050691                   3540.940101
# 35        1.0  73.0                 72.686647                   5306.125216
# 36        1.0  72.0                 76.829337                   5531.712278
# 37        1.0  77.0                 69.979040                   5388.386076
# 38        1.0  71.0                 66.339918                   4710.134206
# 39        1.0  79.0                 58.899731                   4653.078773
# 40        1.0  74.0                 85.082502                   6296.105178
# 41        1.0  76.0                 46.331586                   3521.200567
# 42        1.0  59.0                 69.447270                   4097.388918
# 43        1.0  51.0                 75.739873                   3862.733524
# 44        1.0  77.0                 62.007555                   4774.581704
# 45        1.0  71.0                 73.488381                   5217.675076

# %% [markdown]
# # 03 - Visualize Your Dependent Variable
#
# I have generated this for you based on the formula you provided

# %%
outcome_matrix
# Out:
#     Z_Scored_Percent_Cognitive_Improvement
# 0                                 0.314066
# 1                                 0.013999
# 2                                -0.841572
# 3                                -1.855477
# 4                                 0.533109
# 5                                -0.028151
# 6                                 0.435498
# 7                                 0.158596
# 8                                 0.133118
# 9                                -0.955451
# 10                                1.581744
# 11                               -0.460891
# 12                                0.420542
# 13                               -0.225336
# 14                                0.004385
# 15                                0.681812
# 16                               -0.887835
# 17                                0.186501
# 18                                0.657244
# 19                               -2.068210
# 20                                1.840498
# 21                                0.367883
# 22                               -0.008833
# 23                               -1.264551
# 24                               -0.791810
# 25                                0.326026
# 26                                0.027045
# 27                                0.601088
# 28                               -0.059061
# 29                                0.870170
# 30                                1.335524
# 31                               -0.173870
# 32                               -0.807926
# 33                                0.553251
# 34                               -1.382736
# 35                                1.109898
# 36                                0.744598
# 37                                0.856218
# 38                                0.870170
# 39                               -0.491801
# 40                                0.856218
# 41                               -0.351301
# 42                                0.648924
# 43                               -3.428250
# 44                               -1.063636
# 45                                1.018573

# %% [markdown]
# # 04 - Define Exchangeability Blocks (Optional)

# %% [markdown]
# Optional - Exchangability Blocks
# - This is optional and for when you are doing a meta-analysis
# - Not yet implemented

# %%
### This is just an example, you will have to edit to adapt to your data, 
### but it should be integers, starting with 1,2,3....

# coding_key = {"Prosopagnosia_w_Yeo1000": 1,
#              "Corbetta_Lesions": 1,
#              "DBS_dataset": 2
#              }

# eb_matrix = pd.DataFrame()
# eb_matrix = clean_df['dataset'].replace(coding_key)
# display(eb_matrix)

# %% [markdown]
# # 05 - Run the Regression

# %% [markdown]
# Regression Results Are Displayed Below

# %%
import statsmodels.api as sm
# Fit the regression model
model = sm.OLS(outcome_matrix, design_matrix)
results = model.fit()
print(results.summary2())
# Out:
#                             Results: Ordinary least squares
# =======================================================================================
# Model:              OLS                                    Adj. R-squared:     0.080
# Dependent Variable: Z_Scored_Percent_Cognitive_Improvement AIC:                130.5050
# Date:               2024-02-22 17:41                       BIC:                137.8196
# No. Observations:   46                                     Log-Likelihood:     -61.253
# Df Model:           3                                      F-statistic:        2.310
# Df Residuals:       42                                     Prob (F-statistic): 0.0901
# R-squared:          0.142                                  Scale:              0.91966
# -----------------------------------------------------------------------------------------
#                                  Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------------------
# Intercept                       21.9740    10.8992    2.0161   0.0502   -0.0215   43.9695
# Age                             -0.3415     0.1573   -2.1703   0.0357   -0.6590   -0.0239
# Subiculum_Connectivity_T        -0.3421     0.1650   -2.0738   0.0443   -0.6750   -0.0092
# Age:Subiculum_Connectivity_T     0.0053     0.0024    2.2283   0.0313    0.0005    0.0101
# ---------------------------------------------------------------------------------------
# Omnibus:                      3.296               Durbin-Watson:                 2.277
# Prob(Omnibus):                0.192               Jarque-Bera (JB):              2.231
# Skew:                         -0.483              Prob(JB):                      0.328
# Kurtosis:                     3.481               Condition No.:                 352572
# =======================================================================================
# * The condition number is large (4e+05). This might indicate             strong
# multicollinearity or other numerical problems.

# %% [markdown]
# Visualize the Regression as a Forest Plot
# - This will probably look poor if you ran a regression without standardizing your data.

# %%
from calvin_utils.statistical_utils.statistical_measurements import ForestPlot
forest = ForestPlot(model=results, sig_digits=2, out_dir=out_dir, table=False)
forest.run()
# Out:
# Saved to /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Research/2023/subiculum_cognition_and_age/figures/Figures/joint_distribution_calculus/analyses as regression_forest_plot.svg and .png

# %% [markdown]
# Visualize The Model's Fit

# %%
from calvin_utils.statistical_utils.statistical_measurements import model_diagnostics
model_diagnostics(results)

# %% [markdown]
# Visualize the Partial Regression Plots

# %%
from calvin_utils.statistical_utils.statistical_measurements import PartialRegressionPlot
partial_plot = PartialRegressionPlot(model=results, design_matrix=design_matrix, out_dir=out_dir, palette='Reds')
partial_plot = partial_plot.run()
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# Saved to /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Research/2023/subiculum_cognition_and_age/figures/Figures/joint_distribution_calculus/analyses/partial_regression_plot.svg

# %% [markdown]
# # 06 - Find First Partial Derivative of Each Regressor
#
# **Partial Derivative Explanation for the Equation $ y = B_1x + B_2z + B_3xz $**
#
# When taking the partial derivative of the equation $ y = B_1x + B_2z + B_3xz $ with respect to $ x $, the logic is as follows:
#
# - Treat $ z $ as a constant since we are differentiating with respect to $ x $.
# - Derivatives of constants are zero. Derivatives of first-order polynomials ($ x $) are one.
# - All terms with $ z $ are treated as constants.
#     - This means both $ B_2z $ and $ B_3z $ are considered constants.
#     - When differentiated with respect to $ x $:
#         - $ B_2z $ does not have $ x $. Thus its derivative is zero.
#         - $ B_3z $ has an $ x $ term in $ B_3zx $, thus its derivative is the constant $ B_3z $.
#             - This is due to the special situation of the product rule wherein the derivative of a constant and a differentiable variable is = constant * derivative of differentiable variable.
#
# Hence, the partial derivative of $ y $ with respect to $ x $ is given by:
#
# $$ {\partial y}/{\partial x} = {\partial y}/{\partial x}(B_1x) + {\partial y}/{\partial x}(B_2z) + {\partial y}/{\partial x}(B_3xz) $$
#
# The product rule is applied to the interaction term, which expanding provides:
#
# $$ {\partial y}/{\partial x} = {\partial y}/{\partial x}(B_1x) + {\partial y}/{\partial x}(B_2z) + {\partial y}/{\partial x}(B_3x) * {\partial y}/{\partial x}(B_3z) $$
#
# Which applying the product rule, is equivalent to:
#
# $$ {\partial y}/{\partial x} = {\partial y}/{\partial x}(B_1x) + {\partial y}/{\partial x}(B_2z) + 1 * {\partial y}/{\partial x}(B_3z) $$
#
# The derivative of a constant (z) is equivalent to zero. Thus, simplifying this, we get:
#
# $$ {\partial y}{\partial x} = B_1 + 0 + B_3z $$
#
# Therefore, the resulting equation for the partial derivative is:
#
# $$ {\partial y}{\partial x} = B_1 + B_3z $$
#
# This equation represents the rate of change of $ y $ with respect to $ x $, while holding $ z $ constant.

# %%
coefficients = results.params
coefficients
# Out:
# Intercept                       21.974007
# Age                             -0.341465
# Subiculum_Connectivity_T        -0.342122
# Age:Subiculum_Connectivity_T     0.005304
# dtype: float64

# %% [markdown]
# Use the Above Coefficients With This Equation to Obtain Zero Point
#
# $$ 0 = B_1 + B_3z $$
#
# The critical point of $ x $ occurs at this point:
#
# $$ -B_1 / B_3 = z $$

# %%
print('Zero point of Age: ', -coefficients['Subiculum_Connectivity_T']/coefficients['Age:Subiculum_Connectivity_T'])
print('Zero point of Subiculum Connectivty: ', -coefficients['Age']/coefficients['Age:Subiculum_Connectivity_T'])
# Out:
# Zero point of Age:  64.50448196834475
# Zero point of Subiculum Connectivty:  64.38074076494887

# %% [markdown]
# **At this Point, I suggest visualizing the distribution of the data to insure you did not screw up your math and create a nonsensical number**

# %%
import seaborn as sns
pair_df = data_df.loc[:, ['Age', 'Subiculum_Connectivity_T', 'Z_Scored_Percent_Cognitive_Improvement']]
sns.pairplot(pair_df)

# %% [markdown]
# # 07 - Visualize the Partials
#
# Suggest using regression_visualization.ipynb for the joint distribution and visualization of its gradient.

# %% [markdown]
# **Note**
# - This gets more complicated with more interaction terms. Each equation must be solved by you.

# %% [markdown]
# Enjoy.
#
# -- Calvin
