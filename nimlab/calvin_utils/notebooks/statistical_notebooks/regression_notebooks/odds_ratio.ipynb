# %% [markdown]
# # Run An Odds Ratio
#
# ### Authors: Calvin Howard.
#
# #### Last updated: July 6, 2023
#
# Use this to run/test a statistical model on a spreadsheet.
#
# Notes:
# - To best use this notebook, you should be familar with GLM design and Contrast Matrix design. See this webpage to get started:
# [FSL's GLM page](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM)

# %% [markdown]
# # 00 - Import CSV with All Data
# **The CSV is expected to be in this format**
# - ID and absolute paths to niftis are critical
# ```
# +-----+----------------------------+--------------+--------------+--------------+
# | ID  | Nifti_File_Path            | Covariate_1  | Covariate_2  | Covariate_3  |
# +-----+----------------------------+--------------+--------------+--------------+
# | 1   | /path/to/file1.nii.gz      | 0.5          | 1.2          | 3.4          |
# | 2   | /path/to/file2.nii.gz      | 0.7          | 1.4          | 3.1          |
# | 3   | /path/to/file3.nii.gz      | 0.6          | 1.5          | 3.5          |
# | 4   | /path/to/file4.nii.gz      | 0.9          | 1.1          | 3.2          |
# | ... | ...                        | ...          | ...          | ...          |
# +-----+----------------------------+--------------+--------------+--------------+
# ```

# %% [markdown]
# Prep Output Direction

# %%
# Specify where you want to save your results to
out_dir = '/Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Research/2023/subiculum_cognition_and_age/figures/Figures/odds_ratios/meaningful_threshoold'

# %% [markdown]
# Import Data

# %%
# Specify the path to your CSV file containing NIFTI paths
input_csv_path = '/Users/cu135/Dropbox (Partners HealthCare)/studies/cognition_2023/metadata/master_list_proper_subjects.xlsx'
sheet = 'master_list_proper_subjects'

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=input_csv_path, output_dir=out_dir, sheet=sheet)
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()
# Out:
#      subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 0        101  62.0                                 -0.392857
# 1        102  77.0                                 -0.666667
# 2        103  76.0                                 -1.447368
# 3        104  65.0                                 -2.372549
# 4        105  50.0                                 -0.192982
# ..       ...   ...                                       ...
# 194      211  58.7                                       NaN
# 195      152  69.4                                       NaN
# 196      208  79.2                                       NaN
# 197      223  71.1                                       NaN
# 198      214  76.6                                       NaN
#
#      Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                             0.314066
# 1                                             0.013999
# 2                                            -0.841572
# 3                                            -1.855477
# 4                                             0.533109
# ..                                                 ...
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
#
#      Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                  0.314066                     -21.428571
# 1                                  0.013999                     -36.363636
# 2                                 -0.841572                     -78.947368
# 3                                 -1.855477                    -129.411765
# 4                                  0.533109                     -10.526316
# ..                                      ...                            ...
# 194                                     NaN                            NaN
# 195                                     NaN                            NaN
# 196                                     NaN                            NaN
# 197                                     NaN                            NaN
# 198                                     NaN                            NaN
#
#      Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                                -1.282630                          -1.282630
# 1                                -1.760917                          -1.760917
# 2                                -0.595369                          -0.595369
# 3                                -0.945206                          -0.945206
# 4                                -1.151973                          -1.151973
# ..                                     ...                                ...
# 194                              -0.415745                          -0.189000
# 195                              -0.701419                          -0.455000
# 196                              -0.929958                          -0.669000
# 197                              -0.829972                          -0.575000
# 198                              -1.244199                          -0.958000
#
#      Subiculum_Connectivity_T_Redone  Subiculum_Connectivity_T  ...  DECLINE  \
# 0                          21.150595                 56.864683  ...      1.0
# 1                          19.702349                 52.970984  ...      1.0
# 2                          23.231614                 62.459631  ...      1.0
# 3                          22.172312                 59.611631  ...      1.0
# 4                          21.546222                 57.928350  ...      0.0
# ..                               ...                       ...  ...      ...
# 194                        19.900000                 19.900000  ...      NaN
# 195                        17.900000                 17.900000  ...      NaN
# 196                        16.300000                 16.300000  ...      NaN
# 197                        17.000000                 17.000000  ...      NaN
# 198                        14.100000                 14.100000  ...      NaN
#
#      Cognitive_Improve  Z_Scored_Cognitive_Baseline  \
# 0                   No                     1.518764
# 1                   No                     0.465551
# 2                   No                    -0.061056
# 3                   No                    -0.412127
# 4                   No                    -0.061056
# ..                 ...                          ...
# 194                Yes                          NaN
# 195                Yes                          NaN
# 196                Yes                          NaN
# 197                Yes                          NaN
# 198                Yes                          NaN
#
#      Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                        -1.518764
# 1                                        -0.465551
# 2                                         0.061056
# 3                                         0.412127
# 4                                         0.061056
# ..                                             ...
# 194                                            NaN
# 195                                            NaN
# 196                                            NaN
# 197                                            NaN
# 198                                            NaN
#
#      Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                           0.72                                 0.28
# 1                           0.48                                 0.52
# 2                           0.36                                 0.64
# 3                           0.28                                 0.72
# 4                           0.36                                 0.64
# ..                           ...                                  ...
# 194                          NaN                                  NaN
# 195                          NaN                                  NaN
# 196                          NaN                                  NaN
# 197                          NaN                                  NaN
# 198                          NaN                                  NaN
#
#      ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0         12.222658      14.493929            -1.714513            -1.227368
# 1         14.020048      15.257338            -1.155843            -1.022243
# 2         15.118727      17.376384            -0.814348            -0.452865
# 3         13.112424      15.287916            -1.437954            -1.014027
# 4         15.086568      12.951426            -0.824344            -1.641831
# ..              ...            ...                  ...                  ...
# 194             NaN            NaN                  NaN                  NaN
# 195             NaN            NaN                  NaN                  NaN
# 196             NaN            NaN                  NaN                  NaN
# 197             NaN            NaN                  NaN                  NaN
# 198             NaN            NaN                  NaN                  NaN
#
# [199 rows x 57 columns]

# %% [markdown]
# # 01 - Preprocess Your Data

# %% [markdown]
# **Handle NANs**
# - Set drop_nans=True is you would like to remove NaNs from data
# - Provide a column name or a list of column names to remove NaNs from

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T_Redone',
#        'Subiculum_Connectivity_T', 'Amnesia_Lesion_T_Map', 'Memory_Network_T',
#        'Z_Scored_Memory_Network_R', 'Memory_Network_R',
#        'Subiculum_Grey_Matter', 'Subiculum_White_Matter', 'Subiculum_CSF',
#        'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Categorical_Age_Group', 'Age_Group',
#        'Age_And_Disease', 'Age_Disease_and_Cohort', 'Age_Disease_Cohort_Stim',
#        'Age_And_Stim', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Subiculum_Group_By_24',
#        'Cognitive_Outcome', 'StimMatch', 'StimMatch24', 'Cognitive_Baseline',
#        'Cognitive_Score_1_Yr', 'Abs_Cognitive_Improve', 'IMPROVE_OR_STABLE',
#        'DECLINE_OR_STABLE', 'IMPROVE', 'DECLINE', 'Cognitive_Improve',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %%
drop_list = ['City', 'StimMatch24', 'DECLINE_OR_STABLE']

# %%
data_df = cal_palm.drop_nans_from_columns(columns_to_drop_from=drop_list)
display(data_df)
# Out:
#      subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 0        101  62.0                                 -0.392857
# 1        102  77.0                                 -0.666667
# 2        103  76.0                                 -1.447368
# 3        104  65.0                                 -2.372549
# 4        105  50.0                                 -0.192982
# ..       ...   ...                                       ...
# 194      211  58.7                                       NaN
# 195      152  69.4                                       NaN
# 196      208  79.2                                       NaN
# 197      223  71.1                                       NaN
# 198      214  76.6                                       NaN
#
#      Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                             0.314066
# 1                                             0.013999
# 2                                            -0.841572
# 3                                            -1.855477
# 4                                             0.533109
# ..                                                 ...
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
#
#      Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                  0.314066                     -21.428571
# 1                                  0.013999                     -36.363636
# 2                                 -0.841572                     -78.947368
# 3                                 -1.855477                    -129.411765
# 4                                  0.533109                     -10.526316
# ..                                      ...                            ...
# 194                                     NaN                            NaN
# 195                                     NaN                            NaN
# 196                                     NaN                            NaN
# 197                                     NaN                            NaN
# 198                                     NaN                            NaN
#
#      Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                                -1.282630                          -1.282630
# 1                                -1.760917                          -1.760917
# 2                                -0.595369                          -0.595369
# 3                                -0.945206                          -0.945206
# 4                                -1.151973                          -1.151973
# ..                                     ...                                ...
# 194                              -0.415745                          -0.189000
# 195                              -0.701419                          -0.455000
# 196                              -0.929958                          -0.669000
# 197                              -0.829972                          -0.575000
# 198                              -1.244199                          -0.958000
#
#      Subiculum_Connectivity_T_Redone  Subiculum_Connectivity_T  ...  DECLINE  \
# 0                          21.150595                 56.864683  ...      1.0
# 1                          19.702349                 52.970984  ...      1.0
# 2                          23.231614                 62.459631  ...      1.0
# 3                          22.172312                 59.611631  ...      1.0
# 4                          21.546222                 57.928350  ...      0.0
# ..                               ...                       ...  ...      ...
# 194                        19.900000                 19.900000  ...      NaN
# 195                        17.900000                 17.900000  ...      NaN
# 196                        16.300000                 16.300000  ...      NaN
# 197                        17.000000                 17.000000  ...      NaN
# 198                        14.100000                 14.100000  ...      NaN
#
#      Cognitive_Improve  Z_Scored_Cognitive_Baseline  \
# 0                   No                     1.518764
# 1                   No                     0.465551
# 2                   No                    -0.061056
# 3                   No                    -0.412127
# 4                   No                    -0.061056
# ..                 ...                          ...
# 194                Yes                          NaN
# 195                Yes                          NaN
# 196                Yes                          NaN
# 197                Yes                          NaN
# 198                Yes                          NaN
#
#      Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                        -1.518764
# 1                                        -0.465551
# 2                                         0.061056
# 3                                         0.412127
# 4                                         0.061056
# ..                                             ...
# 194                                            NaN
# 195                                            NaN
# 196                                            NaN
# 197                                            NaN
# 198                                            NaN
#
#      Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                           0.72                                 0.28
# 1                           0.48                                 0.52
# 2                           0.36                                 0.64
# 3                           0.28                                 0.72
# 4                           0.36                                 0.64
# ..                           ...                                  ...
# 194                          NaN                                  NaN
# 195                          NaN                                  NaN
# 196                          NaN                                  NaN
# 197                          NaN                                  NaN
# 198                          NaN                                  NaN
#
#      ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0         12.222658      14.493929            -1.714513            -1.227368
# 1         14.020048      15.257338            -1.155843            -1.022243
# 2         15.118727      17.376384            -0.814348            -0.452865
# 3         13.112424      15.287916            -1.437954            -1.014027
# 4         15.086568      12.951426            -0.824344            -1.641831
# ..              ...            ...                  ...                  ...
# 194             NaN            NaN                  NaN                  NaN
# 195             NaN            NaN                  NaN                  NaN
# 196             NaN            NaN                  NaN                  NaN
# 197             NaN            NaN                  NaN                  NaN
# 198             NaN            NaN                  NaN                  NaN
#
# [188 rows x 57 columns]

# %% [markdown]
# **Drop Row Based on Value of Column**
#
# Define the column, condition, and value for dropping rows
# - column = 'your_column_name'
# - condition = 'above'  # Options: 'equal', 'above', 'below'

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T_Redone',
#        'Subiculum_Connectivity_T', 'Amnesia_Lesion_T_Map', 'Memory_Network_T',
#        'Z_Scored_Memory_Network_R', 'Memory_Network_R',
#        'Subiculum_Grey_Matter', 'Subiculum_White_Matter', 'Subiculum_CSF',
#        'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Categorical_Age_Group', 'Age_Group',
#        'Age_And_Disease', 'Age_Disease_and_Cohort', 'Age_Disease_Cohort_Stim',
#        'Age_And_Stim', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Subiculum_Group_By_24',
#        'Cognitive_Outcome', 'StimMatch', 'StimMatch24', 'Cognitive_Baseline',
#        'Cognitive_Score_1_Yr', 'Abs_Cognitive_Improve', 'IMPROVE_OR_STABLE',
#        'DECLINE_OR_STABLE', 'IMPROVE', 'DECLINE', 'Cognitive_Improve',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %% [markdown]
# Set the parameters for dropping rows

# %%
column = 'City'  # The column you'd like to evaluate
condition = 'equal'  # The condition to check ('equal', 'above', 'below', 'not')
value = 'Boston' # The value to drop if found

# %%
data_df, other_df = cal_palm.drop_rows_based_on_value(column, condition, value)
display(data_df)
# Out:
#      subject   Age  Normalized_Percent_Cognitive_Improvement  \
# 0        101  62.0                                 -0.392857
# 1        102  77.0                                 -0.666667
# 2        103  76.0                                 -1.447368
# 3        104  65.0                                 -2.372549
# 4        105  50.0                                 -0.192982
# ..       ...   ...                                       ...
# 194      211  58.7                                       NaN
# 195      152  69.4                                       NaN
# 196      208  79.2                                       NaN
# 197      223  71.1                                       NaN
# 198      214  76.6                                       NaN
#
#      Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                             0.314066
# 1                                             0.013999
# 2                                            -0.841572
# 3                                            -1.855477
# 4                                             0.533109
# ..                                                 ...
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
#
#      Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                  0.314066                     -21.428571
# 1                                  0.013999                     -36.363636
# 2                                 -0.841572                     -78.947368
# 3                                 -1.855477                    -129.411765
# 4                                  0.533109                     -10.526316
# ..                                      ...                            ...
# 194                                     NaN                            NaN
# 195                                     NaN                            NaN
# 196                                     NaN                            NaN
# 197                                     NaN                            NaN
# 198                                     NaN                            NaN
#
#      Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                                -1.282630                          -1.282630
# 1                                -1.760917                          -1.760917
# 2                                -0.595369                          -0.595369
# 3                                -0.945206                          -0.945206
# 4                                -1.151973                          -1.151973
# ..                                     ...                                ...
# 194                              -0.415745                          -0.189000
# 195                              -0.701419                          -0.455000
# 196                              -0.929958                          -0.669000
# 197                              -0.829972                          -0.575000
# 198                              -1.244199                          -0.958000
#
#      Subiculum_Connectivity_T_Redone  Subiculum_Connectivity_T  ...  DECLINE  \
# 0                          21.150595                 56.864683  ...      1.0
# 1                          19.702349                 52.970984  ...      1.0
# 2                          23.231614                 62.459631  ...      1.0
# 3                          22.172312                 59.611631  ...      1.0
# 4                          21.546222                 57.928350  ...      0.0
# ..                               ...                       ...  ...      ...
# 194                        19.900000                 19.900000  ...      NaN
# 195                        17.900000                 17.900000  ...      NaN
# 196                        16.300000                 16.300000  ...      NaN
# 197                        17.000000                 17.000000  ...      NaN
# 198                        14.100000                 14.100000  ...      NaN
#
#      Cognitive_Improve  Z_Scored_Cognitive_Baseline  \
# 0                   No                     1.518764
# 1                   No                     0.465551
# 2                   No                    -0.061056
# 3                   No                    -0.412127
# 4                   No                    -0.061056
# ..                 ...                          ...
# 194                Yes                          NaN
# 195                Yes                          NaN
# 196                Yes                          NaN
# 197                Yes                          NaN
# 198                Yes                          NaN
#
#      Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                        -1.518764
# 1                                        -0.465551
# 2                                         0.061056
# 3                                         0.412127
# 4                                         0.061056
# ..                                             ...
# 194                                            NaN
# 195                                            NaN
# 196                                            NaN
# 197                                            NaN
# 198                                            NaN
#
#      Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                           0.72                                 0.28
# 1                           0.48                                 0.52
# 2                           0.36                                 0.64
# 3                           0.28                                 0.72
# 4                           0.36                                 0.64
# ..                           ...                                  ...
# 194                          NaN                                  NaN
# 195                          NaN                                  NaN
# 196                          NaN                                  NaN
# 197                          NaN                                  NaN
# 198                          NaN                                  NaN
#
#      ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0         12.222658      14.493929            -1.714513            -1.227368
# 1         14.020048      15.257338            -1.155843            -1.022243
# 2         15.118727      17.376384            -0.814348            -0.452865
# 3         13.112424      15.287916            -1.437954            -1.014027
# 4         15.086568      12.951426            -0.824344            -1.641831
# ..              ...            ...                  ...                  ...
# 194             NaN            NaN                  NaN                  NaN
# 195             NaN            NaN                  NaN                  NaN
# 196             NaN            NaN                  NaN                  NaN
# 197             NaN            NaN                  NaN                  NaN
# 198             NaN            NaN                  NaN                  NaN
#
# [112 rows x 57 columns]

# %% [markdown]
# **Standardize Data**
# - Enter Columns you Don't want to standardize into a list

# %%
# Remove anything you don't want to standardize
cols_not_to_standardize = None # ['Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group', 'Z_Scored_Subiculum_T_By_Origin_Group_'] #['Age']

# %%
data_df = cal_palm.standardize_columns(cols_not_to_standardize)
data_df
# Out:
# Unable to standardize column Disease
# Unable to standardize column City
# Unable to standardize column Age_Group
# Unable to standardize column Age_And_Disease
# Unable to standardize column Age_Disease_and_Cohort
# Unable to standardize column Age_Disease_Cohort_Stim
# Unable to standardize column Age_And_Stim
# Unable to standardize column Subiculum_Group_By_Z_Score_Sign
# Unable to standardize column Subiculum_Group_By_Inflection_Point
# Unable to standardize column Subiculum_Group_By_24
# Unable to standardize column Cognitive_Outcome
# Unable to standardize column StimMatch
# Unable to standardize column StimMatch24
# Unable to standardize column Cognitive_Baseline
# Unable to standardize column Cognitive_Improve
#       subject       Age  Normalized_Percent_Cognitive_Improvement  \
# 0    0.010788 -0.228368                                  0.213001
# 1    0.024902  1.492097                                 -0.052029
# 2    0.039017  1.377399                                 -0.807696
# 3    0.053132  0.115725                                 -1.703210
# 4    0.067246 -1.604740                                  0.406466
# ..        ...       ...                                       ...
# 194  1.563401 -0.606871                                       NaN
# 195  0.730636  0.620395                                       NaN
# 196  1.521057  1.744432                                       NaN
# 197  1.732777  0.815381                                       NaN
# 198  1.605745  1.446218                                       NaN
#
#      Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group  \
# 0                                             0.232369
# 1                                            -0.090968
# 2                                            -1.012887
# 3                                            -2.105418
# 4                                             0.468398
# ..                                                 ...
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
#
#      Z_Scored_Percent_Cognitive_Improvement  Percent_Cognitive_Improvement  \
# 0                                  0.324379                      -0.069554
# 1                                  0.020493                      -0.453739
# 2                                 -0.845965                      -1.549149
# 3                                 -1.872771                      -2.847279
# 4                                  0.546209                       0.210892
# ..                                      ...                            ...
# 194                                     NaN                            NaN
# 195                                     NaN                            NaN
# 196                                     NaN                            NaN
# 197                                     NaN                            NaN
# 198                                     NaN                            NaN
#
#      Z_Scored_Subiculum_T_By_Origin_Group_  Z_Scored_Subiculum_Connectivity_T  \
# 0                                -1.327402                          -1.345266
# 1                                -1.843167                          -1.850344
# 2                                -0.586286                          -0.619507
# 3                                -0.963537                          -0.988940
# 4                                -1.186507                          -1.207290
# ..                                     ...                                ...
# 194                              -0.392587                          -0.190375
# 195                              -0.700647                          -0.471275
# 196                              -0.947094                          -0.697263
# 197                              -0.839274                          -0.597997
# 198                              -1.285960                          -1.002451
#
#      Subiculum_Connectivity_T_Redone  Subiculum_Connectivity_T  ...   DECLINE  \
# 0                          -0.364894                  0.889699  ...  1.381699
# 1                          -0.625154                  0.714702  ...  1.381699
# 2                           0.009081                  1.141157  ...  1.381699
# 3                          -0.181284                  1.013157  ...  1.381699
# 4                          -0.293797                  0.937504  ... -0.723747
# ..                               ...                       ...  ...       ...
# 194                        -0.589635                 -0.771632  ...       NaN
# 195                        -0.949050                 -0.861520  ...       NaN
# 196                        -1.236581                 -0.933430  ...       NaN
# 197                        -1.110786                 -0.901969  ...       NaN
# 198                        -1.631938                 -1.032306  ...       NaN
#
#      Cognitive_Improve  Z_Scored_Cognitive_Baseline  \
# 0                   No                     1.538618
# 1                   No                     0.471637
# 2                   No                    -0.061854
# 3                   No                    -0.417515
# 4                   No                    -0.061854
# ..                 ...                          ...
# 194                Yes                          NaN
# 195                Yes                          NaN
# 196                Yes                          NaN
# 197                Yes                          NaN
# 198                Yes                          NaN
#
#      Z_Scored_Cognitive_Baseline__Lower_is_Better_  \
# 0                                        -1.538618
# 1                                        -0.471637
# 2                                         0.061854
# 3                                         0.417515
# 4                                         0.061854
# ..                                             ...
# 194                                            NaN
# 195                                            NaN
# 196                                            NaN
# 197                                            NaN
# 198                                            NaN
#
#      Min_Max_Normalized_Baseline  MinMaxNormBaseline_Higher_is_Better  \
# 0                       0.776395                            -1.389067
# 1                      -0.038526                            -0.463187
# 2                      -0.445986                            -0.000247
# 3                      -0.717627                             0.308379
# 4                      -0.445986                            -0.000247
# ..                           ...                                  ...
# 194                          NaN                                  NaN
# 195                          NaN                                  NaN
# 196                          NaN                                  NaN
# 197                          NaN                                  NaN
# 198                          NaN                                  NaN
#
#      ROI_to_Alz_Max  ROI_to_PD_Max  Standardzied_AD_Max  Standardized_PD_Max
# 0         -1.059413      -0.660414            -1.736926            -1.243412
# 1         -0.659247      -0.521521            -1.170953            -1.035606
# 2         -0.414640      -0.135985            -0.824994            -0.458785
# 3         -0.861318      -0.515958            -1.456751            -1.027283
# 4         -0.421800      -0.941055            -0.835120            -1.663294
# ..              ...            ...                  ...                  ...
# 194             NaN            NaN                  NaN                  NaN
# 195             NaN            NaN                  NaN                  NaN
# 196             NaN            NaN                  NaN                  NaN
# 197             NaN            NaN                  NaN                  NaN
# 198             NaN            NaN                  NaN                  NaN
#
# [140 rows x 57 columns]

# %%
# for col in data_df.columns:
#     if 'CSF' and 'eh' not in col:
#         data_df[col] = data_df[col] * -1

# %% [markdown]
# # 02 - Simple Odds Ratio

# %%
import pandas as pd
import numpy as np

def calculate_contingency_values(df, condition_column, outcome_column, condition_success, outcome_success):
    """
    Calculates the values of a, b, c, and d for a 2x2 contingency table from a DataFrame.

    Parameters:
    df (pd.DataFrame): The input data frame.
    condition_column (str): The name of the column that contains the condition.
    outcome_column (str): The name of the column that contains the outcome.
    condition_success (any): The value in the condition column that indicates success.
    outcome_success (any): The value in the outcome column that indicates success.

    Returns:
    tuple: A tuple containing the values of a, b, c, and d.
    """
    # Patients who meet the condition
    condition_positive = df[condition_column] == condition_success

    # Patients who don't meet the condition
    condition_negative = ~condition_positive

    # Patients who improved
    outcome_positive = df[outcome_column] == outcome_success

    # Patients who did not improve
    outcome_negative = ~outcome_positive

    # Count values for a, b, c, d
    a = df[condition_positive & outcome_positive].shape[0]
    b = df[condition_positive & outcome_negative].shape[0]
    c = df[condition_negative & outcome_positive].shape[0]
    d = df[condition_negative & outcome_negative].shape[0]

    return a, b, c, d

# Example usage:
# df = pd.DataFrame({'Condition': [...], 'Outcome': [...]})
# a, b, c, d = calculate_contingency_values(df, 'Condition', 'Outcome', 'ConditionSuccessValue', 'OutcomeSuccessValue')
# print(a, b, c, d)

def calculate_odds_ratio(a, b, c, d):
    """
    Calculates the odds ratio from a 2x2 contingency table.
    
    Parameters:
    a (int): Number of patients who meet the condition and improved.
    b (int): Number of patients who meet the condition and did not improve.
    c (int): Number of patients who do not meet the condition but improved.
    d (int): Number of patients who do not meet the condition and did not improve.
    
    Returns:
    float: The odds ratio.
    """
    try:
        odds_ratio = (a * d) / (b * c)
        print("Odds ratio: ", odds_ratio)
        print("Log-odds ratio: ", np.log(odds_ratio))
        return odds_ratio
    except ZeroDivisionError:
        return "Cannot calculate odds ratio due to division by zero."

# Example usage:
# a, b, c, d = 10, 20, 30, 40
# print(calculate_odds_ratio(a, b, c, d)

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T_Redone',
#        'Subiculum_Connectivity_T', 'Amnesia_Lesion_T_Map', 'Memory_Network_T',
#        'Z_Scored_Memory_Network_R', 'Memory_Network_R',
#        'Subiculum_Grey_Matter', 'Subiculum_White_Matter', 'Subiculum_CSF',
#        'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Categorical_Age_Group', 'Age_Group',
#        'Age_And_Disease', 'Age_Disease_and_Cohort', 'Age_Disease_Cohort_Stim',
#        'Age_And_Stim', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Subiculum_Group_By_24',
#        'Cognitive_Outcome', 'StimMatch', 'StimMatch24', 'Cognitive_Baseline',
#        'Cognitive_Score_1_Yr', 'Abs_Cognitive_Improve', 'IMPROVE_OR_STABLE',
#        'DECLINE_OR_STABLE', 'IMPROVE', 'DECLINE', 'Cognitive_Improve',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %%
outcome = 'IMPROVE'
successful_outcome = True
treatment =  'StimMatch'
treatment_success = 'Match'

# %%
a, b, c, d = calculate_contingency_values(data_df, condition_column=treatment, outcome_column=outcome, condition_success=treatment_success, outcome_success=successful_outcome)
odds_ratio = calculate_odds_ratio(a, b, c, d)
# Out:
# Odds ratio:  0.36507936507936506
# Log-odds ratio:  -1.0076405104623831

# %% [markdown]
# # 03 - Forest Plot
# - This code allows you to adjust for covariates.
# - Instead of a normal ad/cb odds ratio calculation, this uses logistic regression.

# %%
data_df.columns
# Out:
# Index(['subject', 'Age', 'Normalized_Percent_Cognitive_Improvement',
#        'Z_Scored_Percent_Cognitive_Improvement_By_Origin_Group',
#        'Z_Scored_Percent_Cognitive_Improvement',
#        'Percent_Cognitive_Improvement',
#        'Z_Scored_Subiculum_T_By_Origin_Group_',
#        'Z_Scored_Subiculum_Connectivity_T', 'Subiculum_Connectivity_T_Redone',
#        'Subiculum_Connectivity_T', 'Amnesia_Lesion_T_Map', 'Memory_Network_T',
#        'Z_Scored_Memory_Network_R', 'Memory_Network_R',
#        'Subiculum_Grey_Matter', 'Subiculum_White_Matter', 'Subiculum_CSF',
#        'Subiculum_Total', 'Standardized_Age',
#        'Standardized_Percent_Improvement',
#        'Standardized_Subiculum_Connectivity',
#        'Standardized_Subiculum_Grey_Matter',
#        'Standardized_Subiculum_White_Matter', 'Standardized_Subiculum_CSF',
#        'Standardized_Subiculum_Total', 'Disease', 'Cohort', 'City',
#        'Inclusion_Cohort', 'Categorical_Age_Group', 'Age_Group',
#        'Age_And_Disease', 'Age_Disease_and_Cohort', 'Age_Disease_Cohort_Stim',
#        'Age_And_Stim', 'Subiculum_Group_By_Z_Score_Sign',
#        'Subiculum_Group_By_Inflection_Point', 'Subiculum_Group_By_24',
#        'Cognitive_Outcome', 'StimMatch', 'StimMatch24', 'Cognitive_Baseline',
#        'Cognitive_Score_1_Yr', 'Abs_Cognitive_Improve', 'IMPROVE_OR_STABLE',
#        'DECLINE_OR_STABLE', 'IMPROVE', 'DECLINE', 'Cognitive_Improve',
#        'Z_Scored_Cognitive_Baseline',
#        'Z_Scored_Cognitive_Baseline__Lower_is_Better_',
#        'Min_Max_Normalized_Baseline', 'MinMaxNormBaseline_Higher_is_Better',
#        'ROI_to_Alz_Max', 'ROI_to_PD_Max', 'Standardzied_AD_Max',
#        'Standardized_PD_Max'],
#       dtype='object')

# %% [markdown]
# - Treatment is the string matching a 'positive' treatment.

# %%
outcome = 'DECLINE'
predictor = 'StimMatch'
cohorts = 'City'
covariate_list = None
treatment = None

# %%
from calvin_utils.statistical_utils.forest_plots import OddsRatioForestPlot
# Create an instance of the LogisticOddsRatioPlot class with covariates
plot = OddsRatioForestPlot(data_df, outcome_col=outcome, predictor_col=predictor,
                             category_col=cohorts, treatment=treatment, covariates=None,
                             table=False, log_odds=True, out_dir=out_dir)

# Run the plotting process
plot.run()
plot.data_for_plot
# Out:
# Running formula:  DECLINE ~ StimMatch
# Optimization terminated successfully.
#          Current function value: 0.629192
#          Iterations 5
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.454878
#          Iterations: 35
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 8
#       3 plot = OddsRatioForestPlot(data_df, outcome_col=outcome, predictor_col=predictor,
#       4                              category_col=cohorts, treatment=treatment, covariates=None,
#       5                              table=False, log_odds=True, out_dir=out_dir)
#       7 # Run the plotting process
# ----> 8 plot.run()
#       9 plot.data_for_plot
#
# File ~/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/Software/Research/nimlab/calvin_utils/calvin_utils/statistical_utils/forest_plots.py:261, in run(self)
#     257 """
#     258 Orchestrator method to calculate odds ratios and generate the forest plot.
#     259 """
#     260 self.create_dummy_variables()
# --> 261 self.construct_formula()
#     262 self.calculate_odds_ratios()
#     263 # self.calculate_overall_odds()
#
# File ~/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/Software/Research/nimlab/calvin_utils/calvin_utils/statistical_utils/forest_plots.py:242, in calculate_odds_ratios(self)
#     240 # Generate Each Group's Odds Ratio
#     241 results = []
# --> 242 for category in self.data[self.category_col].unique():
#     243     logit_model = self.run_logistic_regression(category)
#     245     odds_ratio, ci_low, ci_high, pval = self.get_coef_and_ci(logit_model)
#
# File ~/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/Software/Research/nimlab/calvin_utils/calvin_utils/statistical_utils/forest_plots.py:214, in OddsRatioForestPlot.run_logistic_regression(self, category, debug)
#     212     print(data_subset[self.outcome_col])
#     213 try:
# --> 214     logit_model = smf.logit(self.formula, data=data_subset).fit()
#     215 except sm.tools.sm_exceptions.PerfectSeparationError as e:
#     216     backup_formula = self.formula + " - 1"
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/base/model.py:226, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     220         design_info = design_info.subset(cols)
#     222 kwargs.update({'missing_idx': missing_idx,
#     223                'missing': missing,
#     224                'formula': formula,  # attach formula for unpckling
#     225                'design_info': design_info})
# --> 226 mod = cls(endog, exog, *args, **kwargs)
#     227 mod.formula = formula
#     228 # since we got a dataframe, attach the original
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:462, in BinaryModel.__init__(self, endog, exog, check_rank, **kwargs)
#     459 def __init__(self, endog, exog, check_rank=True, **kwargs):
#     460     # unconditional check, requires no extra kwargs added by subclasses
#     461     self._check_kwargs(kwargs)
# --> 462     super().__init__(endog, exog, check_rank, **kwargs)
#     463     if not issubclass(self.__class__, MultinomialModel):
#     464         if not np.all((self.endog >= 0) & (self.endog <= 1)):
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:178, in DiscreteModel.__init__(self, endog, exog, check_rank, **kwargs)
#     176 def __init__(self, endog, exog, check_rank=True, **kwargs):
#     177     self._check_rank = check_rank
# --> 178     super().__init__(endog, exog, **kwargs)
#     179     self.raise_on_perfect_prediction = True
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/base/model.py:267, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     266 def __init__(self, endog, exog=None, **kwargs):
# --> 267     super().__init__(endog, exog, **kwargs)
#     268     self.initialize()
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/base/model.py:92, in Model.__init__(self, endog, exog, **kwargs)
#      90 missing = kwargs.pop('missing', 'none')
#      91 hasconst = kwargs.pop('hasconst', None)
# ---> 92 self.data = self._handle_data(endog, exog, missing, hasconst,
#      93                               **kwargs)
#      94 self.k_constant = self.data.k_constant
#      95 self.exog = self.data.exog
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/base/model.py:132, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     131 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133     # kwargs arrays could have changed, easier to just attach here
#     134     for key in kwargs:
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/base/data.py:700, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     697     exog = np.asarray(exog)
#     699 klass = handle_data_class_factory(endog, exog)
# --> 700 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     701              **kwargs)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/base/data.py:88, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      86 self.const_idx = None
#      87 self.k_constant = 0
# ---> 88 self._handle_constant(hasconst)
#      89 self._check_integrity()
#      90 self._cache = {}
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/statsmodels/base/data.py:132, in ModelData._handle_constant(self, hasconst)
#     129 else:
#     130     # detect where the constant is
#     131     check_implicit = False
# --> 132     exog_max = np.max(self.exog, axis=0)
#     133     if not np.isfinite(exog_max).all():
#     134         raise MissingDataError('exog contains inf or nans')
#
# File <__array_function__ internals>:180, in amax(*args, **kwargs)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2793, in amax(a, axis, out, keepdims, initial, where)
#    2677 @array_function_dispatch(_amax_dispatcher)
#    2678 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2679          where=np._NoValue):
#    2680     """
#    2681     Return the maximum of an array or maximum along an axis.
#    2682
#    (...)
#    2791     5
#    2792     """
# -> 2793     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2794                           keepdims=keepdims, initial=initial, where=where)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity
