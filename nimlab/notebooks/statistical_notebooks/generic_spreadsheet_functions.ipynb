# %%
import pandas as pd
import os
import numpy as np

# Gather the CSV
spreadsheet_dir = '/Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/study_metadata/all_performances.xlsx'

#----------------------------------------------------------------Don't touch--------------------------------------------------------
# out_dir = spreadsheet_dir.split('.')[0] + '_analysis'
out_dir = '/Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring'

if os.path.exists(out_dir) != True:
    os.makedirs(out_dir)
    print('Made directory', out_dir)

# %% [markdown]
# # Import Relevant Information

# %%
# User Input
## Input the sheet you would like to use below
sheet_name = 'study_results'

if os.path.basename(spreadsheet_dir).split('.')[1] == 'csv':
    df_1 = pd.read_csv(spreadsheet_dir)
else:
    df_1 = pd.read_excel(spreadsheet_dir, sheet_name=sheet_name)
display(df_1)
# Out:
#      Measurement  Cohort  Randomization Group  Age Cognitive Status  \
# 0     patient_11       1                  2.0   50           Intact
# 1     patient_15       1                  1.0   42              MCI
# 2     patient_17       1                  1.0   35              MCI
# 3     patient_19       1                  1.0   71              MCI
# 4     patient_24       1                  2.0   48           Intact
# 5     patient_25       1                  1.0   53              MCI
# 6     patient_26       1                  1.0   49              MCI
# 7     patient_30       1                  2.0   33           Intact
# 8     patient_33       1                  2.0   36              MCI
# 9     patient_38       1                  2.0   27              MCI
# 10    patient_40       1                  1.0   51           intact
# 11    patient_42       1                  1.0   46           intact
# 12    patient_47       1                  1.0   37              MCI
# 13   patient_108       2                  1.0   35           intact
# 14   patient_109       2                  1.0   41              MCI
# 15   patient_106       2                  1.0   39           Intact
# 16   patient_110       2                  2.0   39           intact
# 17   patient_104       2                  1.0   63              MCI
# 18   patient_111       2                  1.0   61              MCI
# 19   patient_103       2                  2.0   43              MCI
# 20   patient_112       2                  2.0   83           Intact
# 21   patient_102       2                  2.0   39              MCI
# 22   patient_103       2                  2.0   43              MCI
# 23   patient_114       2                  2.0   35           Intact
# 24   patient_107       2                  1.0   54              MCI
# 25   patient_115       2                  1.0   35           intact
# 26   patient_119       4                  2.0   37           intact
# 27   patient_121       4                  2.0   36           intact
# 28   patient_122       4                  1.0   35           intact
# 29   patient_123       4                  2.0   35           intact
# 30   patient_126       4                  1.0   37           intact
# 31   patient_128       4                  2.0   78           intact
# 32   patient_130       4                  1.0   47           intact
# 33   patient_131       4                  1.0   49           intact
# 34   patient_132       4                  2.0   45           intact
# 35  patient_1020       3                  NaN   41           intact
# 36  patient_1021       3                  NaN   33           intact
# 37  patient_1003       3                  NaN   65           intact
# 38  patient_1004       3                  NaN   70           intact
# 39  patient_1005       3                  NaN   82           intact
# 40  patient_1006       3                  NaN   80           intact
# 41  patient_1007       3                  NaN   62           intact
# 42  patient_1008       3                  NaN   52           intact
# 43  patient_1009       3                  NaN   49              MCI
# 44  patient_1010       3                  NaN   66              MCI
# 45  patient_1011       3                  NaN   71           intact
#
#     Question_2  Question_3  Question_4  Question_5  Question_6  ...  \
# 0           10           3           5           3          13  ...
# 1           10           3           1           2           6  ...
# 2           10           3           2           3           5  ...
# 3            8           3           5           3           7  ...
# 4            9           3           5           3          11  ...
# 5           10           3           1           3           7  ...
# 6           10           3           5           2          12  ...
# 7           10           3           5           3          10  ...
# 8           10           3           5           3           8  ...
# 9            9           3           4           3          10  ...
# 10           9           3           5           3          10  ...
# 11          10           3           5           3          10  ...
# 12           9           3           4           3          14  ...
# 13          10           3           5           3           8  ...
# 14          10           3           5           3           9  ...
# 15           9           3           0           3          11  ...
# 16          10           3           3           3           9  ...
# 17          10           3           0           2           6  ...
# 18           6           3           0           3           4  ...
# 19           9           3           3           1           0  ...
# 20           9           2           5           2           4  ...
# 21           8           2           5           0           4  ...
# 22           9           3           4           1           6  ...
# 23          10           3           5           3          11  ...
# 24          10           3           3           1           5  ...
# 25          10           3           5           3          14  ...
# 26          10           3           5           3          13  ...
# 27           9           3           5           3          14  ...
# 28          10           3           5           3          14  ...
# 29          10           3           5           3          14  ...
# 30          10           3           5           3          14  ...
# 31          10           3           5           3          14  ...
# 32          10           3           5           3          14  ...
# 33          10           3           5           3          14  ...
# 34          10           2           4           2          13  ...
# 35          10           3           5           3          14  ...
# 36          10           3           5           3          14  ...
# 37          10           1           1           1          13  ...
# 38          10           3           3           1          13  ...
# 39          10           1           5           3          12  ...
# 40          10           0           5           1          12  ...
# 41          10           1           5           0          13  ...
# 42          10           1           3           1          13  ...
# 43          10           0           1           0           8  ...
# 44          10           1           5           1           7  ...
# 45          10           1           4           3          14  ...
#
#     Expert Algorithm Equivalent  Subjective Complaint  Attention Complaint  \
# 0                            33                  None                  NaN
# 1                            26                  None                  NaN
# 2                            30                   Yes                  NaN
# 3                            32                   Yes                  NaN
# 4                            32                   Yes                  NaN
# 5                            28                   Yes                  NaN
# 6                            31                   Yes                  NaN
# 7                            32                   Yes                  Yes
# 8                            32                   Yes                  NaN
# 9                            24                   Yes                  NaN
# 10                           26                   Yes                  NaN
# 11                           31                   Yes                  NaN
# 12                           30                    No                  NaN
# 13                           33                   NaN                  NaN
# 14                           29                   NaN                  NaN
# 15                           30                   NaN                  NaN
# 16                           29                   NaN                  NaN
# 17                           26                   NaN                  NaN
# 18                           21                   NaN                  NaN
# 19                           30                   NaN                  NaN
# 20                           30                   NaN                  NaN
# 21                           26                   NaN                  NaN
# 22                           30                   NaN                  NaN
# 23                           32                   NaN                  NaN
# 24                           26                   NaN                  NaN
# 25                           32                   NaN                  NaN
# 26                           33                   NaN                  NaN
# 27                           31                   NaN                  NaN
# 28                           31                   NaN                  NaN
# 29                           32                   NaN                  NaN
# 30                           33                   NaN                  NaN
# 31                           31                   NaN                  NaN
# 32                           31                   NaN                  NaN
# 33                           31                   NaN                  NaN
# 34                           30                   NaN                  NaN
# 35                            0                   NaN                  NaN
# 36                            0                   NaN                  NaN
# 37                            0                   NaN                  NaN
# 38                            0                   NaN                  NaN
# 39                            0                   NaN                  NaN
# 40                            0                   NaN                  NaN
# 41                            0                   NaN                  NaN
# 42                            0                   NaN                  NaN
# 43                            0                   NaN                  NaN
# 44                            0                   NaN                  NaN
# 45                            0                   NaN                  NaN
#
#     Memory Complaint  Fluency Complaint  Language Complaint  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                Yes                NaN                 Yes
# 3                Yes                NaN                 Yes
# 4                NaN                NaN                 Yes
# 5                Yes                NaN                 NaN
# 6                NaN                NaN                 Yes
# 7                Yes                NaN                 Yes
# 8                Yes                NaN                 NaN
# 9                Yes                NaN                 NaN
# 10               Yes                NaN                 Yes
# 11               Yes                NaN                 Yes
# 12               NaN                NaN                 NaN
# 13               NaN                NaN                 NaN
# 14               NaN                NaN                 NaN
# 15               NaN                NaN                 NaN
# 16               NaN                NaN                 NaN
# 17               NaN                NaN                 NaN
# 18               NaN                NaN                 NaN
# 19               NaN                NaN                 NaN
# 20               NaN                NaN                 NaN
# 21               NaN                NaN                 NaN
# 22               NaN                NaN                 NaN
# 23               NaN                NaN                 NaN
# 24               NaN                NaN                 NaN
# 25               NaN                NaN                 NaN
# 26               NaN                NaN                 NaN
# 27               NaN                NaN                 NaN
# 28               NaN                NaN                 NaN
# 29               NaN                NaN                 NaN
# 30               NaN                NaN                 NaN
# 31               NaN                NaN                 NaN
# 32               NaN                NaN                 NaN
# 33               NaN                NaN                 NaN
# 34               NaN                NaN                 NaN
# 35               NaN                NaN                 NaN
# 36               NaN                NaN                 NaN
# 37               NaN                NaN                 NaN
# 38               NaN                NaN                 NaN
# 39               NaN                NaN                 NaN
# 40               NaN                NaN                 NaN
# 41               NaN                NaN                 NaN
# 42               NaN                NaN                 NaN
# 43               NaN                NaN                 NaN
# 44               NaN                NaN                 NaN
# 45               NaN                NaN                 NaN
#
#     Visuospatial Complaint  Impaired on ACE3  iADL Impaired  ADL Impaired
# 0                      NaN                No           None          None
# 1                      NaN               Yes           None          None
# 2                      NaN               Yes           None          None
# 3                      NaN               Yes           None          None
# 4                      NaN                No           None          None
# 5                      NaN               Yes           None          None
# 6                      NaN               Yes           None          None
# 7                      NaN                No           None          None
# 8                      NaN               Yes           None          None
# 9                      NaN               Yes           None          None
# 10                     NaN                No           None          None
# 11                     NaN                No           None          None
# 12                     NaN                No           None          None
# 13                     NaN               NaN            NaN           NaN
# 14                     NaN               NaN            NaN           NaN
# 15                     NaN               NaN            NaN           NaN
# 16                     NaN               NaN            NaN           NaN
# 17                     NaN               NaN            NaN           NaN
# 18                     NaN               NaN            NaN           NaN
# 19                     NaN               NaN            NaN           NaN
# 20                     NaN               NaN            NaN           NaN
# 21                     NaN               NaN            NaN           NaN
# 22                     NaN               NaN            NaN           NaN
# 23                     NaN               NaN            NaN           NaN
# 24                     NaN               NaN            NaN           NaN
# 25                     NaN               NaN            NaN           NaN
# 26                     NaN               NaN            NaN           NaN
# 27                     NaN               NaN            NaN           NaN
# 28                     NaN               NaN            NaN           NaN
# 29                     NaN               NaN            NaN           NaN
# 30                     NaN               NaN            NaN           NaN
# 31                     NaN               NaN            NaN           NaN
# 32                     NaN               NaN            NaN           NaN
# 33                     NaN               NaN            NaN           NaN
# 34                     NaN               NaN            NaN           NaN
# 35                     NaN               NaN            NaN           NaN
# 36                     NaN               NaN            NaN           NaN
# 37                     NaN               NaN            NaN           NaN
# 38                     NaN               NaN            NaN           NaN
# 39                     NaN               NaN            NaN           NaN
# 40                     NaN               NaN            NaN           NaN
# 41                     NaN               NaN            NaN           NaN
# 42                     NaN               NaN            NaN           NaN
# 43                     NaN               NaN            NaN           NaN
# 44                     NaN               NaN            NaN           NaN
# 45                     NaN               NaN            NaN           NaN
#
# [46 rows x 73 columns]

# %%
#always run this
# trim the dataframe as needed
row_to_stop_at = None
col_to_stop_at = None

#----------------------------------------------------------------Do Not Touch----------------------------------------------------------------
if row_to_stop_at is not None:
    pass
else:
    row_to_stop_at = pd.IndexSlice[:]
    
if col_to_stop_at is not None:
    pass
else:
    col_to_stop_at = pd.IndexSlice[:]
    
df_1 = df_1.loc[row_to_stop_at, col_to_stop_at].copy()
df_1
# Out:
#      Measurement  Cohort  Randomization Group  Age Cognitive Status  \
# 0     patient_11       1                  2.0   50           Intact
# 1     patient_15       1                  1.0   42              MCI
# 2     patient_17       1                  1.0   35              MCI
# 3     patient_19       1                  1.0   71              MCI
# 4     patient_24       1                  2.0   48           Intact
# 5     patient_25       1                  1.0   53              MCI
# 6     patient_26       1                  1.0   49              MCI
# 7     patient_30       1                  2.0   33           Intact
# 8     patient_33       1                  2.0   36              MCI
# 9     patient_38       1                  2.0   27              MCI
# 10    patient_40       1                  1.0   51           intact
# 11    patient_42       1                  1.0   46           intact
# 12    patient_47       1                  1.0   37              MCI
# 13   patient_108       2                  1.0   35           intact
# 14   patient_109       2                  1.0   41              MCI
# 15   patient_106       2                  1.0   39           Intact
# 16   patient_110       2                  2.0   39           intact
# 17   patient_104       2                  1.0   63              MCI
# 18   patient_111       2                  1.0   61              MCI
# 19   patient_103       2                  2.0   43              MCI
# 20   patient_112       2                  2.0   83           Intact
# 21   patient_102       2                  2.0   39              MCI
# 22   patient_103       2                  2.0   43              MCI
# 23   patient_114       2                  2.0   35           Intact
# 24   patient_107       2                  1.0   54              MCI
# 25   patient_115       2                  1.0   35           intact
# 26   patient_119       4                  2.0   37           intact
# 27   patient_121       4                  2.0   36           intact
# 28   patient_122       4                  1.0   35           intact
# 29   patient_123       4                  2.0   35           intact
# 30   patient_126       4                  1.0   37           intact
# 31   patient_128       4                  2.0   78           intact
# 32   patient_130       4                  1.0   47           intact
# 33   patient_131       4                  1.0   49           intact
# 34   patient_132       4                  2.0   45           intact
# 35  patient_1020       3                  NaN   41           intact
# 36  patient_1021       3                  NaN   33           intact
# 37  patient_1003       3                  NaN   65           intact
# 38  patient_1004       3                  NaN   70           intact
# 39  patient_1005       3                  NaN   82           intact
# 40  patient_1006       3                  NaN   80           intact
# 41  patient_1007       3                  NaN   62           intact
# 42  patient_1008       3                  NaN   52           intact
# 43  patient_1009       3                  NaN   49              MCI
# 44  patient_1010       3                  NaN   66              MCI
# 45  patient_1011       3                  NaN   71           intact
#
#     Question_2  Question_3  Question_4  Question_5  Question_6  ...  \
# 0           10           3           5           3          13  ...
# 1           10           3           1           2           6  ...
# 2           10           3           2           3           5  ...
# 3            8           3           5           3           7  ...
# 4            9           3           5           3          11  ...
# 5           10           3           1           3           7  ...
# 6           10           3           5           2          12  ...
# 7           10           3           5           3          10  ...
# 8           10           3           5           3           8  ...
# 9            9           3           4           3          10  ...
# 10           9           3           5           3          10  ...
# 11          10           3           5           3          10  ...
# 12           9           3           4           3          14  ...
# 13          10           3           5           3           8  ...
# 14          10           3           5           3           9  ...
# 15           9           3           0           3          11  ...
# 16          10           3           3           3           9  ...
# 17          10           3           0           2           6  ...
# 18           6           3           0           3           4  ...
# 19           9           3           3           1           0  ...
# 20           9           2           5           2           4  ...
# 21           8           2           5           0           4  ...
# 22           9           3           4           1           6  ...
# 23          10           3           5           3          11  ...
# 24          10           3           3           1           5  ...
# 25          10           3           5           3          14  ...
# 26          10           3           5           3          13  ...
# 27           9           3           5           3          14  ...
# 28          10           3           5           3          14  ...
# 29          10           3           5           3          14  ...
# 30          10           3           5           3          14  ...
# 31          10           3           5           3          14  ...
# 32          10           3           5           3          14  ...
# 33          10           3           5           3          14  ...
# 34          10           2           4           2          13  ...
# 35          10           3           5           3          14  ...
# 36          10           3           5           3          14  ...
# 37          10           1           1           1          13  ...
# 38          10           3           3           1          13  ...
# 39          10           1           5           3          12  ...
# 40          10           0           5           1          12  ...
# 41          10           1           5           0          13  ...
# 42          10           1           3           1          13  ...
# 43          10           0           1           0           8  ...
# 44          10           1           5           1           7  ...
# 45          10           1           4           3          14  ...
#
#     Expert Algorithm Equivalent  Subjective Complaint  Attention Complaint  \
# 0                            33                  None                  NaN
# 1                            26                  None                  NaN
# 2                            30                   Yes                  NaN
# 3                            32                   Yes                  NaN
# 4                            32                   Yes                  NaN
# 5                            28                   Yes                  NaN
# 6                            31                   Yes                  NaN
# 7                            32                   Yes                  Yes
# 8                            32                   Yes                  NaN
# 9                            24                   Yes                  NaN
# 10                           26                   Yes                  NaN
# 11                           31                   Yes                  NaN
# 12                           30                    No                  NaN
# 13                           33                   NaN                  NaN
# 14                           29                   NaN                  NaN
# 15                           30                   NaN                  NaN
# 16                           29                   NaN                  NaN
# 17                           26                   NaN                  NaN
# 18                           21                   NaN                  NaN
# 19                           30                   NaN                  NaN
# 20                           30                   NaN                  NaN
# 21                           26                   NaN                  NaN
# 22                           30                   NaN                  NaN
# 23                           32                   NaN                  NaN
# 24                           26                   NaN                  NaN
# 25                           32                   NaN                  NaN
# 26                           33                   NaN                  NaN
# 27                           31                   NaN                  NaN
# 28                           31                   NaN                  NaN
# 29                           32                   NaN                  NaN
# 30                           33                   NaN                  NaN
# 31                           31                   NaN                  NaN
# 32                           31                   NaN                  NaN
# 33                           31                   NaN                  NaN
# 34                           30                   NaN                  NaN
# 35                            0                   NaN                  NaN
# 36                            0                   NaN                  NaN
# 37                            0                   NaN                  NaN
# 38                            0                   NaN                  NaN
# 39                            0                   NaN                  NaN
# 40                            0                   NaN                  NaN
# 41                            0                   NaN                  NaN
# 42                            0                   NaN                  NaN
# 43                            0                   NaN                  NaN
# 44                            0                   NaN                  NaN
# 45                            0                   NaN                  NaN
#
#     Memory Complaint  Fluency Complaint  Language Complaint  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                Yes                NaN                 Yes
# 3                Yes                NaN                 Yes
# 4                NaN                NaN                 Yes
# 5                Yes                NaN                 NaN
# 6                NaN                NaN                 Yes
# 7                Yes                NaN                 Yes
# 8                Yes                NaN                 NaN
# 9                Yes                NaN                 NaN
# 10               Yes                NaN                 Yes
# 11               Yes                NaN                 Yes
# 12               NaN                NaN                 NaN
# 13               NaN                NaN                 NaN
# 14               NaN                NaN                 NaN
# 15               NaN                NaN                 NaN
# 16               NaN                NaN                 NaN
# 17               NaN                NaN                 NaN
# 18               NaN                NaN                 NaN
# 19               NaN                NaN                 NaN
# 20               NaN                NaN                 NaN
# 21               NaN                NaN                 NaN
# 22               NaN                NaN                 NaN
# 23               NaN                NaN                 NaN
# 24               NaN                NaN                 NaN
# 25               NaN                NaN                 NaN
# 26               NaN                NaN                 NaN
# 27               NaN                NaN                 NaN
# 28               NaN                NaN                 NaN
# 29               NaN                NaN                 NaN
# 30               NaN                NaN                 NaN
# 31               NaN                NaN                 NaN
# 32               NaN                NaN                 NaN
# 33               NaN                NaN                 NaN
# 34               NaN                NaN                 NaN
# 35               NaN                NaN                 NaN
# 36               NaN                NaN                 NaN
# 37               NaN                NaN                 NaN
# 38               NaN                NaN                 NaN
# 39               NaN                NaN                 NaN
# 40               NaN                NaN                 NaN
# 41               NaN                NaN                 NaN
# 42               NaN                NaN                 NaN
# 43               NaN                NaN                 NaN
# 44               NaN                NaN                 NaN
# 45               NaN                NaN                 NaN
#
#     Visuospatial Complaint  Impaired on ACE3  iADL Impaired  ADL Impaired
# 0                      NaN                No           None          None
# 1                      NaN               Yes           None          None
# 2                      NaN               Yes           None          None
# 3                      NaN               Yes           None          None
# 4                      NaN                No           None          None
# 5                      NaN               Yes           None          None
# 6                      NaN               Yes           None          None
# 7                      NaN                No           None          None
# 8                      NaN               Yes           None          None
# 9                      NaN               Yes           None          None
# 10                     NaN                No           None          None
# 11                     NaN                No           None          None
# 12                     NaN                No           None          None
# 13                     NaN               NaN            NaN           NaN
# 14                     NaN               NaN            NaN           NaN
# 15                     NaN               NaN            NaN           NaN
# 16                     NaN               NaN            NaN           NaN
# 17                     NaN               NaN            NaN           NaN
# 18                     NaN               NaN            NaN           NaN
# 19                     NaN               NaN            NaN           NaN
# 20                     NaN               NaN            NaN           NaN
# 21                     NaN               NaN            NaN           NaN
# 22                     NaN               NaN            NaN           NaN
# 23                     NaN               NaN            NaN           NaN
# 24                     NaN               NaN            NaN           NaN
# 25                     NaN               NaN            NaN           NaN
# 26                     NaN               NaN            NaN           NaN
# 27                     NaN               NaN            NaN           NaN
# 28                     NaN               NaN            NaN           NaN
# 29                     NaN               NaN            NaN           NaN
# 30                     NaN               NaN            NaN           NaN
# 31                     NaN               NaN            NaN           NaN
# 32                     NaN               NaN            NaN           NaN
# 33                     NaN               NaN            NaN           NaN
# 34                     NaN               NaN            NaN           NaN
# 35                     NaN               NaN            NaN           NaN
# 36                     NaN               NaN            NaN           NaN
# 37                     NaN               NaN            NaN           NaN
# 38                     NaN               NaN            NaN           NaN
# 39                     NaN               NaN            NaN           NaN
# 40                     NaN               NaN            NaN           NaN
# 41                     NaN               NaN            NaN           NaN
# 42                     NaN               NaN            NaN           NaN
# 43                     NaN               NaN            NaN           NaN
# 44                     NaN               NaN            NaN           NaN
# 45                     NaN               NaN            NaN           NaN
#
# [46 rows x 73 columns]

# %%
df_1.columns.names
# Out:
# FrozenList([None])

# %% [markdown]
# Handle NANs

# %%
# df_1.dropna(inplace=True)

# df_1 = df_1.fillna(method='pad')
df_1
# Out:
#      Measurement  Cohort  Randomization Group  Age Cognitive Status  \
# 0     patient_11       1                  2.0   50           Intact
# 1     patient_15       1                  1.0   42              MCI
# 2     patient_17       1                  1.0   35              MCI
# 3     patient_19       1                  1.0   71              MCI
# 4     patient_24       1                  2.0   48           Intact
# 5     patient_25       1                  1.0   53              MCI
# 6     patient_26       1                  1.0   49              MCI
# 7     patient_30       1                  2.0   33           Intact
# 8     patient_33       1                  2.0   36              MCI
# 9     patient_38       1                  2.0   27              MCI
# 10    patient_40       1                  1.0   51           intact
# 11    patient_42       1                  1.0   46           intact
# 12    patient_47       1                  1.0   37              MCI
# 13   patient_108       2                  1.0   35           intact
# 14   patient_109       2                  1.0   41              MCI
# 15   patient_106       2                  1.0   39           Intact
# 16   patient_110       2                  2.0   39           intact
# 17   patient_104       2                  1.0   63              MCI
# 18   patient_111       2                  1.0   61              MCI
# 19   patient_103       2                  2.0   43              MCI
# 20   patient_112       2                  2.0   83           Intact
# 21   patient_102       2                  2.0   39              MCI
# 22   patient_103       2                  2.0   43              MCI
# 23   patient_114       2                  2.0   35           Intact
# 24   patient_107       2                  1.0   54              MCI
# 25   patient_115       2                  1.0   35           intact
# 26   patient_119       4                  2.0   37           intact
# 27   patient_121       4                  2.0   36           intact
# 28   patient_122       4                  1.0   35           intact
# 29   patient_123       4                  2.0   35           intact
# 30   patient_126       4                  1.0   37           intact
# 31   patient_128       4                  2.0   78           intact
# 32   patient_130       4                  1.0   47           intact
# 33   patient_131       4                  1.0   49           intact
# 34   patient_132       4                  2.0   45           intact
# 35  patient_1020       3                  NaN   41           intact
# 36  patient_1021       3                  NaN   33           intact
# 37  patient_1003       3                  NaN   65           intact
# 38  patient_1004       3                  NaN   70           intact
# 39  patient_1005       3                  NaN   82           intact
# 40  patient_1006       3                  NaN   80           intact
# 41  patient_1007       3                  NaN   62           intact
# 42  patient_1008       3                  NaN   52           intact
# 43  patient_1009       3                  NaN   49              MCI
# 44  patient_1010       3                  NaN   66              MCI
# 45  patient_1011       3                  NaN   71           intact
#
#     Question_2  Question_3  Question_4  Question_5  Question_6  ...  \
# 0           10           3           5           3          13  ...
# 1           10           3           1           2           6  ...
# 2           10           3           2           3           5  ...
# 3            8           3           5           3           7  ...
# 4            9           3           5           3          11  ...
# 5           10           3           1           3           7  ...
# 6           10           3           5           2          12  ...
# 7           10           3           5           3          10  ...
# 8           10           3           5           3           8  ...
# 9            9           3           4           3          10  ...
# 10           9           3           5           3          10  ...
# 11          10           3           5           3          10  ...
# 12           9           3           4           3          14  ...
# 13          10           3           5           3           8  ...
# 14          10           3           5           3           9  ...
# 15           9           3           0           3          11  ...
# 16          10           3           3           3           9  ...
# 17          10           3           0           2           6  ...
# 18           6           3           0           3           4  ...
# 19           9           3           3           1           0  ...
# 20           9           2           5           2           4  ...
# 21           8           2           5           0           4  ...
# 22           9           3           4           1           6  ...
# 23          10           3           5           3          11  ...
# 24          10           3           3           1           5  ...
# 25          10           3           5           3          14  ...
# 26          10           3           5           3          13  ...
# 27           9           3           5           3          14  ...
# 28          10           3           5           3          14  ...
# 29          10           3           5           3          14  ...
# 30          10           3           5           3          14  ...
# 31          10           3           5           3          14  ...
# 32          10           3           5           3          14  ...
# 33          10           3           5           3          14  ...
# 34          10           2           4           2          13  ...
# 35          10           3           5           3          14  ...
# 36          10           3           5           3          14  ...
# 37          10           1           1           1          13  ...
# 38          10           3           3           1          13  ...
# 39          10           1           5           3          12  ...
# 40          10           0           5           1          12  ...
# 41          10           1           5           0          13  ...
# 42          10           1           3           1          13  ...
# 43          10           0           1           0           8  ...
# 44          10           1           5           1           7  ...
# 45          10           1           4           3          14  ...
#
#     Expert Algorithm Equivalent  Subjective Complaint  Attention Complaint  \
# 0                            33                  None                  NaN
# 1                            26                  None                  NaN
# 2                            30                   Yes                  NaN
# 3                            32                   Yes                  NaN
# 4                            32                   Yes                  NaN
# 5                            28                   Yes                  NaN
# 6                            31                   Yes                  NaN
# 7                            32                   Yes                  Yes
# 8                            32                   Yes                  NaN
# 9                            24                   Yes                  NaN
# 10                           26                   Yes                  NaN
# 11                           31                   Yes                  NaN
# 12                           30                    No                  NaN
# 13                           33                   NaN                  NaN
# 14                           29                   NaN                  NaN
# 15                           30                   NaN                  NaN
# 16                           29                   NaN                  NaN
# 17                           26                   NaN                  NaN
# 18                           21                   NaN                  NaN
# 19                           30                   NaN                  NaN
# 20                           30                   NaN                  NaN
# 21                           26                   NaN                  NaN
# 22                           30                   NaN                  NaN
# 23                           32                   NaN                  NaN
# 24                           26                   NaN                  NaN
# 25                           32                   NaN                  NaN
# 26                           33                   NaN                  NaN
# 27                           31                   NaN                  NaN
# 28                           31                   NaN                  NaN
# 29                           32                   NaN                  NaN
# 30                           33                   NaN                  NaN
# 31                           31                   NaN                  NaN
# 32                           31                   NaN                  NaN
# 33                           31                   NaN                  NaN
# 34                           30                   NaN                  NaN
# 35                            0                   NaN                  NaN
# 36                            0                   NaN                  NaN
# 37                            0                   NaN                  NaN
# 38                            0                   NaN                  NaN
# 39                            0                   NaN                  NaN
# 40                            0                   NaN                  NaN
# 41                            0                   NaN                  NaN
# 42                            0                   NaN                  NaN
# 43                            0                   NaN                  NaN
# 44                            0                   NaN                  NaN
# 45                            0                   NaN                  NaN
#
#     Memory Complaint  Fluency Complaint  Language Complaint  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                Yes                NaN                 Yes
# 3                Yes                NaN                 Yes
# 4                NaN                NaN                 Yes
# 5                Yes                NaN                 NaN
# 6                NaN                NaN                 Yes
# 7                Yes                NaN                 Yes
# 8                Yes                NaN                 NaN
# 9                Yes                NaN                 NaN
# 10               Yes                NaN                 Yes
# 11               Yes                NaN                 Yes
# 12               NaN                NaN                 NaN
# 13               NaN                NaN                 NaN
# 14               NaN                NaN                 NaN
# 15               NaN                NaN                 NaN
# 16               NaN                NaN                 NaN
# 17               NaN                NaN                 NaN
# 18               NaN                NaN                 NaN
# 19               NaN                NaN                 NaN
# 20               NaN                NaN                 NaN
# 21               NaN                NaN                 NaN
# 22               NaN                NaN                 NaN
# 23               NaN                NaN                 NaN
# 24               NaN                NaN                 NaN
# 25               NaN                NaN                 NaN
# 26               NaN                NaN                 NaN
# 27               NaN                NaN                 NaN
# 28               NaN                NaN                 NaN
# 29               NaN                NaN                 NaN
# 30               NaN                NaN                 NaN
# 31               NaN                NaN                 NaN
# 32               NaN                NaN                 NaN
# 33               NaN                NaN                 NaN
# 34               NaN                NaN                 NaN
# 35               NaN                NaN                 NaN
# 36               NaN                NaN                 NaN
# 37               NaN                NaN                 NaN
# 38               NaN                NaN                 NaN
# 39               NaN                NaN                 NaN
# 40               NaN                NaN                 NaN
# 41               NaN                NaN                 NaN
# 42               NaN                NaN                 NaN
# 43               NaN                NaN                 NaN
# 44               NaN                NaN                 NaN
# 45               NaN                NaN                 NaN
#
#     Visuospatial Complaint  Impaired on ACE3  iADL Impaired  ADL Impaired
# 0                      NaN                No           None          None
# 1                      NaN               Yes           None          None
# 2                      NaN               Yes           None          None
# 3                      NaN               Yes           None          None
# 4                      NaN                No           None          None
# 5                      NaN               Yes           None          None
# 6                      NaN               Yes           None          None
# 7                      NaN                No           None          None
# 8                      NaN               Yes           None          None
# 9                      NaN               Yes           None          None
# 10                     NaN                No           None          None
# 11                     NaN                No           None          None
# 12                     NaN                No           None          None
# 13                     NaN               NaN            NaN           NaN
# 14                     NaN               NaN            NaN           NaN
# 15                     NaN               NaN            NaN           NaN
# 16                     NaN               NaN            NaN           NaN
# 17                     NaN               NaN            NaN           NaN
# 18                     NaN               NaN            NaN           NaN
# 19                     NaN               NaN            NaN           NaN
# 20                     NaN               NaN            NaN           NaN
# 21                     NaN               NaN            NaN           NaN
# 22                     NaN               NaN            NaN           NaN
# 23                     NaN               NaN            NaN           NaN
# 24                     NaN               NaN            NaN           NaN
# 25                     NaN               NaN            NaN           NaN
# 26                     NaN               NaN            NaN           NaN
# 27                     NaN               NaN            NaN           NaN
# 28                     NaN               NaN            NaN           NaN
# 29                     NaN               NaN            NaN           NaN
# 30                     NaN               NaN            NaN           NaN
# 31                     NaN               NaN            NaN           NaN
# 32                     NaN               NaN            NaN           NaN
# 33                     NaN               NaN            NaN           NaN
# 34                     NaN               NaN            NaN           NaN
# 35                     NaN               NaN            NaN           NaN
# 36                     NaN               NaN            NaN           NaN
# 37                     NaN               NaN            NaN           NaN
# 38                     NaN               NaN            NaN           NaN
# 39                     NaN               NaN            NaN           NaN
# 40                     NaN               NaN            NaN           NaN
# 41                     NaN               NaN            NaN           NaN
# 42                     NaN               NaN            NaN           NaN
# 43                     NaN               NaN            NaN           NaN
# 44                     NaN               NaN            NaN           NaN
# 45                     NaN               NaN            NaN           NaN
#
# [46 rows x 73 columns]

# %% [markdown]
# Remove Dataframe Rows by Value in a Given Column

# %%
# df_1 = df_1[df_1['Cohort'] != 3]
# df_1

# %% [markdown]
# Descriptive Stats

# %%
descriptive_stats = df_1.describe().transpose()
descriptive_stats
# Out:
#                                          count       mean        std   min  \
# Cohort                                    46.0   2.347826   1.099846   1.0
# Randomization Group                       35.0   1.457143   0.505433   1.0
# Age                                       46.0  49.086957  14.970825  27.0
# Question_2                                46.0   9.630435   0.770532   6.0
# Question_3                                46.0   2.543478   0.887106   0.0
# ...                                        ...        ...        ...   ...
# Convolutional Neural Network Equivalent   46.0   5.347826   3.308020   0.0
# Natural Language Processing Equivalent    46.0  38.239130  22.391650   0.0
# Expert Algorithm Equivalent               46.0  22.695652  13.097701   0.0
# Fluency Complaint                          0.0        NaN        NaN   NaN
# Visuospatial Complaint                     0.0        NaN        NaN   NaN
#
#                                            25%   50%    75%   max
# Cohort                                    1.00   2.0   3.00   4.0
# Randomization Group                       1.00   1.0   2.00   2.0
# Age                                      37.00  45.5  59.25  83.0
# Question_2                                9.25  10.0  10.00  10.0
# Question_3                                3.00   3.0   3.00   3.0
# ...                                        ...   ...    ...   ...
# Convolutional Neural Network Equivalent   1.75   7.0   8.00   8.0
# Natural Language Processing Equivalent   36.25  46.5  55.00  59.0
# Expert Algorithm Equivalent              21.75  30.0  31.00  33.0
# Fluency Complaint                          NaN   NaN    NaN   NaN
# Visuospatial Complaint                     NaN   NaN    NaN   NaN
#
# [64 rows x 8 columns]

# %% [markdown]
# Normalize to Max Value in Column

# %%
age = df_1.pop('Age'
)
for col in df_1.columns.to_list():
    try:
        df_1[col] = (df_1[col])/(df_1[col].max())
    except:
        print(f'Cannot normalize {col}')
df_1['Age'] = age
df_1
# Out:
# Cannot normalize Measurement
# Cannot normalize Cognitive Status
# Cannot normalize Subjective Complaint
# Cannot normalize Attention Complaint
# Cannot normalize Memory Complaint
# Cannot normalize Language Complaint
# Cannot normalize Impaired on ACE3
# Cannot normalize iADL Impaired
# Cannot normalize ADL Impaired
#      Measurement  Cohort  Randomization Group Cognitive Status  Question_2  \
# 0     patient_11    0.25                  1.0           Intact         1.0
# 1     patient_15    0.25                  0.5              MCI         1.0
# 2     patient_17    0.25                  0.5              MCI         1.0
# 3     patient_19    0.25                  0.5              MCI         0.8
# 4     patient_24    0.25                  1.0           Intact         0.9
# 5     patient_25    0.25                  0.5              MCI         1.0
# 6     patient_26    0.25                  0.5              MCI         1.0
# 7     patient_30    0.25                  1.0           Intact         1.0
# 8     patient_33    0.25                  1.0              MCI         1.0
# 9     patient_38    0.25                  1.0              MCI         0.9
# 10    patient_40    0.25                  0.5           intact         0.9
# 11    patient_42    0.25                  0.5           intact         1.0
# 12    patient_47    0.25                  0.5              MCI         0.9
# 13   patient_108    0.50                  0.5           intact         1.0
# 14   patient_109    0.50                  0.5              MCI         1.0
# 15   patient_106    0.50                  0.5           Intact         0.9
# 16   patient_110    0.50                  1.0           intact         1.0
# 17   patient_104    0.50                  0.5              MCI         1.0
# 18   patient_111    0.50                  0.5              MCI         0.6
# 19   patient_103    0.50                  1.0              MCI         0.9
# 20   patient_112    0.50                  1.0           Intact         0.9
# 21   patient_102    0.50                  1.0              MCI         0.8
# 22   patient_103    0.50                  1.0              MCI         0.9
# 23   patient_114    0.50                  1.0           Intact         1.0
# 24   patient_107    0.50                  0.5              MCI         1.0
# 25   patient_115    0.50                  0.5           intact         1.0
# 26   patient_119    1.00                  1.0           intact         1.0
# 27   patient_121    1.00                  1.0           intact         0.9
# 28   patient_122    1.00                  0.5           intact         1.0
# 29   patient_123    1.00                  1.0           intact         1.0
# 30   patient_126    1.00                  0.5           intact         1.0
# 31   patient_128    1.00                  1.0           intact         1.0
# 32   patient_130    1.00                  0.5           intact         1.0
# 33   patient_131    1.00                  0.5           intact         1.0
# 34   patient_132    1.00                  1.0           intact         1.0
# 35  patient_1020    0.75                  NaN           intact         1.0
# 36  patient_1021    0.75                  NaN           intact         1.0
# 37  patient_1003    0.75                  NaN           intact         1.0
# 38  patient_1004    0.75                  NaN           intact         1.0
# 39  patient_1005    0.75                  NaN           intact         1.0
# 40  patient_1006    0.75                  NaN           intact         1.0
# 41  patient_1007    0.75                  NaN           intact         1.0
# 42  patient_1008    0.75                  NaN           intact         1.0
# 43  patient_1009    0.75                  NaN              MCI         1.0
# 44  patient_1010    0.75                  NaN              MCI         1.0
# 45  patient_1011    0.75                  NaN           intact         1.0
#
#     Question_3  Question_4  Question_5  Question_6  Question_7  ...  \
# 0     1.000000         1.0    1.000000    0.928571    0.857143  ...
# 1     1.000000         0.2    0.666667    0.428571    0.571429  ...
# 2     1.000000         0.4    1.000000    0.357143    1.000000  ...
# 3     1.000000         1.0    1.000000    0.500000    0.428571  ...
# 4     1.000000         1.0    1.000000    0.785714    0.571429  ...
# 5     1.000000         0.2    1.000000    0.500000    0.428571  ...
# 6     1.000000         1.0    0.666667    0.857143    1.000000  ...
# 7     1.000000         1.0    1.000000    0.714286    1.000000  ...
# 8     1.000000         1.0    1.000000    0.571429    0.857143  ...
# 9     1.000000         0.8    1.000000    0.714286    1.000000  ...
# 10    1.000000         1.0    1.000000    0.714286    1.000000  ...
# 11    1.000000         1.0    1.000000    0.714286    0.571429  ...
# 12    1.000000         0.8    1.000000    1.000000    0.571429  ...
# 13    1.000000         1.0    1.000000    0.571429    1.000000  ...
# 14    1.000000         1.0    1.000000    0.642857    0.857143  ...
# 15    1.000000         0.0    1.000000    0.785714    1.000000  ...
# 16    1.000000         0.6    1.000000    0.642857    0.714286  ...
# 17    1.000000         0.0    0.666667    0.428571    0.714286  ...
# 18    1.000000         0.0    1.000000    0.285714    0.285714  ...
# 19    1.000000         0.6    0.333333    0.000000    0.428571  ...
# 20    0.666667         1.0    0.666667    0.285714    0.857143  ...
# 21    0.666667         1.0    0.000000    0.285714    0.857143  ...
# 22    1.000000         0.8    0.333333    0.428571    0.000000  ...
# 23    1.000000         1.0    1.000000    0.785714    1.000000  ...
# 24    1.000000         0.6    0.333333    0.357143    0.714286  ...
# 25    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 26    1.000000         1.0    1.000000    0.928571    1.000000  ...
# 27    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 28    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 29    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 30    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 31    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 32    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 33    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 34    0.666667         0.8    0.666667    0.928571    0.857143  ...
# 35    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 36    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 37    0.333333         0.2    0.333333    0.928571    0.428571  ...
# 38    1.000000         0.6    0.333333    0.928571    0.285714  ...
# 39    0.333333         1.0    1.000000    0.857143    0.285714  ...
# 40    0.000000         1.0    0.333333    0.857143    0.285714  ...
# 41    0.333333         1.0    0.000000    0.928571    0.428571  ...
# 42    0.333333         0.6    0.333333    0.928571    0.571429  ...
# 43    0.000000         0.2    0.000000    0.571429    0.000000  ...
# 44    0.333333         1.0    0.333333    0.500000    0.000000  ...
# 45    0.333333         0.8    1.000000    1.000000    1.000000  ...
#
#     Subjective Complaint  Attention Complaint  Memory Complaint  \
# 0                   None                  NaN               NaN
# 1                   None                  NaN               NaN
# 2                    Yes                  NaN               Yes
# 3                    Yes                  NaN               Yes
# 4                    Yes                  NaN               NaN
# 5                    Yes                  NaN               Yes
# 6                    Yes                  NaN               NaN
# 7                    Yes                  Yes               Yes
# 8                    Yes                  NaN               Yes
# 9                    Yes                  NaN               Yes
# 10                   Yes                  NaN               Yes
# 11                   Yes                  NaN               Yes
# 12                    No                  NaN               NaN
# 13                   NaN                  NaN               NaN
# 14                   NaN                  NaN               NaN
# 15                   NaN                  NaN               NaN
# 16                   NaN                  NaN               NaN
# 17                   NaN                  NaN               NaN
# 18                   NaN                  NaN               NaN
# 19                   NaN                  NaN               NaN
# 20                   NaN                  NaN               NaN
# 21                   NaN                  NaN               NaN
# 22                   NaN                  NaN               NaN
# 23                   NaN                  NaN               NaN
# 24                   NaN                  NaN               NaN
# 25                   NaN                  NaN               NaN
# 26                   NaN                  NaN               NaN
# 27                   NaN                  NaN               NaN
# 28                   NaN                  NaN               NaN
# 29                   NaN                  NaN               NaN
# 30                   NaN                  NaN               NaN
# 31                   NaN                  NaN               NaN
# 32                   NaN                  NaN               NaN
# 33                   NaN                  NaN               NaN
# 34                   NaN                  NaN               NaN
# 35                   NaN                  NaN               NaN
# 36                   NaN                  NaN               NaN
# 37                   NaN                  NaN               NaN
# 38                   NaN                  NaN               NaN
# 39                   NaN                  NaN               NaN
# 40                   NaN                  NaN               NaN
# 41                   NaN                  NaN               NaN
# 42                   NaN                  NaN               NaN
# 43                   NaN                  NaN               NaN
# 44                   NaN                  NaN               NaN
# 45                   NaN                  NaN               NaN
#
#     Fluency Complaint  Language Complaint  Visuospatial Complaint  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 Yes                     NaN
# 3                 NaN                 Yes                     NaN
# 4                 NaN                 Yes                     NaN
# 5                 NaN                 NaN                     NaN
# 6                 NaN                 Yes                     NaN
# 7                 NaN                 Yes                     NaN
# 8                 NaN                 NaN                     NaN
# 9                 NaN                 NaN                     NaN
# 10                NaN                 Yes                     NaN
# 11                NaN                 Yes                     NaN
# 12                NaN                 NaN                     NaN
# 13                NaN                 NaN                     NaN
# 14                NaN                 NaN                     NaN
# 15                NaN                 NaN                     NaN
# 16                NaN                 NaN                     NaN
# 17                NaN                 NaN                     NaN
# 18                NaN                 NaN                     NaN
# 19                NaN                 NaN                     NaN
# 20                NaN                 NaN                     NaN
# 21                NaN                 NaN                     NaN
# 22                NaN                 NaN                     NaN
# 23                NaN                 NaN                     NaN
# 24                NaN                 NaN                     NaN
# 25                NaN                 NaN                     NaN
# 26                NaN                 NaN                     NaN
# 27                NaN                 NaN                     NaN
# 28                NaN                 NaN                     NaN
# 29                NaN                 NaN                     NaN
# 30                NaN                 NaN                     NaN
# 31                NaN                 NaN                     NaN
# 32                NaN                 NaN                     NaN
# 33                NaN                 NaN                     NaN
# 34                NaN                 NaN                     NaN
# 35                NaN                 NaN                     NaN
# 36                NaN                 NaN                     NaN
# 37                NaN                 NaN                     NaN
# 38                NaN                 NaN                     NaN
# 39                NaN                 NaN                     NaN
# 40                NaN                 NaN                     NaN
# 41                NaN                 NaN                     NaN
# 42                NaN                 NaN                     NaN
# 43                NaN                 NaN                     NaN
# 44                NaN                 NaN                     NaN
# 45                NaN                 NaN                     NaN
#
#     Impaired on ACE3  iADL Impaired  ADL Impaired  Age
# 0                 No           None          None   50
# 1                Yes           None          None   42
# 2                Yes           None          None   35
# 3                Yes           None          None   71
# 4                 No           None          None   48
# 5                Yes           None          None   53
# 6                Yes           None          None   49
# 7                 No           None          None   33
# 8                Yes           None          None   36
# 9                Yes           None          None   27
# 10                No           None          None   51
# 11                No           None          None   46
# 12                No           None          None   37
# 13               NaN            NaN           NaN   35
# 14               NaN            NaN           NaN   41
# 15               NaN            NaN           NaN   39
# 16               NaN            NaN           NaN   39
# 17               NaN            NaN           NaN   63
# 18               NaN            NaN           NaN   61
# 19               NaN            NaN           NaN   43
# 20               NaN            NaN           NaN   83
# 21               NaN            NaN           NaN   39
# 22               NaN            NaN           NaN   43
# 23               NaN            NaN           NaN   35
# 24               NaN            NaN           NaN   54
# 25               NaN            NaN           NaN   35
# 26               NaN            NaN           NaN   37
# 27               NaN            NaN           NaN   36
# 28               NaN            NaN           NaN   35
# 29               NaN            NaN           NaN   35
# 30               NaN            NaN           NaN   37
# 31               NaN            NaN           NaN   78
# 32               NaN            NaN           NaN   47
# 33               NaN            NaN           NaN   49
# 34               NaN            NaN           NaN   45
# 35               NaN            NaN           NaN   41
# 36               NaN            NaN           NaN   33
# 37               NaN            NaN           NaN   65
# 38               NaN            NaN           NaN   70
# 39               NaN            NaN           NaN   82
# 40               NaN            NaN           NaN   80
# 41               NaN            NaN           NaN   62
# 42               NaN            NaN           NaN   52
# 43               NaN            NaN           NaN   49
# 44               NaN            NaN           NaN   66
# 45               NaN            NaN           NaN   71
#
# [46 rows x 73 columns]

# %% [markdown]
# Set New Variables

# %%
df_1['autocog_status'] = np.where(df_1['Total'] < 82/100, 1, 0)
df_1['ace_status'] = np.where(df_1['Total'] < 82/100, 1, 0)
df_1
# Out:
#      Measurement  Cohort  Randomization Group Cognitive Status  Question_2  \
# 0     patient_11    0.25                  1.0           Intact         1.0
# 1     patient_15    0.25                  0.5              MCI         1.0
# 2     patient_17    0.25                  0.5              MCI         1.0
# 3     patient_19    0.25                  0.5              MCI         0.8
# 4     patient_24    0.25                  1.0           Intact         0.9
# 5     patient_25    0.25                  0.5              MCI         1.0
# 6     patient_26    0.25                  0.5              MCI         1.0
# 7     patient_30    0.25                  1.0           Intact         1.0
# 8     patient_33    0.25                  1.0              MCI         1.0
# 9     patient_38    0.25                  1.0              MCI         0.9
# 10    patient_40    0.25                  0.5           intact         0.9
# 11    patient_42    0.25                  0.5           intact         1.0
# 12    patient_47    0.25                  0.5              MCI         0.9
# 13   patient_108    0.50                  0.5           intact         1.0
# 14   patient_109    0.50                  0.5              MCI         1.0
# 15   patient_106    0.50                  0.5           Intact         0.9
# 16   patient_110    0.50                  1.0           intact         1.0
# 17   patient_104    0.50                  0.5              MCI         1.0
# 18   patient_111    0.50                  0.5              MCI         0.6
# 19   patient_103    0.50                  1.0              MCI         0.9
# 20   patient_112    0.50                  1.0           Intact         0.9
# 21   patient_102    0.50                  1.0              MCI         0.8
# 22   patient_103    0.50                  1.0              MCI         0.9
# 23   patient_114    0.50                  1.0           Intact         1.0
# 24   patient_107    0.50                  0.5              MCI         1.0
# 25   patient_115    0.50                  0.5           intact         1.0
# 26   patient_119    1.00                  1.0           intact         1.0
# 27   patient_121    1.00                  1.0           intact         0.9
# 28   patient_122    1.00                  0.5           intact         1.0
# 29   patient_123    1.00                  1.0           intact         1.0
# 30   patient_126    1.00                  0.5           intact         1.0
# 31   patient_128    1.00                  1.0           intact         1.0
# 32   patient_130    1.00                  0.5           intact         1.0
# 33   patient_131    1.00                  0.5           intact         1.0
# 34   patient_132    1.00                  1.0           intact         1.0
# 35  patient_1020    0.75                  NaN           intact         1.0
# 36  patient_1021    0.75                  NaN           intact         1.0
# 37  patient_1003    0.75                  NaN           intact         1.0
# 38  patient_1004    0.75                  NaN           intact         1.0
# 39  patient_1005    0.75                  NaN           intact         1.0
# 40  patient_1006    0.75                  NaN           intact         1.0
# 41  patient_1007    0.75                  NaN           intact         1.0
# 42  patient_1008    0.75                  NaN           intact         1.0
# 43  patient_1009    0.75                  NaN              MCI         1.0
# 44  patient_1010    0.75                  NaN              MCI         1.0
# 45  patient_1011    0.75                  NaN           intact         1.0
#
#     Question_3  Question_4  Question_5  Question_6  Question_7  ...  \
# 0     1.000000         1.0    1.000000    0.928571    0.857143  ...
# 1     1.000000         0.2    0.666667    0.428571    0.571429  ...
# 2     1.000000         0.4    1.000000    0.357143    1.000000  ...
# 3     1.000000         1.0    1.000000    0.500000    0.428571  ...
# 4     1.000000         1.0    1.000000    0.785714    0.571429  ...
# 5     1.000000         0.2    1.000000    0.500000    0.428571  ...
# 6     1.000000         1.0    0.666667    0.857143    1.000000  ...
# 7     1.000000         1.0    1.000000    0.714286    1.000000  ...
# 8     1.000000         1.0    1.000000    0.571429    0.857143  ...
# 9     1.000000         0.8    1.000000    0.714286    1.000000  ...
# 10    1.000000         1.0    1.000000    0.714286    1.000000  ...
# 11    1.000000         1.0    1.000000    0.714286    0.571429  ...
# 12    1.000000         0.8    1.000000    1.000000    0.571429  ...
# 13    1.000000         1.0    1.000000    0.571429    1.000000  ...
# 14    1.000000         1.0    1.000000    0.642857    0.857143  ...
# 15    1.000000         0.0    1.000000    0.785714    1.000000  ...
# 16    1.000000         0.6    1.000000    0.642857    0.714286  ...
# 17    1.000000         0.0    0.666667    0.428571    0.714286  ...
# 18    1.000000         0.0    1.000000    0.285714    0.285714  ...
# 19    1.000000         0.6    0.333333    0.000000    0.428571  ...
# 20    0.666667         1.0    0.666667    0.285714    0.857143  ...
# 21    0.666667         1.0    0.000000    0.285714    0.857143  ...
# 22    1.000000         0.8    0.333333    0.428571    0.000000  ...
# 23    1.000000         1.0    1.000000    0.785714    1.000000  ...
# 24    1.000000         0.6    0.333333    0.357143    0.714286  ...
# 25    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 26    1.000000         1.0    1.000000    0.928571    1.000000  ...
# 27    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 28    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 29    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 30    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 31    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 32    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 33    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 34    0.666667         0.8    0.666667    0.928571    0.857143  ...
# 35    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 36    1.000000         1.0    1.000000    1.000000    1.000000  ...
# 37    0.333333         0.2    0.333333    0.928571    0.428571  ...
# 38    1.000000         0.6    0.333333    0.928571    0.285714  ...
# 39    0.333333         1.0    1.000000    0.857143    0.285714  ...
# 40    0.000000         1.0    0.333333    0.857143    0.285714  ...
# 41    0.333333         1.0    0.000000    0.928571    0.428571  ...
# 42    0.333333         0.6    0.333333    0.928571    0.571429  ...
# 43    0.000000         0.2    0.000000    0.571429    0.000000  ...
# 44    0.333333         1.0    0.333333    0.500000    0.000000  ...
# 45    0.333333         0.8    1.000000    1.000000    1.000000  ...
#
#     Memory Complaint  Fluency Complaint  Language Complaint  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                Yes                NaN                 Yes
# 3                Yes                NaN                 Yes
# 4                NaN                NaN                 Yes
# 5                Yes                NaN                 NaN
# 6                NaN                NaN                 Yes
# 7                Yes                NaN                 Yes
# 8                Yes                NaN                 NaN
# 9                Yes                NaN                 NaN
# 10               Yes                NaN                 Yes
# 11               Yes                NaN                 Yes
# 12               NaN                NaN                 NaN
# 13               NaN                NaN                 NaN
# 14               NaN                NaN                 NaN
# 15               NaN                NaN                 NaN
# 16               NaN                NaN                 NaN
# 17               NaN                NaN                 NaN
# 18               NaN                NaN                 NaN
# 19               NaN                NaN                 NaN
# 20               NaN                NaN                 NaN
# 21               NaN                NaN                 NaN
# 22               NaN                NaN                 NaN
# 23               NaN                NaN                 NaN
# 24               NaN                NaN                 NaN
# 25               NaN                NaN                 NaN
# 26               NaN                NaN                 NaN
# 27               NaN                NaN                 NaN
# 28               NaN                NaN                 NaN
# 29               NaN                NaN                 NaN
# 30               NaN                NaN                 NaN
# 31               NaN                NaN                 NaN
# 32               NaN                NaN                 NaN
# 33               NaN                NaN                 NaN
# 34               NaN                NaN                 NaN
# 35               NaN                NaN                 NaN
# 36               NaN                NaN                 NaN
# 37               NaN                NaN                 NaN
# 38               NaN                NaN                 NaN
# 39               NaN                NaN                 NaN
# 40               NaN                NaN                 NaN
# 41               NaN                NaN                 NaN
# 42               NaN                NaN                 NaN
# 43               NaN                NaN                 NaN
# 44               NaN                NaN                 NaN
# 45               NaN                NaN                 NaN
#
#     Visuospatial Complaint  Impaired on ACE3  iADL Impaired  ADL Impaired  \
# 0                      NaN                No           None          None
# 1                      NaN               Yes           None          None
# 2                      NaN               Yes           None          None
# 3                      NaN               Yes           None          None
# 4                      NaN                No           None          None
# 5                      NaN               Yes           None          None
# 6                      NaN               Yes           None          None
# 7                      NaN                No           None          None
# 8                      NaN               Yes           None          None
# 9                      NaN               Yes           None          None
# 10                     NaN                No           None          None
# 11                     NaN                No           None          None
# 12                     NaN                No           None          None
# 13                     NaN               NaN            NaN           NaN
# 14                     NaN               NaN            NaN           NaN
# 15                     NaN               NaN            NaN           NaN
# 16                     NaN               NaN            NaN           NaN
# 17                     NaN               NaN            NaN           NaN
# 18                     NaN               NaN            NaN           NaN
# 19                     NaN               NaN            NaN           NaN
# 20                     NaN               NaN            NaN           NaN
# 21                     NaN               NaN            NaN           NaN
# 22                     NaN               NaN            NaN           NaN
# 23                     NaN               NaN            NaN           NaN
# 24                     NaN               NaN            NaN           NaN
# 25                     NaN               NaN            NaN           NaN
# 26                     NaN               NaN            NaN           NaN
# 27                     NaN               NaN            NaN           NaN
# 28                     NaN               NaN            NaN           NaN
# 29                     NaN               NaN            NaN           NaN
# 30                     NaN               NaN            NaN           NaN
# 31                     NaN               NaN            NaN           NaN
# 32                     NaN               NaN            NaN           NaN
# 33                     NaN               NaN            NaN           NaN
# 34                     NaN               NaN            NaN           NaN
# 35                     NaN               NaN            NaN           NaN
# 36                     NaN               NaN            NaN           NaN
# 37                     NaN               NaN            NaN           NaN
# 38                     NaN               NaN            NaN           NaN
# 39                     NaN               NaN            NaN           NaN
# 40                     NaN               NaN            NaN           NaN
# 41                     NaN               NaN            NaN           NaN
# 42                     NaN               NaN            NaN           NaN
# 43                     NaN               NaN            NaN           NaN
# 44                     NaN               NaN            NaN           NaN
# 45                     NaN               NaN            NaN           NaN
#
#     Age  autocog_status  ace_status
# 0    50               0           0
# 1    42               1           1
# 2    35               1           1
# 3    71               1           1
# 4    48               0           0
# 5    53               1           1
# 6    49               1           1
# 7    33               0           0
# 8    36               0           0
# 9    27               1           1
# 10   51               0           0
# 11   46               0           0
# 12   37               0           0
# 13   35               0           0
# 14   41               1           1
# 15   39               0           0
# 16   39               1           1
# 17   63               1           1
# 18   61               1           1
# 19   43               1           1
# 20   83               1           1
# 21   39               1           1
# 22   43               1           1
# 23   35               0           0
# 24   54               1           1
# 25   35               0           0
# 26   37               0           0
# 27   36               0           0
# 28   35               0           0
# 29   35               0           0
# 30   37               0           0
# 31   78               0           0
# 32   47               0           0
# 33   49               0           0
# 34   45               0           0
# 35   41               0           0
# 36   33               0           0
# 37   65               1           1
# 38   70               0           0
# 39   82               0           0
# 40   80               1           1
# 41   62               1           1
# 42   52               1           1
# 43   49               1           1
# 44   66               1           1
# 45   71               0           0
#
# [46 rows x 75 columns]

# %% [markdown]
# Finalize

# %%
data_df = df_1.copy()

# %% [markdown]
# # Get Descriptive Statistics

# %%
descriptive_stats = df_1.describe().transpose()
descriptive_stats
# Out:
#                         count       mean        std    min     25%   50%  \
# Cohort                   46.0   0.586957   0.274962   0.25   0.250   0.5
# Randomization Group      35.0   0.728571   0.252716   0.50   0.500   0.5
# Question_2               46.0   0.963043   0.077053   0.60   0.925   1.0
# Question_3               46.0   0.847826   0.295702   0.00   1.000   1.0
# Question_4               46.0   0.786957   0.327691   0.00   0.600   1.0
# ...                       ...        ...        ...    ...     ...   ...
# Fluency Complaint         0.0        NaN        NaN    NaN     NaN   NaN
# Visuospatial Complaint    0.0        NaN        NaN    NaN     NaN   NaN
# Age                      46.0  49.086957  14.970825  27.00  37.000  45.5
# autocog_status           46.0   0.456522   0.503610   0.00   0.000   0.0
# ace_status               46.0   0.456522   0.503610   0.00   0.000   0.0
#
#                           75%   max
# Cohort                   0.75   1.0
# Randomization Group      1.00   1.0
# Question_2               1.00   1.0
# Question_3               1.00   1.0
# Question_4               1.00   1.0
# ...                       ...   ...
# Fluency Complaint         NaN   NaN
# Visuospatial Complaint    NaN   NaN
# Age                     59.25  83.0
# autocog_status           1.00   1.0
# ace_status               1.00   1.0
#
# [66 rows x 8 columns]

# %%
data_df.rename(columns={"Total.1": "Paper Test"}, inplace=True)
data_df.rename(columns={"Total": "Autonomous Test"}, inplace=True)

# %% [markdown]
# # Compare Distributions

# %%
from statannotations.Annotator import Annotator
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
def plot_with_annotation(dataframe, col1, col2, xlabel, ylabel, test_type):
    # Validate the test type
    valid_tests = ['t-test_ind', 't-test_paired', 'Mann-Whitney', 'Wilcoxon']
    if test_type not in valid_tests:
        raise ValueError(f"Invalid test type. Choose from: {', '.join(valid_tests)}")
    
    # Extract series
    series1 = dataframe[col1]
    series2 = dataframe[col2]
    
    # Prepare data
    data = pd.DataFrame({'Group': [col1] * len(series1) + [col2] * len(series2),
                         'Value': series1.tolist() + series2.tolist()})
    
    # Pairs for comparison
    pairs = [(col1, col2)]
    
    # Create figure
    fig, ax = plt.subplots(figsize=(6.5, 2.5))
    
    sns.set_palette('tab10', 2, desat=1)
    
    # Plot with seaborn
    sns.boxplot(x='Group', y='Value', data=data, ax=ax)
    
    # Add annotations
    annotator = Annotator(ax=ax,
                          data=data,
                          x='Group',
                          y='Value',
                          pairs=pairs,
                          test=test_type,
                          text_format='full',
                          loc='inside',
                          verbose=2)
    
    # Configure and annotate
    _, corrected_results = annotator.configure(test=test_type, comparisons_correction="bonferroni").apply_and_annotate()
    
    # Label and show plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    return plt

# %%
group1_col_name = 'Paper Test'
group2_col_name = 'Autonomous Test'
x_label = 'Test Type'
y_label = 'Score'
test_type = 'Mann-Whitney'
#----------------------------------------------------------------
plt = plot_with_annotation(dataframe=data_df, 
                           col1=group1_col_name, 
                           col2=group2_col_name,
                           xlabel=x_label, 
                           ylabel=y_label, 
                           test_type=test_type)

os.makedirs(os.path.join(out_dir, 'distribution_figures'), exist_ok=True)
plt.savefig(os.path.join(out_dir, f'distribution_figures/{group1_col_name}_{test_type}_{group2_col_name}.png'))
plt.savefig(os.path.join(out_dir, f'distribution_figures/{group1_col_name}_{test_type}_{group2_col_name}.svg'))
print('Figure saved to: ', (os.path.join(out_dir, f'distribution_figures/{group1_col_name}_{test_type}_{group2_col_name}')))
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Paper Test vs. Autonomous Test: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.597e-02 U_stat=7.640e+02
# Figure saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/distribution_figures/Paper Test_Mann-Whitney_Autonomous Test

# %% [markdown]
# Perform Multiple Distribution Tests and Correct for Multiple Comparisons

# %% [markdown]
# Below is a detailed description of the `plot_distribution_tests` function.
#
# ### `plot_distribution_tests` Function
#
# This function creates a plot of distribution tests with optional annotations for multiple key-value pair comparisons.
#
# #### Parameters
#
# - `dataframe`: A pandas DataFrame containing the data for comparison.
# - `comparisons_dict`: A dictionary mapping comparisons with keys and values representing column names in the DataFrame.
# - `test_type`: Specifies the statistical method used for testing. Available options are:
#   - `'t-test_ind'`: Independent t-test
#   - `'t-test_paired'`: Paired t-test
#   - `'Mann-Whitney'`: Mann-Whitney U test
#   - `'Wilcoxon'`: Wilcoxon signed-rank test
# - `correction_method`: Specifies the method used to correct for multiple comparisons. Available options are:
#   - `'bonferroni'`: Bonferroni correction
#   - `'holm'`: Holm's correction
#   - `'fdr_bh'`: Benjamini-Hochberg false discovery rate correction
# - `key_label`: A string label for the keys in the plot.
# - `value_label`: A string label for the values in the plot.
# - `x_label`: Label for the x-axis.
# - `y_label`: Label for the y-axis.
# - `display`: Controls how the keys and values are displayed. Available options are:
#   - `'split_pairs'`: Displays keys and values side by side, with keys on the left and values on the right.
#   - `'group_pairs'`: Groups the key-value pairs together.
# - `full_legend_patches`: A boolean that controls the appearance of the legend. If `True`, full key-value pairs are shown in the legend; if `False`, only keys are shown.
#
# #### Returns
#
# - A matplotlib plot object.
#
# #### Example Usage
#
# ```python
# comparisons_dict = {
#     'Attention': 'Attention.1',
#     'Memory': 'Memory.1',
#     'Language': 'Language.1',
#     'Fluency': 'Fluency.1',
#     'Visuospatial': 'Visuospatial.1',
# }
# test_type = 'Mann-Whitney'
# correction_method = 'bonferroni'
# key_label = 'Keys'
# value_label = 'Values'
# x_label = 'Metrics'
# y_label = 'Values'
#
# plt = plot_distribution_tests(dataframe=data_df,
#                               comparisons_dict=comparisons_dict,
#                               test_type=test_type,
#                               correction_method=correction_method,
#                               key_label=key_label,
#                               value_label=value_label,
#                               x_label=x_label,
#                               y_label=y_label)
# plt.show()
# ```
#
# #### Notes
#
# - The `test_type` and `correction_method` must be chosen from the available options; otherwise, a `ValueError` will be raised.
# - The function supports customization of the plot appearance, including color mapping, annotations, and more, to suit various use cases.

# %%
from statannotations.Annotator import Annotator
import matplotlib.patches as mpatches

def plot_distribution_tests(dataframe, comparisons_dict, test_type, correction_method, key_label, value_label, x_label, y_label, display='split_pairs', full_legend_patches=False):
    valid_tests = ['t-test_ind', 't-test_paired', 'Mann-Whitney', 'Wilcoxon']
    valid_corrections = ['bonferroni', 'holm', 'fdr_bh']
    if test_type not in valid_tests:
        raise ValueError(f"Invalid test type. Choose from: {', '.join(valid_tests)}")
    if correction_method not in valid_corrections:
        raise ValueError(f"Invalid correction method. Choose from: {', '.join(valid_corrections)}")

    # Create a color palette with enough unique colors
    colors = sns.color_palette("tab10", len(comparisons_dict))

    # Create a new DataFrame to hold the data for plotting
    data = pd.DataFrame(columns=['GroupType', 'Metric', 'Value'])
    pairs = []
    # Create legend patches
    legend_patches = []

    # Iterate through comparisons_dict
    for idx, (key, value) in enumerate(comparisons_dict.items()):
        key_series = dataframe[key]
        value_series = dataframe[value]
        color = colors[idx]
        temp_data = pd.DataFrame({
            'GroupType': [f'Key'] * len(key_series) + [f'Value'] * len(value_series),
            'Metric': [key] * len(key_series) + [value] * len(value_series),
            'Value': key_series.tolist() + value_series.tolist(),
            'Color': [color] * (len(key_series) + len(value_series))
        })
        data = pd.concat([data, temp_data], axis=0)
        pairs.append(((key, 'Key'), (value, 'Value')))
        
        if full_legend_patches:
            legend_patches.append(mpatches.Patch(color=colors[idx], label=f'{key} vs {value}'))
        else:
            legend_patches.append(mpatches.Patch(color=colors[idx], label=f'{value}'))

    # Map colour
    palette_mapping = {row['Metric']: row['Color'] for _, row in data.iterrows()}

    # Create figure
    fig, ax = plt.subplots(figsize=(len(comparisons_dict)*1.3, 5))
    # Add annotations
    if display=='group_pairs':
        # Plot with seaborn (split image)
        sns.set_style('white')
        palette = sns.color_palette('tab10', 2, desat=1)  # Define palette with 2 colors
        sns.set_palette(palette)
        ax = sns.boxplot(x='Metric', y='Value', hue='GroupType', data=data, ax=ax, palette=palette)
        
        # Define the Legend
        key_color = palette[0]  # Color for the 'Key' group
        value_color = palette[1]  # Color for the 'Value' group
        legend_patches = [mpatches.Patch(color=key_color, label=key_label),
                        mpatches.Patch(color=value_color, label=value_label)]
        
        # Add annotations
        annotator = Annotator(ax=ax,
                              data=data,
                              x='Metric',
                              y='Value',
                              hue='GroupType',
                              pairs=pairs,
                              test=test_type,
                              text_format='full',
                              loc='inside',
                              verbose=2)
        x_labels = ['Question ' + pair[0][0].split('_')[2] for pair in pairs]
        result = [' '] * (len(x_labels) * 2)
        result[0::2] = x_labels
        x_labels = result
        x_ticks = [i for i in range(0, len(pairs)*2)]
        plt.xticks(ticks=x_ticks, labels=x_labels)
    elif display=='split_pairs':
        # Plot with seaborn (side-by-side)
        ax = sns.boxplot(x='GroupType', y='Value', hue='Metric', data=data, ax=ax, palette={row['Metric']: row['Color'] for _, row in data.iterrows()})
        # Adjust pairs for side-by-side
        pairs = [(('Key', col1), ('Value', col2)) for col1, col2 in comparisons_dict.items()]
        # Add annotations
        annotator = Annotator(ax=ax,
                              data=data,
                              x='GroupType',
                              y='Value',
                              hue='Metric',
                              pairs=pairs,
                              test=test_type,
                              text_format='full',
                              loc='outside',
                              verbose=1)
        x_labels = [key_label] + [value_label]
        plt.xticks(ticks=range(len(x_labels)), labels=x_labels)
    else:
        raise ValueError(f'display {display} not supported please choose "split_pairs" or "group_pairs"')

    # Configure and annotate
    _, corrected_results = annotator.configure(test=test_type, comparisons_correction=correction_method).apply_and_annotate()

    # Label and show plot
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    plt.title(f'Distribution Test: {test_type} with {correction_method} correction')
    plt.legend(handles=legend_patches, frameon=False, loc=(0.025, 0.05))

    return plt

# %%
data_df.columns
# Out:
# Index(['Measurement', 'Cohort', 'Randomization Group', 'Cognitive Status',
#        'Question_2', 'Question_3', 'Question_4', 'Question_5', 'Question_6',
#        'Question_7', 'Question_8', 'Question_9', 'Question_10', 'Question_11',
#        'Question_12', 'Question_13', 'Question_14', 'Question_15',
#        'Question_16', 'Question_17', 'Question_18', 'Question_19',
#        'Question_20', 'Autonomous Test', 'Attention', 'Memory', 'Fluency',
#        'Language', 'Visuospatial', 'POCA', 'Convolutional Neural Network',
#        'Natural Language Processing', 'Expert Algorithm', 'Completed',
#        'ACE3_Question_2', 'ACE3_Question_3', 'ACE3_Question_4',
#        'ACE3_Question_5', 'ACE3_Question_6', 'ACE3_Question_7',
#        'ACE3_Question_8', 'ACE3_Question_9', 'ACE3_Question_10',
#        'ACE3_Question_11', 'ACE3_Question_12', 'ACE3_Question_13',
#        'ACE3_Question_14', 'ACE3_Question_15', 'ACE3_Question_16',
#        'ACE3_Question_17', 'ACE3_Question_18', 'ACE3_Question_19',
#        'ACE3_Question_20', 'Paper Test', 'Attention.1', 'Memory.1',
#        'Fluency.1', 'Language.1', 'Visuospatial.1', 'Paper PoCA',
#        'Convolutional Neural Network Equivalent',
#        'Natural Language Processing Equivalent', 'Expert Algorithm Equivalent',
#        'Subjective Complaint', 'Attention Complaint', 'Memory Complaint',
#        'Fluency Complaint', 'Language Complaint', 'Visuospatial Complaint',
#        'Impaired on ACE3', 'iADL Impaired', 'ADL Impaired', 'Age',
#        'autocog_status', 'ace_status'],
#       dtype='object')

# %%
comparisons_dict = {'ACE3_Question_2': 'Question_2', 'ACE3_Question_3': 'Question_3', 'ACE3_Question_4': 'Question_4', 'ACE3_Question_5': 'Question_5', 'ACE3_Question_6': 'Question_6', 'ACE3_Question_7': 'Question_7', 'ACE3_Question_8': 'Question_8', 'ACE3_Question_9': 'Question_9', 'ACE3_Question_10': 'Question_10', 'ACE3_Question_11': 'Question_11', 'ACE3_Question_12': 'Question_12', 'ACE3_Question_13': 'Question_13', 'ACE3_Question_14': 'Question_14', 'ACE3_Question_15': 'Question_15', 'ACE3_Question_16': 'Question_16', 'ACE3_Question_17': 'Question_17', 'ACE3_Question_18': 'Question_18', 'ACE3_Question_19': 'Question_19', 'ACE3_Question_20': 'Question_20'}
test_type = 'Wilcoxon'
correction_method = 'bonferroni'
key_label = 'Paper'
value_label = 'Autonomous'
x_label = 'Question'
y_label = 'Score'

#----------------------------------------------------------------
plt = plot_distribution_tests(dataframe=data_df,
                        comparisons_dict=comparisons_dict, 
                        test_type=test_type, 
                        correction_method=correction_method,
                        key_label=key_label, 
                        value_label=value_label, 
                        x_label=x_label, 
                        y_label=y_label,
                        display='group_pairs')
plt

os.makedirs(os.path.join(out_dir, 'distribution_figures'), exist_ok=True)
plt.savefig(os.path.join(out_dir, f'distribution_figures/{test_type}_{correction_method}_multiple_comparison_barplot.png'))
plt.savefig(os.path.join(out_dir, f'distribution_figures/{test_type}_{correction_method}_multiple_comparison_barplot_barplot.svg'))
print('Figure saved to: ', (os.path.join(out_dir, f'icc_figures/{test_type}_{correction_method}_multiple_comparison_barplot')))
# Out:
# /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/scipy/stats/_morestats.py:3337: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/scipy/stats/_morestats.py:3351: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# ACE3_Question_7_Key vs. Question_7_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=3.000e+01
# ACE3_Question_8_Key vs. Question_8_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:6.641e-01 Stat=2.000e+01
# ACE3_Question_9_Key vs. Question_9_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:2.950e-02 Stat=0.000e+00
# ACE3_Question_10_Key vs. Question_10_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:2.885e-01 Stat=0.000e+00
# ACE3_Question_11_Key vs. Question_11_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=8.000e+00
# ACE3_Question_12_Key vs. Question_12_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=7.000e+00
# ACE3_Question_13_Key vs. Question_13_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=7.000e+00
# ACE3_Question_14_Key vs. Question_14_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:4.397e-01 Stat=0.000e+00
# ACE3_Question_15_Key vs. Question_15_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=1.800e+01
# ACE3_Question_16_Key vs. Question_16_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:8.477e-01 Stat=2.550e+01
# ACE3_Question_17_Key vs. Question_17_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=7.000e+00
# ACE3_Question_6_Key vs. Question_6_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:8.377e-02 Stat=3.900e+01
# ACE3_Question_2_Key vs. Question_2_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=1.950e+01
# ACE3_Question_3_Key vs. Question_3_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=0.000e+00
# ACE3_Question_4_Key vs. Question_4_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=4.500e+00
# ACE3_Question_5_Key vs. Question_5_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:8.358e-05 Stat=4.050e+01
# ACE3_Question_18_Key vs. Question_18_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=7.000e+00
# ACE3_Question_19_Key vs. Question_19_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=5.400e+01
# ACE3_Question_20_Key vs. Question_20_Value: Wilcoxon test (paired samples) with Bonferroni correction, P_val:1.000e+00 Stat=9.000e+00
# Figure saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/icc_figures/Wilcoxon_bonferroni_multiple_comparison_barplot

# %% [markdown]
# # Measures of Correlation

# %% [markdown]
# Spearman/Pearson Correlation

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import spearmanr, pearsonr, kendalltau
from natsort import index_natsorted

def generate_scatterplot(dataframe, dependent_variable_name, independent_columns, columns_per_row=4, x_label='xlabel', y_label='ylabel', correlation='spearman'):
    '''
    Generate scatterplots with Spearman's R annotated.

    :param dataframe: DataFrame containing the data
    :param dependent_variable_name: Name of the dependent variable column
    :param independent_columns: List of names of independent variable columns
    :param columns_per_row: Number of columns per row in the facet plot
    :param x_label: Label for the x-axis
    :param y_label: Label for the y-axis
    :param correlation: method of correlation
    :return: Facet plot
    '''
    # Melt the DataFrame
    melted_df = pd.melt(dataframe, id_vars=[dependent_variable_name], value_vars=independent_columns,
                        var_name='independent_variable_name', value_name='independent_variable_units')

    # Sort the DataFrame
    melted_df = melted_df.sort_values(by='independent_variable_name', key=lambda x: np.argsort(index_natsorted(melted_df['independent_variable_name'])))

    # Begin plotting
    sns.set_style('white')
    sns.set_palette('tab10', 1, desat=1)
    facet_plot = sns.lmplot(y=dependent_variable_name, x='independent_variable_units', data=melted_df,
                            col='independent_variable_name', truncate=False, col_wrap=columns_per_row,
                            facet_kws=dict(sharex=False, sharey=True))

    # Calculate Spearman's correlation for each cluster
    grouped_df = melted_df.groupby('independent_variable_name')
    if correlation == 'pearson':
        result = grouped_df.apply(lambda x: pearsonr(x['independent_variable_units'], x[dependent_variable_name]))
    elif correlation == 'spearman':
        result = grouped_df.apply(lambda x: spearmanr(x['independent_variable_units'], x[dependent_variable_name]))
    elif correlation == 'kendall':
        result = grouped_df.apply(lambda x: kendalltau(x['independent_variable_units'], x[dependent_variable_name]))
    else:
        raise ValueError(f'Correlation {correlation} not specified, please select "pearson", "kendall" or "spearman"')

    # Annotate with Spearman's correlation
    for i, ax in enumerate(facet_plot.axes):
        r, p = result[i]
        region = melted_df['independent_variable_name'].unique()[i]
        ax.set_title(region)
        ax.annotate(f"r = {r:.2f}, p = {p:.5f}", xy=(.5, 1.0), xycoords='axes fraction',
                    xytext=(0, 0), textcoords='offset points', ha='center', va='top',
                    bbox=dict(boxstyle='round,pad=0.0', alpha=0.0),
                    arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0'))

    facet_plot.set_xlabels(x_label)
    facet_plot.set_ylabels(y_label)
    return facet_plot

# %%
data_df.columns
# Out:
# Index(['Measurement', 'Cohort', 'Randomization Group', 'Cognitive Status',
#        'Question_2', 'Question_3', 'Question_4', 'Question_5', 'Question_6',
#        'Question_7', 'Question_8', 'Question_9', 'Question_10', 'Question_11',
#        'Question_12', 'Question_13', 'Question_14', 'Question_15',
#        'Question_16', 'Question_17', 'Question_18', 'Question_19',
#        'Question_20', 'Autonomous Test', 'Attention', 'Memory', 'Fluency',
#        'Language', 'Visuospatial', 'POCA', 'Convolutional Neural Network',
#        'Natural Language Processing', 'Expert Algorithm', 'Completed',
#        'ACE3_Question_2', 'ACE3_Question_3', 'ACE3_Question_4',
#        'ACE3_Question_5', 'ACE3_Question_6', 'ACE3_Question_7',
#        'ACE3_Question_8', 'ACE3_Question_9', 'ACE3_Question_10',
#        'ACE3_Question_11', 'ACE3_Question_12', 'ACE3_Question_13',
#        'ACE3_Question_14', 'ACE3_Question_15', 'ACE3_Question_16',
#        'ACE3_Question_17', 'ACE3_Question_18', 'ACE3_Question_19',
#        'ACE3_Question_20', 'Paper Test', 'Attention.1', 'Memory.1',
#        'Fluency.1', 'Language.1', 'Visuospatial.1', 'Paper PoCA',
#        'Convolutional Neural Network Equivalent',
#        'Natural Language Processing Equivalent', 'Expert Algorithm Equivalent',
#        'Subjective Complaint', 'Attention Complaint', 'Memory Complaint',
#        'Fluency Complaint', 'Language Complaint', 'Visuospatial Complaint',
#        'Impaired on ACE3', 'iADL Impaired', 'ADL Impaired', 'Age',
#        'autocog_status', 'ace_status'],
#       dtype='object')

# %%
columns_to_correlate_to = 'Paper Test'
columns_to_correlate_list = ['Autonomous Test']
x_label = 'Autonomous Score'
y_label = 'Paper Score'
correlation = 'spearman'

#---------
plot = generate_scatterplot(dataframe=data_df, 
                     dependent_variable_name=columns_to_correlate_to, 
                     independent_columns=columns_to_correlate_list, 
                     x_label=x_label, 
                     y_label=y_label,
                     correlation=correlation)

os.makedirs(os.path.join(out_dir, 'scatterplot_figures'), exist_ok=True)
plot.savefig(os.path.join(out_dir, f'scatterplot_figures/{x_label}_to_{y_label}.png'))
plot.savefig(os.path.join(out_dir, f'scatterplot_figures/{x_label}_to_{y_label}.svg'))
print('Figure saved to: ', (os.path.join(out_dir, f'scatterplot_figures/{x_label}_to_{y_label}')))
# Out:
# Figure saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/scatterplot_figures/Autonomous Score_to_Paper Score

# %% [markdown]
# Intraclass Correlation Coefficient

# %%
import pingouin as pg

def calculate_icc(series1, series2):
    # Combine the series into a DataFrame
    df = series1.to_frame(name='rating1')
    df['rating2'] = series2

    # Melt the DataFrame to long format
    df_melted = df.melt(value_vars=['rating1', 'rating2'], var_name='rater', value_name='rating')

    # Add a subject column
    df_melted['subject'] = df_melted.groupby('rater').cumcount()

    # Calculate ICC
    icc_result = pg.intraclass_corr(data=df_melted, targets='subject', raters='rater', ratings='rating')
    
    # You can choose the ICC type you want, here I'm returning ICC(3,1)
    return icc_result.set_index('Type').loc['ICC3', 'ICC']

# %%
data_df.columns
# Out:
# Index(['Measurement', 'Cohort', 'Randomization Group', 'Cognitive Status',
#        'Question_2', 'Question_3', 'Question_4', 'Question_5', 'Question_6',
#        'Question_7', 'Question_8', 'Question_9', 'Question_10', 'Question_11',
#        'Question_12', 'Question_13', 'Question_14', 'Question_15',
#        'Question_16', 'Question_17', 'Question_18', 'Question_19',
#        'Question_20', 'Autonomous Test', 'Attention', 'Memory', 'Fluency',
#        'Language', 'Visuospatial', 'POCA', 'Convolutional Neural Network',
#        'Natural Language Processing', 'Expert Algorithm', 'Completed',
#        'ACE3_Question_2', 'ACE3_Question_3', 'ACE3_Question_4',
#        'ACE3_Question_5', 'ACE3_Question_6', 'ACE3_Question_7',
#        'ACE3_Question_8', 'ACE3_Question_9', 'ACE3_Question_10',
#        'ACE3_Question_11', 'ACE3_Question_12', 'ACE3_Question_13',
#        'ACE3_Question_14', 'ACE3_Question_15', 'ACE3_Question_16',
#        'ACE3_Question_17', 'ACE3_Question_18', 'ACE3_Question_19',
#        'ACE3_Question_20', 'Paper Test', 'Attention.1', 'Memory.1',
#        'Fluency.1', 'Language.1', 'Visuospatial.1', 'Paper PoCA',
#        'Convolutional Neural Network Equivalent',
#        'Natural Language Processing Equivalent', 'Expert Algorithm Equivalent',
#        'Subjective Complaint', 'Attention Complaint', 'Memory Complaint',
#        'Fluency Complaint', 'Language Complaint', 'Visuospatial Complaint',
#        'Impaired on ACE3', 'iADL Impaired', 'ADL Impaired', 'Age',
#        'autocog_status', 'ace_status'],
#       dtype='object')

# %%
icc = calculate_icc(data_df['Paper Test'], data_df['Autonomous Test'])
icc
# Out:
# 0.8091610409496094

# %% [markdown]
# Bootstrapped ICC 95% Confidence Intervals

# %%
from tqdm import tqdm
from pingouin import intraclass_corr
from calvin_utils.statistical_utils.distribution_statistics import BootstrappedDistributionStatistics
from calvin_utils.statistical_utils.resampling_functions import Bootstrap

def calculate_icc(df, col1, col2):
    # Select only the specified columns and rename them for compatibility with pingouin
    data = df[[col1, col2]].rename(columns={col1: 'rating1', col2: 'rating2'})

    # Reshape data for pingouin's intraclass_corr function
    df_melted = data.melt(value_vars=['rating1', 'rating2'], var_name='rater', value_name='rating')
    df_melted['subject'] = df_melted.groupby('rater').cumcount()

    # Calculate ICC
    icc_result = intraclass_corr(data=df_melted, targets='subject', raters='rater', ratings='rating')
    
    # Return ICC(3,1)
    return icc_result.set_index('Type').loc['ICC3', 'ICC']

def bootstrap_icc(data, col1, col2, bootstrap_samples=2500):
    # Perform the bootstrap resampling using the Bootstrap class
    bootstrap = Bootstrap(data=data, func=calculate_icc, func_args={'col1': col1, 'col2': col2}, bootstrap_samples=bootstrap_samples)
    bootstrap_results = bootstrap.bootstrap_function()

    # Calculate the confidence intervals using the BootstrappedDistributionStatistics class
    distribution_statistics = BootstrappedDistributionStatistics(bootstrap_results)
    lower_bound, upper_bound = distribution_statistics.percentile_ci(alpha=0.05)

    return lower_bound, upper_bound

# %%
lower_bound, upper_bound = bootstrap_icc(data=data_df, col1='Paper Test', col2='Autonomous Test', bootstrap_samples=10000)
print(lower_bound, upper_bound)
# Out:
# 100%|██████████| 10000/10000 [05:31<00:00, 30.14it/s]
# 0.6786323573723834 0.9098448396404453

# %% [markdown]
# Visualize ICC

# %%
import matplotlib.pyplot as plt

def plot_icc_with_ci(icc, ci_lower, ci_upper):
    plt.figure(figsize=(6.5, 2))
    plt.errorbar(x=icc, y=0, xerr=[[icc - ci_lower], [ci_upper - icc]], fmt='o', color='#1f77b4', capsize=5)
    plt.xlim(0, 1)
    plt.yticks([])
    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.xlabel('ICC')
    plt.title('Intraclass Correlation Coefficient (ICC) with 95% Confidence Interval')
    plt.grid(axis='x', linestyle='--')
    return plt

# %%
figure = plot_icc_with_ci(icc=icc, ci_lower=lower_bound, ci_upper=upper_bound)
os.makedirs(os.path.join(out_dir, 'icc_figures'), exist_ok=True)
figure.savefig(os.path.join(out_dir, 'icc_figures/icc_barplot.png'))
figure.savefig(os.path.join(out_dir, 'icc_figures/icc_barplot.svg'))
print('Figure saved to: ', (os.path.join(out_dir, 'icc_figures/icc_barplot')))
# Out:
# Figure saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/icc_figures/icc_barplot

# %% [markdown]
# Plot a Bunch of ICCs

# %%
import matplotlib.patches as mpatches

def plot_icc_forest(comparisons_dict, dataframe, bootstrap_samples=2500, full_legend_patches=False):
    # figure = plt.figure(figsize=(4, len(comparisons_dict)*1.2))
    figure = plt.figure(figsize=(4, 5))
    
    # Create a color palette with enough unique colors
    colors = sns.color_palette("tab10", len(comparisons_dict))
    
    # Create legend patches
    legend_patches = []
    
    # Iterate through the dictionary and plot ICC for each comparison
    for idx, (col1_name, col2_name) in enumerate(comparisons_dict.items()):
        # Calculate ICC
        icc_value = calculate_icc(dataframe, col1_name, col2_name)

        # Bootstrap 95% confidence interval
        ci_lower, ci_upper = bootstrap_icc(dataframe, col1_name, col2_name, bootstrap_samples=bootstrap_samples)

        # Plot ICC with confidence interval
        plt.errorbar(x=icc_value, y=idx, xerr=[[icc_value - ci_lower], [ci_upper - icc_value]], fmt='o', color=colors[idx], capsize=5)
        
        # Add legend patch
        if full_legend_patches:
            legend_patches.append(mpatches.Patch(color=colors[idx], label=f'{col1_name} vs {col2_name}'))
        else:
            legend_patches.append(mpatches.Patch(color=colors[idx], label=f'{col1_name}'))

    plt.xlim(0, 1)
    plt.ylim(-1, len(comparisons_dict))
    plt.yticks([])
    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.xlabel('ICC')
    plt.title('Intraclass Correlation Coefficients (ICC) with 95% Confidence Intervals')
    plt.grid(axis='x', linestyle='--')
    
    # Add legend
    plt.legend(handles=legend_patches, frameon=False, loc=(0.05, 0.1))
    return figure

# Example usage
# comparisons_dict = {
#     'Total': 'Total.1',
#     'Score1': 'Score2'
# }

# plot_icc_forest(comparisons_dict, dataframe=data_df)

# %%
comparisons_dict = {'Attention': 'Attention.1', 
                    'Memory': 'Memory.1', 
                    'Fluency': 'Fluency.1', 
                    'Language': 'Language.1', 
                    'Visuospatial': 'Visuospatial.1', 
}  
bootstrap_samples = 10000
#-----------------------------------------------------------------------------
multi_icc_fig = plot_icc_forest(comparisons_dict, dataframe=data_df, bootstrap_samples=bootstrap_samples)

os.makedirs(os.path.join(out_dir, 'icc_figures'), exist_ok=True)
multi_icc_fig.savefig(os.path.join(out_dir, 'icc_figures/icc_multipl_comparison_barplot.png'))
multi_icc_fig.savefig(os.path.join(out_dir, 'icc_figures/icc_multipl_comparison_barplot_barplot.svg'))
print('Figure saved to: ', (os.path.join(out_dir, 'icc_figures/icc_multipl_comparison_barplot')))
# Out:
# 100%|██████████| 10000/10000 [05:41<00:00, 29.29it/s]
# 100%|██████████| 10000/10000 [05:39<00:00, 29.50it/s]
# 100%|██████████| 10000/10000 [05:34<00:00, 29.88it/s]
# 100%|██████████| 10000/10000 [05:44<00:00, 29.02it/s]
# 100%|██████████| 10000/10000 [05:52<00:00, 28.40it/s]
# Figure saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/cognitive_domains/icc_figures/icc_multipl_comparison_barplot

# %% [markdown]
# ## Generate ROC

# %%
df_1.columns
# Out:
# Index(['Measurement', 'Cohort', 'Randomization Group', 'Cognitive Status',
#        'Question_2', 'Question_3', 'Question_4', 'Question_5', 'Question_6',
#        'Question_7', 'Question_8', 'Question_9', 'Question_10', 'Question_11',
#        'Question_12', 'Question_13', 'Question_14', 'Question_15',
#        'Question_16', 'Question_17', 'Question_18', 'Question_19',
#        'Question_20', 'Total', 'Attention', 'Memory', 'Fluency', 'Language',
#        'Visuospatial', 'POCA', 'Convolutional Neural Network',
#        'Natural Language Processing', 'Expert Algorithm', 'Completed',
#        'ACE3_Question_2', 'ACE3_Question_3', 'ACE3_Question_4',
#        'ACE3_Question_5', 'ACE3_Question_6', 'ACE3_Question_7',
#        'ACE3_Question_8', 'ACE3_Question_9', 'ACE3_Question_10',
#        'ACE3_Question_11', 'ACE3_Question_12', 'ACE3_Question_13',
#        'ACE3_Question_14', 'ACE3_Question_15', 'ACE3_Question_16',
#        'ACE3_Question_17', 'ACE3_Question_18', 'ACE3_Question_19',
#        'ACE3_Question_20', 'Total.1', 'Attention.1', 'Memory.1', 'Fluency.1',
#        'Language.1', 'Visuospatial.1', 'Paper PoCA',
#        'Convolutional Neural Network Equivalent',
#        'Natural Language Processing Equivalent', 'Expert Algorithm Equivalent',
#        'Subjective Complaint', 'Attention Complaint', 'Memory Complaint',
#        'Fluency Complaint', 'Language Complaint', 'Visuospatial Complaint',
#        'Impaired on ACE3', 'iADL Impaired', 'ADL Impaired', 'Age',
#        'autocog_status', 'ace_status'],
#       dtype='object')

# %%
independent_var_column = 'Total'
dependent_var_column = 'Cognitive Status'
positive_outcome = 'MCI'
negative_outcome = 'Intact'

#----------------------------------------------------------------DO NOT TOUCH----------------------------------------------------------------
data_df = df_1.loc[:, [independent_var_column, dependent_var_column]].copy()
data_df['one_hot_status'] = np.where(data_df[dependent_var_column] == positive_outcome, 0, 1)
display(data_df)
# Out:
#        Total Cognitive Status  one_hot_status
# 0   0.969697           Intact               1
# 1   0.707071              MCI               0
# 2   0.727273              MCI               0
# 3   0.808081              MCI               0
# 4   0.858586           Intact               1
# 5   0.696970              MCI               0
# 6   0.797980              MCI               0
# 7   0.939394           Intact               1
# 8   0.868687              MCI               0
# 9   0.767677              MCI               0
# 10  0.929293           intact               1
# 11  0.898990           intact               1
# 12  0.868687              MCI               0
# 13  0.898990           intact               1
# 14  0.757576              MCI               0
# 15  0.828283           Intact               1
# 16  0.818182           intact               1
# 17  0.646465              MCI               0
# 18  0.545455              MCI               0
# 19  0.565657              MCI               0
# 20  0.767677           Intact               1
# 21  0.565657              MCI               0
# 22  0.686869              MCI               0
# 23  0.858586           Intact               1
# 24  0.727273              MCI               0
# 25  0.949495           intact               1
# 26  0.959596           intact               1
# 27  0.969697           intact               1
# 28  0.939394           intact               1
# 29  0.979798           intact               1
# 30  1.000000           intact               1
# 31  0.979798           intact               1
# 32  0.969697           intact               1
# 33  0.949495           intact               1
# 34  0.909091           intact               1
# 35  0.959596           intact               1
# 36  1.000000           intact               1
# 37  0.767677           intact               1
# 38  0.848485           intact               1
# 39  0.838384           intact               1
# 40  0.787879           intact               1
# 41  0.787879           intact               1
# 42  0.797980           intact               1
# 43  0.585859              MCI               0
# 44  0.727273              MCI               0
# 45  0.898990           intact               1

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
#----------------------------------------------------------------DO NOT TOUCH----------------------------------------------------------------
# assuming 'one_hot_status' is the target with MCI encoded as 1 and intact as 0, and 'Question_16' is the score
y_true = data_df['one_hot_status']
scores = data_df[independent_var_column]

# calculate the false positive rate and true positive rate for all thresholds of the classification
fpr, tpr, thresholds = roc_curve(y_true, scores)

# calculate the AUC (Area Under Curve)
roc_auc = auc(fpr, tpr)

# Create a DataFrame to store FPR, TPR, and corresponding thresholds
df_roc = pd.DataFrame({
    "FPR": fpr,
    "TPR": tpr,
    "Threshold": thresholds
})

# Plot
sns.set_style("white")
roc = plt.figure(figsize=(7, 6))
sns.lineplot(x="FPR", y="TPR", data=df_roc, marker='o', color="#1f77b4")


plt.title(f'AUC = {roc_auc:.2f}', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=13)
plt.ylabel('True Positive Rate', fontsize=13)

plt.plot([0, 1], [0, 1], color='grey', linestyle='--')

sns.despine()
plt.show()

if not os.path.exists(out_dir + '/roc'):
    os.makedirs(out_dir + '/roc')
    
roc.savefig(out_dir + '/roc/roc.png')
roc.savefig(out_dir + '/roc/roc.svg')
print('saved to: ', out_dir + '/roc/roc.svg')
# Out:
# saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/roc/roc.svg

# %% [markdown]
# Bootstrap Confidence Intervals for the AUC Value

# %%
from calvin_utils.statistical_utils.distribution_statistics import bootstrap_distribution_statistics
from calvin_utils.statistical_utils.classification_statistics import compute_auc
# Use the bootstrap function
roc_func_args = {'y_true_variable': 'one_hot_status', 'independent_variable': f'{independent_var_column}'}
result_df = bootstrap_distribution_statistics(data_df, compute_auc, roc_func_args, bootstrap_samples=10000)
result_df
# Out:
# 100%|██████████| 10000/10000 [00:04<00:00, 2289.33it/s]
#                      Point Estimate  2.5th Percentile  97.5th Percentile  \
# Bootstrapped 95-CIs        0.958377          0.886364                1.0
#
#                      P-value  Standard Error of Mean
# Bootstrapped 95-CIs      0.0                0.000297

# %% [markdown]
# Bootstrapped ROC Plot

# %%
from sklearn.metrics import roc_curve, auc
from numpy import interp
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

def plot_bootstrapped_roc(data, y_true_variable, independent_variable, n_bootstraps=2000):
    """
    Plot ROC curve with bootstrapped confidence intervals.

    Parameters:
    - data: DataFrame with the data.
    - y_true_variable: string with the name of the column containing the true binary labels.
    - independent_variable: string with the name of the column containing the independent variable (classifier scores).
    - n_bootstraps: number of bootstrap samples to use for generating confidence intervals.
    """
    
    #real valutes
    fpr, tpr, thresholds = roc_curve(y_true, scores)

    # calculate the AUC (Area Under Curve)
    roc_auc = auc(fpr, tpr)

    # Create a DataFrame to store FPR, TPR, and corresponding thresholds
    df_roc = pd.DataFrame({
        "FPR": fpr,
        "TPR": tpr,
        "Threshold": thresholds
    })

    #empiric values
    roc_auc_bootstraps = []
    base_fpr = np.linspace(0, 1, 101)
    sns.set_style("white")

    # Generate bootstrap samples and calculate ROC curve for each
    for i in tqdm(range(n_bootstraps)):
        sample = data.sample(frac=1, replace=True)
        y_true = sample[y_true_variable]
        scores = sample[independent_variable]
        fpr, tpr, thresholds = roc_curve(y_true, scores)
        tpr = interp(base_fpr, fpr, tpr)
        tpr[0] = 0.0
        roc_auc_bootstraps.append(tpr)

    roc_auc_bootstraps = np.array(roc_auc_bootstraps)

    # Calculate mean and confidence intervals
    roc_auc_mean = roc_auc_bootstraps.mean(axis=0)
    ci_lower = np.percentile(roc_auc_bootstraps, 2.5, axis=0)
    ci_upper = np.percentile(roc_auc_bootstraps, 97.5, axis=0)

    # Compute AUC using mean ROC curve
    roc_auc = auc(base_fpr, roc_auc_mean)

    # Plot
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.set_style("white")
    sns.lineplot(x="FPR", y="TPR", data=df_roc, marker='o', color="darkblue")

    # ax.plot(base_fpr, roc_auc_mean, 'b')
    ax.fill_between(base_fpr, ci_lower, ci_upper, color='blue', alpha=0.15)
    ax.plot(base_fpr, ci_lower, 'b-', alpha=0.05)
    ax.plot(base_fpr, ci_upper, 'b-', alpha=0.05)
    

    

    ax.set_title('AUC = %0.2f' % roc_auc, fontsize=16)
    ax.plot([0, 1], [0, 1],'--', color='#ADD8E6')
    ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.set_ylabel('True Positive Rate', fontsize=13)
    ax.set_xlabel('False Positive Rate', fontsize=13)
    
    sns.despine()
    plt.show()
    if not os.path.exists(out_dir + '/roc'):
        os.makedirs(out_dir + '/roc')
    plt.savefig(out_dir + f'/roc/bootstrapped_roc.png')
    plt.savefig(out_dir + f'/roc/bootstrapped_roc.svg')
    print('Saved to: ', out_dir + f'/roc/bootstrapped_roc.svg')
    

# fig = plot_bootstrap_auc(data_df, f'one_hot_status', f'{independent_var_column}')
# plt.show()

# %%
plot_bootstrapped_roc(data_df, 
                      y_true_variable='one_hot_status', 
                      independent_variable=f'{independent_var_column}', 
                      n_bootstraps=10000)

# %% [markdown]
# Plot CIs with Observed Value

# %%
from sklearn.metrics import roc_curve, auc
from numpy import interp
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

def plot_bootstrapped_roc(data, y_true_variable, independent_variable, n_bootstraps=2000):
    """
    Plot ROC curve with bootstrapped confidence intervals.

    Parameters:
    - data: DataFrame with the data.
    - y_true_variable: string with the name of the column containing the true binary labels.
    - independent_variable: string with the name of the column containing the independent variable (classifier scores).
    - n_bootstraps: number of bootstrap samples to use for generating confidence intervals.
    """
    # Real values
    y_true = data[y_true_variable]
    scores = data[independent_variable]
    fpr, tpr, thresholds = roc_curve(y_true, scores)

    # Calculate the AUC (Area Under Curve)
    roc_auc = auc(fpr, tpr)

    # Create a DataFrame to store FPR, TPR, and corresponding thresholds
    df_roc = pd.DataFrame({
        "FPR": fpr,
        "TPR": tpr,
        "Threshold": thresholds
    })

    # Empirical values
    roc_auc_bootstraps = []
    base_fpr = np.linspace(0, 1, 101)
    sns.set_style("white")

    # Generate bootstrap samples and calculate ROC curve for each
    for i in tqdm(range(n_bootstraps)):
        sample = data.sample(frac=1, replace=True)
        y_true_sample = sample[y_true_variable]
        scores_sample = sample[independent_variable]
        fpr, tpr, thresholds = roc_curve(y_true_sample, scores_sample)
        tpr = interp(base_fpr, fpr, tpr)
        tpr[0] = 0.0
        roc_auc_bootstraps.append(tpr)

    roc_auc_bootstraps = np.array(roc_auc_bootstraps)

    # Calculate mean and confidence intervals
    roc_auc_mean = roc_auc_bootstraps.mean(axis=0)
    ci_lower = np.percentile(roc_auc_bootstraps, 2.5, axis=0)
    ci_upper = np.percentile(roc_auc_bootstraps, 97.5, axis=0)

    # Compute AUC using mean ROC curve
    roc_auc = auc(base_fpr, roc_auc_mean)

    # Plot
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.set_style("white")
    sns.lineplot(x="FPR", y="TPR", data=df_roc, marker='o', color="darkblue", ci=None)
    ax.fill_between(base_fpr, ci_lower, ci_upper, color='blue', alpha=0.15)
    ax.plot(base_fpr, ci_lower, 'b-', alpha=0.05)
    ax.plot(base_fpr, ci_upper, 'b-', alpha=0.05)

    ax.set_title('AUC = %0.2f' % roc_auc, fontsize=16)
    ax.plot([0, 1], [0, 1],'--', color='#ADD8E6')
    ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.set_ylabel('True Positive Rate', fontsize=13)
    ax.set_xlabel('False Positive Rate', fontsize=13)
    
    sns.despine()
    if not os.path.exists(out_dir + '/roc'):
        os.makedirs(out_dir + '/roc')
    fig.savefig(out_dir + f'/roc/bootstrapped_roc_observed_plotted.png')
    fig.savefig(out_dir + f'/roc/bootstrapped_roc_observed_plotted.svg')
    print('Saved to: ', out_dir + f'/roc/bootstrapped_roc_observed_plotted.svg')
    
plot_bootstrapped_roc(data_df, 'one_hot_status', f'{independent_var_column}', 10000)
# Out:
# 100%|██████████| 10000/10000 [00:03<00:00, 2645.10it/s]
# /var/folders/82/946tskyj68b6htgvndtppmz80000gp/T/ipykernel_28130/2792653718.py:61: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="FPR", y="TPR", data=df_roc, marker='o', color="darkblue", ci=None)
# Saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/roc/bootstrapped_roc_observed_plotted.svg

# %% [markdown]
# Bootstrapped Presenting Mean Values

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

def plot_bootstrapped_roc(data, y_true_variable, independent_variable, n_bootstraps=2000):
    """
    Plot ROC curve with bootstrapped confidence intervals.

    Parameters:
    - data: DataFrame with the data.
    - y_true_variable: string with the name of the column containing the true binary labels.
    - independent_variable: string with the name of the column containing the independent variable (classifier scores).
    - n_bootstraps: number of bootstrap samples to use for generating confidence intervals.
    """
    roc_auc_bootstraps = []
    base_fpr = np.linspace(0, 1, 101)
    sns.set_style("white")

    # Convert the labels in the 'Cognitive Status' column to lowercase
    data['Cognitive Status'] = data['Cognitive Status'].str.lower()

    # Convert 'Cognitive Status' to 'one_hot_status' based on positive_outcome and negative_outcome
    data['one_hot_status'] = np.where(data['Cognitive Status'] == positive_outcome.lower(), 0, 1)

    # Generate bootstrap samples and calculate ROC curve for each
    for i in tqdm(range(n_bootstraps)):
        sample = data.sample(frac=1, replace=True)
        y_true = sample[y_true_variable]
        scores = sample[independent_variable]

        # Exclude rows with NaN values
        mask = ~(y_true.isna() | scores.isna())
        y_true = y_true[mask]
        scores = scores[mask]

        fpr, tpr, thresholds = roc_curve(y_true, scores)

        # Interpolate the ROC curve to ensure it starts from (0,0)
        tpr = np.interp(base_fpr, fpr, tpr)
        tpr[0] = 0.0

        roc_auc_bootstraps.append(tpr)

    roc_auc_bootstraps = np.array(roc_auc_bootstraps)

    # Calculate mean and confidence intervals, ignoring NaN values
    roc_auc_mean = np.nanmean(roc_auc_bootstraps, axis=0)
    ci_lower = np.percentile(roc_auc_bootstraps, 2.5, axis=0)
    ci_upper = np.percentile(roc_auc_bootstraps, 97.5, axis=0)

    # Compute AUC using mean ROC curve
    roc_auc = auc(base_fpr, roc_auc_mean)

    # Plot
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.plot(base_fpr, roc_auc_mean, '#1f77b4')
    ax.fill_between(base_fpr, ci_lower, ci_upper, color='#1f77b4', alpha=0.25)
    ax.plot(base_fpr, ci_lower, 'b-', alpha=0.05)
    ax.plot(base_fpr, ci_upper, 'b-', alpha=0.05)

    ax.set_title('AUC = %0.2f' % roc_auc, fontsize=16)
    ax.plot([0, 1], [0, 1],'--', color='#ff7f0e')
    ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.set_ylabel('True Positive Rate', fontsize=13)
    ax.set_xlabel('False Positive Rate', fontsize=13)

    sns.despine()
    if not os.path.exists(out_dir + '/roc'):
        os.makedirs(out_dir + '/roc')
    plt.savefig(out_dir + f'/roc/bootstrapped_roc_mean_plotted.png')
    plt.savefig(out_dir + f'/roc/bootstrapped_roc_mean_plotted.svg')
    print('Saved to: ', out_dir + f'/roc/bootstrapped_roc_mean_plotted.svg')

# Assuming 'MCI' is the positive outcome and 'Intact' is the negative outcome
positive_outcome = 'MCI'
negative_outcome = 'Intact'

plot_bootstrapped_roc(data_df, 'one_hot_status', f'{independent_var_column}', 10000)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 100%|██████████| 10000/10000 [00:05<00:00, 1713.30it/s]
# Saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/roc/bootstrapped_roc_mean_plotted.svg

# %% [markdown]
# ## Generate Accuracy Curves Across Thresolds

# %%
positive_outcome = 'mci'

# %%
#----------------------------------------------------------------DO NOT TOUCH----------------------------------------------------------------
data_df = data_df.loc[:, [independent_var_column, dependent_var_column]]
data_df['one_hot_status'] = np.where(data_df[dependent_var_column] == positive_outcome, 0, 1)

scores = data_df[independent_var_column]
y_true = data_df['one_hot_status']

display(data_df)
# Out:
#        Total Cognitive Status  one_hot_status
# 0   0.969697           intact               1
# 1   0.707071              mci               0
# 2   0.727273              mci               0
# 3   0.808081              mci               0
# 4   0.858586           intact               1
# 5   0.696970              mci               0
# 6   0.797980              mci               0
# 7   0.939394           intact               1
# 8   0.868687              mci               0
# 9   0.767677              mci               0
# 10  0.929293           intact               1
# 11  0.898990           intact               1
# 12  0.868687              mci               0
# 13  0.898990           intact               1
# 14  0.757576              mci               0
# 15  0.828283           intact               1
# 16  0.818182           intact               1
# 17  0.646465              mci               0
# 18  0.545455              mci               0
# 19  0.565657              mci               0
# 20  0.767677           intact               1
# 21  0.565657              mci               0
# 22  0.686869              mci               0
# 23  0.858586           intact               1
# 24  0.727273              mci               0
# 25  0.949495           intact               1
# 26  0.959596           intact               1
# 27  0.969697           intact               1
# 28  0.939394           intact               1
# 29  0.979798           intact               1
# 30  1.000000           intact               1
# 31  0.979798           intact               1
# 32  0.969697           intact               1
# 33  0.949495           intact               1
# 34  0.909091           intact               1

# %%
from sklearn.metrics import accuracy_score 
from calvin_utils.statistical_utils.distribution_statistics import bootstrap_distribution_statistics
import matplotlib.pyplot as plt
import os
import seaborn as sns

def compute_accuracy(sample, threshold, y_true_variable, independent_variable):
    """
    Computes the accuracy for a given threshold.

    Parameters:
    - sample: DataFrame with the data.
    - threshold: float with the threshold to use for classifying the scores.
    - y_true_variable: string with the name of the column containing the true binary labels.
    - independent_variable: string with the name of the column containing the independent variable (classifier scores).

    Returns:
    - Scalar with the accuracy.
    """
    y_true = sample[y_true_variable]
    scores = sample[independent_variable]
    
    predictions = [0 if score <= threshold else 1 for score in scores]
    return accuracy_score(y_true, predictions)

def point_accuracy_and_distribution(data, scores_var, y_true_var, bootstrap_samples=1000):
    # Extract the scores and true labels
    scores = data[scores_var]
    y_true = data[y_true_var]

    # Calculate accuracies for all thresholds
    thresholds_unique = sorted(list(set(scores)))  # get unique score values and sort them
    accuracies = []

    bootstrap_results = {}
    for threshold in thresholds_unique:
        predictions = [0 if score <= threshold else 1 for score in scores]
        accuracy = accuracy_score(y_true, predictions)
        accuracies.append(accuracy)

        # Bootstrap Distribution
        func_args = {'threshold': threshold, 'y_true_variable': y_true_var, 'independent_variable': scores_var}
        bootstrap_results[f'{threshold}'] = bootstrap_distribution_statistics(data, compute_accuracy, func_args, bootstrap_samples)
    # Create a DataFrame to store thresholds and corresponding accuracies
    df_accuracies = pd.DataFrame({
        "Threshold": thresholds_unique,
        "Accuracy": accuracies
    })
    
    return df_accuracies, bootstrap_results

def plot_accuracy_with_ci(df_accuracies, bootstrap_results, output_dir):
    """
    Plots accuracy as a function of threshold with 95% confidence intervals.

    Parameters:
    - df_accuracies: DataFrame with 'Threshold' and 'Accuracy' columns.
    - bootstrap_results: Dictionary with keys as thresholds and values as DataFrames containing bootstrapped statistics.
    - output_dir: String with the path to the output directory.

    Returns:
    - No return value. The plot is saved to the output directory.
    """

    # Get the lower and upper bounds of the 95% confidence interval for each threshold
    lower_bounds = [bootstrap_results[str(threshold)].loc['Bootstrapped 95-CIs', '2.5th Percentile'] for threshold in df_accuracies["Threshold"]]
    upper_bounds = [bootstrap_results[str(threshold)].loc['Bootstrapped 95-CIs', '97.5th Percentile'] for threshold in df_accuracies["Threshold"]]

    # Plot accuracy as a function of threshold
    fig, ax = plt.subplots(figsize=(10, 6))

    # Plot the accuracies 
    ax.plot(df_accuracies["Threshold"], df_accuracies["Accuracy"], '-o', color="darkblue")

    # Plot the 95% confidence intervals with lighter shade
    ax.fill_between(df_accuracies["Threshold"], lower_bounds, upper_bounds, color='blue', alpha=0.05)

    # Labels
    ax.set_ylabel('Accuracy', fontsize=13)
    ax.set_xlabel('Threshold', fontsize=13)

    sns.despine()

    # Check if the directory exists and create it if it doesn't
    if not os.path.exists(output_dir + '/accuracy_curves'):
        os.makedirs(output_dir + '/accuracy_curves')

    # Save the figure before calling show()
    fig.savefig(output_dir + f'/accuracy_curves/accuracy_curves_rct_group.svg')

    # Display the plot
    plt.show()

# %% [markdown]
# Derive Statistics

# %%
df_accuracies, bootstrap_results = point_accuracy_and_distribution(data_df, scores_var=f'{independent_var_column}', y_true_var='one_hot_status', bootstrap_samples=10000)
display(bootstrap_results)
# Out:
# 100%|██████████| 10000/10000 [00:03<00:00, 3026.03it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3015.02it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3009.19it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3048.72it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3086.53it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3119.82it/s]
#  87%|████████▋ | 8740/10000 [00:02<00:00, 3000.71it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[370], line 1
# ----> 1 df_accuracies, bootstrap_results = point_accuracy_and_distribution(data_df, scores_var=f'{independent_var_column}', y_true_var='one_hot_status', bootstrap_samples=10000)
#       2 display(bootstrap_results)
#
# Cell In[369], line 43, in point_accuracy_and_distribution(data, scores_var, y_true_var, bootstrap_samples)
#      41     # Bootstrap Distribution
#      42     func_args = {'threshold': threshold, 'y_true_variable': y_true_var, 'independent_variable': scores_var}
# ---> 43     bootstrap_results[f'{threshold}'] = bootstrap_distribution_statistics(data, compute_accuracy, func_args, bootstrap_samples)
#      44 # Create a DataFrame to store thresholds and corresponding accuracies
#      45 df_accuracies = pd.DataFrame({
#      46     "Threshold": thresholds_unique,
#      47     "Accuracy": accuracies
#      48 })
#
# File ~/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/Software/Research/nimlab/calvin_utils/calvin_utils/statistical_utils/distribution_statistics.py:144, in bootstrap_distribution_statistics(data, func, func_args, bootstrap_samples)
#     142     sample = data.sample(frac=1, replace=True)
#     143     # Apply the function to the sample and append the result
# --> 144     bootstrap_results.append(func(sample, **func_args))
#     145 # Convert the results to a numpy array
#     146 bootstrap_results = np.array(bootstrap_results)
#
# Cell In[369], line 24, in compute_accuracy(sample, threshold, y_true_variable, independent_variable)
#      21 scores = sample[independent_variable]
#      23 predictions = [0 if score <= threshold else 1 for score in scores]
# ---> 24 return accuracy_score(y_true, predictions)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 to_ignore += ["self", "cls"]
#     185 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
#     192     return func(*args, **kwargs)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:77, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      74 constraints = [make_constraint(constraint) for constraint in constraints]
#      76 for constraint in constraints:
# ---> 77     if constraint.is_satisfied_by(param_val):
#      78         # this constraint is satisfied, no need to check further.
#      79         break
#      80 else:
#      81     # No constraint is satisfied, raise with an informative message.
#      82
#      83     # Ignore constraints that we don't want to expose in the error message,
#      84     # i.e. options that are for internal purpose or not officially supported.
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:472, in _ArrayLikes.is_satisfied_by(self, val)
#     471 def is_satisfied_by(self, val):
# --> 472     return _is_arraylike_not_scalar(val)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/sklearn/utils/validation.py:264, in _is_arraylike_not_scalar(array)
#     262 def _is_arraylike_not_scalar(array):
#     263     """Return True if array is array-like and not a scalar"""
# --> 264     return _is_arraylike(array) and not np.isscalar(array)
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/numpy/core/numeric.py:1951, in isscalar(element)
#    1873 @set_module('numpy')
#    1874 def isscalar(element):
#    1875     """
#    1876     Returns True if the type of `element` is a scalar type.
#    1877
#    (...)
#    1947
#    1948     """
#    1949     return (isinstance(element, generic)
#    1950             or type(element) in ScalarType
# -> 1951             or isinstance(element, numbers.Number))
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %% [markdown]
# Generate Figure

# %%
# Usage
# df_accuracies, bootstrap_results = point_accuracy_and_distribution(data_df, scores_var=f'{independent_var_column}', y_true_var='one_hot_status', bootstrap_samples=1000)
plot_accuracy_with_ci(df_accuracies, bootstrap_results, output_dir=out_dir)

# %% [markdown]
# View Results

# %%
df_accuracies
# Out:
#     Threshold  Accuracy
# 0    0.545455  0.652174
# 1    0.565657  0.695652
# 2    0.585859  0.717391
# 3    0.646465  0.739130
# 4    0.686869  0.760870
# 5    0.696970  0.782609
# 6    0.707071  0.804348
# 7    0.727273  0.869565
# 8    0.757576  0.891304
# 9    0.767677  0.869565
# 10   0.787879  0.826087
# 11   0.797980  0.826087
# 12   0.808081  0.847826
# 13   0.818182  0.826087
# 14   0.828283  0.804348
# 15   0.838384  0.782609
# 16   0.848485  0.760870
# 17   0.858586  0.717391
# 18   0.868687  0.760870
# 19   0.898990  0.695652
# 20   0.909091  0.673913
# 21   0.929293  0.652174
# 22   0.939394  0.608696
# 23   0.949495  0.565217
# 24   0.959596  0.521739
# 25   0.969697  0.456522
# 26   0.979798  0.413043
# 27   1.000000  0.369565

# %%
print('Displaying bootstrap results of threshold with highest accuracy')
bootstrap_results[str(df_accuracies.loc[df_accuracies['Accuracy'].idxmax(), 'Threshold'])]
# Out:
# Displaying bootstrap results of threshold with highest accuracy
#                      Point Estimate  2.5th Percentile  97.5th Percentile  \
# Bootstrapped 95-CIs          0.8917          0.804348           0.978261
#
#                      P-value  Standard Error of Mean
# Bootstrapped 95-CIs      0.0                0.000456

# %%
bootstrap_results
# Out:
# {'0.5454545454545454':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.651874          0.521739           0.782609
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000699  ,
#  '0.5656565656565656':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.695726          0.565217           0.826087
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000677  ,
#  '0.5858585858585859':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.716185          0.586957           0.847826
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000663  ,
#  '0.6464646464646465':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.740696          0.608696           0.869565
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000649  ,
#  '0.6868686868686869':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.760176          0.630435           0.869565
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000637  ,
#  '0.696969696969697':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.782211          0.652174           0.891304
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000606  ,
#  '0.7070707070707071':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.804257          0.673913           0.913043
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000586  ,
#  '0.7272727272727273':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.869728           0.76087           0.956522
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000495  ,
#  '0.7575757575757576':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs          0.8917          0.804348           0.978261
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000456  ,
#  '0.7676767676767676':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.870174           0.76087           0.956522
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000495  ,
#  '0.7878787878787878':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.826211          0.717391           0.934783
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                 0.00056  ,
#  '0.797979797979798':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.825715          0.717391           0.934783
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000556  ,
#  '0.8080808080808081':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.847763           0.73913           0.934783
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000533  ,
#  '0.8181818181818182':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.825733          0.717391           0.934783
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000561  ,
#  '0.8282828282828283':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.804198          0.673913           0.913043
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                 0.00059  ,
#  '0.8383838383838383':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.783302          0.652174           0.891304
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                 0.00061  ,
#  '0.8484848484848485':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.760376          0.630435           0.869565
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000623  ,
#  '0.8585858585858586':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.717278          0.586957           0.847826
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000673  ,
#  '0.8686868686868687':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs         0.76182          0.630435           0.891304
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000637  ,
#  '0.898989898989899':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.694748          0.565217           0.826087
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000677  ,
#  '0.9090909090909091':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.673717          0.543478           0.804348
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000692  ,
#  '0.9292929292929293':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.651926          0.521739           0.782609
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000706  ,
#  '0.9393939393939394':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.607957          0.456522            0.76087
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000731  ,
#  '0.9494949494949495':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.564526          0.413043           0.717391
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000736  ,
#  '0.9595959595959596':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.520843          0.369565           0.673913
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000734  ,
#  '0.9696969696969697':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.456522          0.304348           0.608696
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                 0.00073  ,
#  '0.9797979797979798':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs        0.412002           0.26087           0.565217
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000731  ,
#  '1.0':                      Point Estimate  2.5th Percentile  97.5th Percentile  \
#  Bootstrapped 95-CIs         0.36975           0.23913           0.521739
#
#                       P-value  Standard Error of Mean
#  Bootstrapped 95-CIs      0.0                0.000719  }

# %% [markdown]
# ## Generate Sensitivity and Specificity Across Different Outcomes

# %%
positive_outcome = 'MCI'

# %%
#----------------------------------------------------------------DO NOT TOUCH----------------------------------------------------------------
data_df = df_1.copy().loc[:, [independent_var_column, dependent_var_column]]
data_df['one_hot_status'] = np.where(data_df[dependent_var_column] == positive_outcome, 1, 0)

scores = data_df[independent_var_column]
y_true = data_df['one_hot_status']

display(data_df)
# Out:
#        Total Cognitive Status  one_hot_status
# 0   0.969697           Intact               0
# 1   0.707071              MCI               1
# 2   0.727273              MCI               1
# 3   0.808081              MCI               1
# 4   0.858586           Intact               0
# 5   0.696970              MCI               1
# 6   0.797980              MCI               1
# 7   0.939394           Intact               0
# 8   0.868687              MCI               1
# 9   0.767677              MCI               1
# 10  0.929293           intact               0
# 11  0.898990           intact               0
# 12  0.868687              MCI               1
# 13  0.898990           intact               0
# 14  0.757576              MCI               1
# 15  0.828283           Intact               0
# 16  0.818182           intact               0
# 17  0.646465              MCI               1
# 18  0.545455              MCI               1
# 19  0.565657              MCI               1
# 20  0.767677           Intact               0
# 21  0.565657              MCI               1
# 22  0.686869              MCI               1
# 23  0.858586           Intact               0
# 24  0.727273              MCI               1
# 25  0.949495           intact               0
# 26  0.959596           intact               0
# 27  0.969697           intact               0
# 28  0.939394           intact               0
# 29  0.979798           intact               0
# 30  1.000000           intact               0
# 31  0.979798           intact               0
# 32  0.969697           intact               0
# 33  0.949495           intact               0
# 34  0.909091           intact               0
# 35  0.959596           intact               0
# 36  1.000000           intact               0
# 37  0.767677           intact               0
# 38  0.848485           intact               0
# 39  0.838384           intact               0
# 40  0.787879           intact               0
# 41  0.787879           intact               0
# 42  0.797980           intact               0
# 43  0.585859              MCI               1
# 44  0.727273              MCI               1
# 45  0.898990           intact               0

# %% [markdown]
# No Confidence Intervals

# %%
from sklearn.metrics import confusion_matrix

#----------------------------------------------------------------DO NOT TOUCH----------------------------------------------------------------
# Unique thresholds
thresholds_unique = sorted(list(set(scores)))  # get unique score values and sort them

sensitivities = []
specificities = []

for threshold in thresholds_unique:
    # Compute predictions based on threshold
    predictions = [1 if score <= threshold else 0 for score in scores]
    
    # Compute confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, predictions).ravel()
    
    # Compute sensitivity and specificity
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    
    # Append to lists
    sensitivities.append(sensitivity)
    specificities.append(specificity)

# Create a DataFrame to store thresholds, sensitivities, and specificities
df_threshold_metrics = pd.DataFrame({
    "Threshold": thresholds_unique,
    "Sensitivity": sensitivities,
    "Specificity": specificities
})

# Plot sensitivity and specificity as functions of threshold
plt.figure(figsize=(10, 6))

# Sensitivity
sns.lineplot(x="Threshold", y="Sensitivity", data=df_threshold_metrics, marker='o', color="lightblue", label="Sensitivity")

# Specificity
sns.lineplot(x="Threshold", y="Specificity", data=df_threshold_metrics, marker='o', color="darkblue", label="Specificity")

# Labels
plt.ylabel('Metric Value', fontsize=13)
plt.xlabel('Threshold', fontsize=13)
plt.legend()

sns.despine()

if not os.path.exists(out_dir + '/sensitivity_specificity_curves'):
    os.makedirs(out_dir + '/sensitivity_specificity_curves')
plt.savefig(out_dir + f'/sensitivity_specificity_curves/sensitivity_specificity_curves.png')
plt.savefig(out_dir + f'/sensitivity_specificity_curves/sensitivity_specificity_curves.svg')
df_threshold_metrics.to_csv(out_dir + f'/sensitivity_specificity_curves/sensitivity_specificity_curves_values.csv')

# %%
df_threshold_metrics
# Out:
#     Threshold  Sensitivity  Specificity
# 0    0.545455     0.058824     1.000000
# 1    0.565657     0.176471     1.000000
# 2    0.585859     0.235294     1.000000
# 3    0.646465     0.294118     1.000000
# 4    0.686869     0.352941     1.000000
# 5    0.696970     0.411765     1.000000
# 6    0.707071     0.470588     1.000000
# 7    0.727273     0.647059     1.000000
# 8    0.757576     0.705882     1.000000
# 9    0.767677     0.764706     0.931034
# 10   0.787879     0.764706     0.862069
# 11   0.797980     0.823529     0.827586
# 12   0.808081     0.882353     0.827586
# 13   0.818182     0.882353     0.793103
# 14   0.828283     0.882353     0.758621
# 15   0.838384     0.882353     0.724138
# 16   0.848485     0.882353     0.689655
# 17   0.858586     0.882353     0.620690
# 18   0.868687     1.000000     0.620690
# 19   0.898990     1.000000     0.517241
# 20   0.909091     1.000000     0.482759
# 21   0.929293     1.000000     0.448276
# 22   0.939394     1.000000     0.379310
# 23   0.949495     1.000000     0.310345
# 24   0.959596     1.000000     0.241379
# 25   0.969697     1.000000     0.137931
# 26   0.979798     1.000000     0.068966
# 27   1.000000     1.000000     0.000000

# %%
import numpy as np
from sklearn.utils import resample

bootstrap_iterations = 10000

sensitivities = []
specificities = []
lower_sensitivity_bounds = []
upper_sensitivity_bounds = []
lower_specificity_bounds = []
upper_specificity_bounds = []

for threshold in thresholds_unique:
    bootstrap_sensitivities = []
    bootstrap_specificities = []

    for i in range(bootstrap_iterations):
        # Resample data with replacement
        resampled_scores, resampled_y_true = resample(scores, y_true)
        
        # Compute predictions based on threshold
        predictions = [1 if score <= threshold else 0 for score in resampled_scores]
        
        # Compute confusion matrix
        try:
            tn, fp, fn, tp = confusion_matrix(resampled_y_true, predictions).ravel()
        except:
            continue 
        if tp + fn != 0:
            sensitivity = tp / (tp + fn)
        else:
            sensitivity = np.nan

        if tn + fp != 0:
            specificity = tn / (tn + fp)
        else:
            specificity = np.nan
        # # Compute sensitivity and specificity
        # sensitivity = tp / (tp + fn)
        # specificity = tn / (tn + fp)

        # Append to lists
        bootstrap_sensitivities.append(sensitivity)
        bootstrap_specificities.append(specificity)

    # Append mean values to lists
    # sensitivities.append(np.mean(bootstrap_sensitivities))
    # specificities.append(np.mean(bootstrap_specificities))
    sensitivities.append(np.nanmean(bootstrap_sensitivities))
    specificities.append(np.nanmean(bootstrap_specificities))
    
    # Compute 95% confidence intervals for sensitivity and specificity
    # lower_sensitivity, upper_sensitivity = np.percentile(bootstrap_sensitivities, [2.5, 97.5])
    # lower_specificity, upper_specificity = np.percentile(bootstrap_specificities, [2.5, 97.5])
    # Compute 95% confidence intervals for sensitivity and specificity
    lower_sensitivity, upper_sensitivity = np.nanpercentile(bootstrap_sensitivities, [2.5, 97.5])
    lower_specificity, upper_specificity = np.nanpercentile(bootstrap_specificities, [2.5, 97.5])
    
    lower_sensitivity_bounds.append(lower_sensitivity)
    upper_sensitivity_bounds.append(upper_sensitivity)
    lower_specificity_bounds.append(lower_specificity)
    upper_specificity_bounds.append(upper_specificity)
    
confidence_interval_df = pd.DataFrame({
    'threshold': thresholds_unique,
    'sensitivity': sensitivities,
    'lower_sensitivity_bound': lower_sensitivity_bounds,
    'upper_sensitivity_bound': upper_sensitivity_bounds,
    'specificity': specificities,
    'lower_specificity_bound': lower_specificity_bounds,
    'upper_specificity_bound': upper_specificity_bounds,
})
confidence_interval_df
# Out:
#     threshold  sensitivity  lower_sensitivity_bound  upper_sensitivity_bound  \
# 0    0.545455     0.058022                 0.000000                 0.190476
# 1    0.565657     0.176388                 0.000000                 0.380952
# 2    0.585859     0.235745                 0.055556                 0.454545
# 3    0.646465     0.292210                 0.076923                 0.529412
# 4    0.686869     0.354232                 0.133333                 0.600000
# 5    0.696970     0.410508                 0.176471                 0.650000
# 6    0.707071     0.466858                 0.222222                 0.714286
# 7    0.727273     0.647284                 0.411765                 0.875000
# 8    0.757576     0.704544                 0.470588                 0.923077
# 9    0.767677     0.763429                 0.545455                 0.944518
# 10   0.787879     0.765064                 0.538462                 0.944444
# 11   0.797980     0.824428                 0.615385                 1.000000
# 12   0.808081     0.883320                 0.705882                 1.000000
# 13   0.818182     0.882188                 0.705882                 1.000000
# 14   0.828283     0.881490                 0.700000                 1.000000
# 15   0.838384     0.882463                 0.705882                 1.000000
# 16   0.848485     0.883282                 0.705882                 1.000000
# 17   0.858586     0.882455                 0.705882                 1.000000
# 18   0.868687     1.000000                 1.000000                 1.000000
# 19   0.898990     1.000000                 1.000000                 1.000000
# 20   0.909091     1.000000                 1.000000                 1.000000
# 21   0.929293     1.000000                 1.000000                 1.000000
# 22   0.939394     1.000000                 1.000000                 1.000000
# 23   0.949495     1.000000                 1.000000                 1.000000
# 24   0.959596     1.000000                 1.000000                 1.000000
# 25   0.969697     1.000000                 1.000000                 1.000000
# 26   0.979798     1.000000                 1.000000                 1.000000
# 27   1.000000     1.000000                 1.000000                 1.000000
#
#     specificity  lower_specificity_bound  upper_specificity_bound
# 0      1.000000                 1.000000                 1.000000
# 1      1.000000                 1.000000                 1.000000
# 2      1.000000                 1.000000                 1.000000
# 3      1.000000                 1.000000                 1.000000
# 4      1.000000                 1.000000                 1.000000
# 5      1.000000                 1.000000                 1.000000
# 6      1.000000                 1.000000                 1.000000
# 7      1.000000                 1.000000                 1.000000
# 8      1.000000                 1.000000                 1.000000
# 9      0.931034                 0.826087                 1.000000
# 10     0.862677                 0.724138                 0.967742
# 11     0.828493                 0.677419                 0.960000
# 12     0.827147                 0.678571                 0.960000
# 13     0.793178                 0.633333                 0.928571
# 14     0.758836                 0.592593                 0.909091
# 15     0.723810                 0.555556                 0.878788
# 16     0.689374                 0.516129                 0.851852
# 17     0.621274                 0.440000                 0.794118
# 18     0.622003                 0.437500                 0.794118
# 19     0.517583                 0.333333                 0.700000
# 20     0.483111                 0.300000                 0.666667
# 21     0.447902                 0.266667                 0.629630
# 22     0.378651                 0.206897                 0.558824
# 23     0.309504                 0.147059                 0.482759
# 24     0.240534                 0.096774                 0.406250
# 25     0.136982                 0.031250                 0.272727
# 26     0.069340                 0.000000                 0.173913
# 27     0.000000                 0.000000                 0.000000

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Merge the two dataframes on the 'Threshold' column
df_threshold_metrics = df_threshold_metrics.merge(confidence_interval_df, how='inner', left_on='Threshold', right_on='threshold')

# Plot sensitivity and specificity as functions of threshold
plt.figure(figsize=(15.5, 6))

# Sensitivity
sns.lineplot(x="Threshold", y="Sensitivity", data=df_threshold_metrics, marker='o', color="#1f77b4", label="Sensitivity")
plt.fill_between(df_threshold_metrics['Threshold'], df_threshold_metrics['lower_sensitivity_bound'], df_threshold_metrics['upper_sensitivity_bound'], color='#1f77b4', alpha=0.25)

# Specificity
sns.lineplot(x="Threshold", y="Specificity", data=df_threshold_metrics, marker='o', color="#ff7f0e", label="Specificity")
plt.fill_between(df_threshold_metrics['Threshold'], df_threshold_metrics['lower_specificity_bound'], df_threshold_metrics['upper_specificity_bound'], color='#ff7f0e', alpha=0.25)

# Labels
plt.ylabel('Metric Value', fontsize=13)
plt.xlabel('Threshold', fontsize=13)
plt.legend(loc=(0.9, 0.5), frameon=False)

sns.despine()

if not os.path.exists(out_dir + '/sensitivity_specificity_curves'):
    os.makedirs(out_dir + '/sensitivity_specificity_curves')
plt.savefig(out_dir + f'/sensitivity_specificity_curves/sensitivity_specificity_curves.png')
plt.savefig(out_dir + f'/sensitivity_specificity_curves/sensitivity_specificity_curves.svg')
df_threshold_metrics.to_csv(out_dir + f'/sensitivity_specificity_curves/sensitivity_specificity_curves_values.csv')
print('Saved to: ', out_dir + f'/sensitivity_specificity_curves/sensitivity_specificity_curves.svg')
# Out:
# Saved to:  /Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Work/KiTH_Solutions/Research/Clinical Trial/final_results/tab10_colouring/sensitivity_specificity_curves/sensitivity_specificity_curves.svg

# %% [markdown]
# ## Generate PPV and NPV Across All Thresholds

# %%
#----------------------------------------------------------------DO NOT TOUCH----------------------------------------------------------------
data_df = data_df.loc[:, [independent_var_column, dependent_var_column]]
data_df['one_hot_status'] = np.where(data_df[dependent_var_column] == positive_outcome, 1, 0)

scores = data_df[independent_var_column]
y_true = data_df['one_hot_status']

display(data_df)
# Out:
#        Total Cognitive Status  one_hot_status
# 0   0.969697           Intact               0
# 1   0.707071              MCI               1
# 2   0.727273              MCI               1
# 3   0.808081              MCI               1
# 4   0.858586           Intact               0
# 5   0.696970              MCI               1
# 6   0.797980              MCI               1
# 7   0.939394           Intact               0
# 8   0.868687              MCI               1
# 9   0.767677              MCI               1
# 10  0.929293           intact               0
# 11  0.898990           intact               0
# 12  0.868687              MCI               1
# 13  0.898990           intact               0
# 14  0.757576              MCI               1
# 15  0.828283           Intact               0
# 16  0.818182           intact               0
# 17  0.646465              MCI               1
# 18  0.545455              MCI               1
# 19  0.565657              MCI               1
# 20  0.767677           Intact               0
# 21  0.565657              MCI               1
# 22  0.686869              MCI               1
# 23  0.858586           Intact               0
# 24  0.727273              MCI               1
# 25  0.949495           intact               0
# 26  0.959596           intact               0
# 27  0.969697           intact               0
# 28  0.939394           intact               0
# 29  0.979798           intact               0
# 30  1.000000           intact               0
# 31  0.979798           intact               0
# 32  0.969697           intact               0
# 33  0.949495           intact               0
# 34  0.909091           intact               0
# 35  0.959596           intact               0
# 36  1.000000           intact               0
# 37  0.767677           intact               0
# 38  0.848485           intact               0
# 39  0.838384           intact               0
# 40  0.787879           intact               0
# 41  0.787879           intact               0
# 42  0.797980           intact               0
# 43  0.585859              MCI               1
# 44  0.727273              MCI               1
# 45  0.898990           intact               0

# %% [markdown]
# No Confidence Intervals

# %%
from sklearn.metrics import confusion_matrix

# Unique thresholds
thresholds_unique = sorted(list(set(scores)))  # get unique score values and sort them

ppv_list = []
npv_list = []

for threshold in thresholds_unique:
    # Compute predictions based on threshold
    predictions = [1 if score <= threshold else 0 for score in scores]
    
    # Compute confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, predictions).ravel()
    
    # Compute Positive Predictive Value (PPV) and Negative Predictive Value (NPV)
    ppv = tp / (tp + fp) if (tp + fp) != 0 else 0  # Prevent division by zero
    npv = tn / (tn + fn) if (tn + fn) != 0 else 0  # Prevent division by zero
    
    # Append to lists
    ppv_list.append(ppv)
    npv_list.append(npv)

# Create a DataFrame to store thresholds, PPVs, and NPVs
df_ppv_npv = pd.DataFrame({
    "Threshold": thresholds_unique,
    "Positive Predictive Value": ppv_list,
    "Negative Predictive Value": npv_list
})

# Plot PPV and NPV as functions of threshold
plt.figure(figsize=(10, 6))

# PPV
sns.lineplot(x="Threshold", y="Positive Predictive Value", data=df_ppv_npv, marker='o', color="lightblue", label="PPV")

# NPV
sns.lineplot(x="Threshold", y="Negative Predictive Value", data=df_ppv_npv, marker='o', color="darkblue", label="NPV")

# Labels
plt.ylabel('Metric Value', fontsize=13)
plt.xlabel('Threshold', fontsize=13)
plt.legend()

sns.despine()

if not os.path.exists(out_dir + '/ppv_npv_curves'):
    os.makedirs(out_dir + '/ppv_npv_curves')
plt.savefig(out_dir + f'/ppv_npv_curves/ppv_npv_curves.png')
plt.savefig(out_dir + f'/ppv_npv_curves/ppv_npv_curves.svg')
df_ppv_npv.to_csv(out_dir + f'/ppv_npv_curves/ppv_npv_curves.csv')

# %% [markdown]
# With Confidence Intervals

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import scipy.stats as st
bootstrap_samples = 10000  # number of bootstrap samples to generate

# Unique thresholds
thresholds_unique = sorted(list(set(scores)))  # get unique score values and sort them

ppv_list = []
npv_list = []
ppv_lower = []
ppv_upper = []
npv_lower = []
npv_upper = []

y_true_array = y_true.to_numpy()
scores_array = scores.to_numpy()
for threshold in thresholds_unique:
    # Compute predictions based on threshold
    predictions = [1 if score <= threshold else 0 for score in scores_array]
    
    # Compute confusion matrix
    try:
        tn, fp, fn, tp = confusion_matrix(y_true, predictions).ravel()
    except:
        continue
    
    # Compute Positive Predictive Value (PPV) and Negative Predictive Value (NPV)
    ppv = tp / (tp + fp) if (tp + fp) != 0 else 0  # Prevent division by zero
    npv = tn / (tn + fn) if (tn + fn) != 0 else 0  # Prevent division by zero

    # Bootstrap samples
    ppv_bootstrap = []
    npv_bootstrap = []

    # Generate bootstrap samples
    for _ in range(bootstrap_samples):
        # Create bootstrap sample
        bootstrap_indices = np.random.choice(np.arange(len(predictions)), size=len(predictions), replace=True)
        bootstrap_predictions = [predictions[i] for i in bootstrap_indices]
        bootstrap_y_true = [y_true_array[i] for i in bootstrap_indices]

        
        # Compute confusion matrix for bootstrap sample
        tn, fp, fn, tp = confusion_matrix(bootstrap_y_true, bootstrap_predictions).ravel()
        
        # Compute PPV and NPV for bootstrap sample
        ppv_bootstrap_sample = tp / (tp + fp) if (tp + fp) != 0 else 0  # Prevent division by zero
        npv_bootstrap_sample = tn / (tn + fn) if (tn + fn) != 0 else 0  # Prevent division by zero

        # Append to lists
        ppv_bootstrap.append(ppv_bootstrap_sample)
        npv_bootstrap.append(npv_bootstrap_sample)

    # Compute 95% confidence intervals
    ppv_lower.append(np.percentile(ppv_bootstrap, 2.5))
    ppv_upper.append(np.percentile(ppv_bootstrap, 97.5))
    npv_lower.append(np.percentile(npv_bootstrap, 2.5))
    npv_upper.append(np.percentile(npv_bootstrap, 97.5))
    
    # Append to lists
    ppv_list.append(ppv)
    npv_list.append(npv)

# Create a DataFrame to store thresholds, PPVs, and NPVs
df_ppv_npv = pd.DataFrame({
    "Threshold": thresholds_unique,
    "Positive Predictive Value": ppv_list,
    "PPV Lower": ppv_lower,
    "PPV Upper": ppv_upper,
    "Negative Predictive Value": npv_list,
    "NPV Lower": npv_lower,
    "NPV Upper": npv_upper
})

# Plot PPV and NPV as functions of threshold
plt.figure(figsize=(10, 6))

# PPV
plt.plot(df_ppv_npv["Threshold"], df_ppv_npv["Positive Predictive Value"], '-o', color="lightblue", label="PPV")
plt.fill_between(df_ppv_npv["Threshold"], df_ppv_npv["PPV Lower"], df_ppv_npv["PPV Upper"], color='lightblue', alpha=0.25)

# NPV
plt.plot(df_ppv_npv["Threshold"], df_ppv_npv["Negative Predictive Value"], '-o', color="darkblue", label="NPV")
plt.fill_between(df_ppv_npv["Threshold"], df_ppv_npv["NPV Lower"], df_ppv_npv["NPV Upper"], color='darkblue', alpha=0.05)

# Labels
plt.ylabel('Metric Value', fontsize=13)
plt.xlabel('Threshold', fontsize=13)
plt.legend()

sns.despine()

if not os.path.exists(out_dir + '/ppv_npv_curves'):
    os.makedirs(out_dir + '/ppv_npv_curves')
plt.savefig(out_dir + f'/ppv_npv_curves/ppv_npv_curves.png')
plt.savefig(out_dir + f'/ppv_npv_curves/ppv_npv_curves.svg')
df_ppv_npv.to_csv(out_dir + f'/ppv_npv_curves/ppv_npv_curves.csv')

# %% [markdown]
# GPT Version

# %%
import numpy as np
from sklearn.utils import resample

bootstrap_samples = 10000  # number of bootstrap samples to generate

# Unique thresholds
thresholds_unique = sorted(list(set(scores)))  # get unique score values and sort them

ppv_list = []
npv_list = []
ppv_lower = []
ppv_upper = []
npv_lower = []
npv_upper = []

y_true_array = y_true.to_numpy()
scores_array = scores.to_numpy()
for threshold in thresholds_unique:
    # Compute predictions based on threshold
    predictions = [1 if score <= threshold else 0 for score in scores_array]
    
    # Compute confusion matrix
    try:
        tn, fp, fn, tp = confusion_matrix(y_true_array, predictions).ravel()
    except:
        continue
    
    # Compute Positive Predictive Value (PPV) and Negative Predictive Value (NPV)
    ppv = tp / (tp + fp) if (tp + fp) != 0 else 0  # Prevent division by zero
    npv = tn / (tn + fn) if (tn + fn) != 0 else 0  # Prevent division by zero

    # Bootstrap samples
    ppv_bootstrap = []
    npv_bootstrap = []

    # Generate bootstrap samples
    for _ in range(bootstrap_samples):
        # Create bootstrap sample
        bootstrap_indices = np.random.choice(np.arange(len(predictions)), size=len(predictions), replace=True)
        bootstrap_predictions = [predictions[i] for i in bootstrap_indices]
        bootstrap_y_true = [y_true_array[i] for i in bootstrap_indices]

        
        # Compute confusion matrix for bootstrap sample
        tn, fp, fn, tp = confusion_matrix(bootstrap_y_true, bootstrap_predictions).ravel()
        
        # Compute PPV and NPV for bootstrap sample
        ppv_bootstrap_sample = tp / (tp + fp) if (tp + fp) != 0 else 0  # Prevent division by zero
        npv_bootstrap_sample = tn / (tn + fn) if (tn + fn) != 0 else 0  # Prevent division by zero

        # Append to lists
        ppv_bootstrap.append(ppv_bootstrap_sample)
        npv_bootstrap.append(npv_bootstrap_sample)

    # Compute 95% confidence intervals
    ppv_lower.append(np.percentile(ppv_bootstrap, 2.5))
    ppv_upper.append(np.percentile(ppv_bootstrap, 97.5))
    npv_lower.append(np.percentile(npv_bootstrap, 2.5))
    npv_upper.append(np.percentile(npv_bootstrap, 97.5))
    
    # Append to lists
    ppv_list.append(ppv)
    npv_list.append(npv)

# Create a DataFrame to store thresholds, PPVs, and NPVs
df_ppv_npv = pd.DataFrame({
    "Threshold": thresholds_unique,
    "Positive Predictive Value": ppv_list,
    "PPV Lower": ppv_lower,
    "PPV Upper": ppv_upper,
    "Negative Predictive Value": npv_list,
    "NPV Lower": npv_lower,
    "NPV Upper": npv_upper
})

# Plot PPV and NPV as functions of threshold
plt.figure(figsize=(10, 6))

# PPV
plt.plot(df_ppv_npv["Threshold"], df_ppv_npv["Positive Predictive Value"], '-o', color="lightblue", label="PPV")
plt.fill_between(df_ppv_npv["Threshold"], df_ppv_npv["PPV Lower"], df_ppv_npv["PPV Upper"], color='lightblue', alpha=0.25)

# NPV
plt.plot(df_ppv_npv["Threshold"], df_ppv_npv["Negative Predictive Value"], '-o', color="darkblue", label="NPV")
plt.fill_between(df_ppv_npv["Threshold"], df_ppv_npv["NPV Lower"], df_ppv_npv["NPV Upper"], color='darkblue', alpha=0.05)

# Labels
plt.ylabel('Metric Value', fontsize=13)
plt.xlabel('Threshold', fontsize=13)
plt.legend(frameon=False)

sns.despine()

if not os.path.exists(out_dir + '/ppv_npv_curves'):
    os.makedirs(out_dir + '/ppv_npv_curves')
plt.savefig(out_dir + f'/ppv_npv_curves/ppv_npv_curves.png')
plt.savefig(out_dir + f'/ppv_npv_curves/ppv_npv_curves.svg')
df_ppv_npv.to_csv(out_dir + f'/ppv_npv_curves/ppv_npv_curves.csv')

# %%
display(df_ppv_npv)
# Out:
#     Threshold  Positive Predictive Value  PPV Lower  PPV Upper  \
# 0    0.545455                   1.000000   0.000000   1.000000
# 1    0.565657                   1.000000   0.000000   1.000000
# 2    0.585859                   1.000000   1.000000   1.000000
# 3    0.646465                   1.000000   1.000000   1.000000
# 4    0.686869                   1.000000   1.000000   1.000000
# 5    0.696970                   1.000000   1.000000   1.000000
# 6    0.707071                   1.000000   1.000000   1.000000
# 7    0.727273                   1.000000   1.000000   1.000000
# 8    0.757576                   1.000000   1.000000   1.000000
# 9    0.767677                   0.866667   0.666667   1.000000
# 10   0.787879                   0.764706   0.538462   0.944444
# 11   0.797980                   0.736842   0.526316   0.933333
# 12   0.808081                   0.750000   0.550000   0.933333
# 13   0.818182                   0.714286   0.500000   0.900000
# 14   0.828283                   0.681818   0.476190   0.869565
# 15   0.838384                   0.652174   0.454545   0.846154
# 16   0.848485                   0.625000   0.423077   0.814815
# 17   0.858586                   0.576923   0.380952   0.760000
# 18   0.868687                   0.607143   0.416667   0.787919
# 19   0.898990                   0.548387   0.371429   0.718750
# 20   0.909091                   0.531250   0.357085   0.702728
# 21   0.929293                   0.515152   0.344828   0.687500
# 22   0.939394                   0.485714   0.322581   0.648649
# 23   0.949495                   0.459459   0.297297   0.621622
# 24   0.959596                   0.435897   0.282051   0.595238
# 25   0.969697                   0.404762   0.261905   0.555556
# 26   0.979798                   0.386364   0.244444   0.524048
# 27   1.000000                   0.369565   0.239130   0.500000
#
#     Negative Predictive Value  NPV Lower  NPV Upper
# 0                    0.644444   0.511111   0.782609
# 1                    0.674419   0.534884   0.809524
# 2                    0.690476   0.550000   0.825000
# 3                    0.707317   0.560976   0.840939
# 4                    0.725000   0.583285   0.860481
# 5                    0.743590   0.600000   0.875000
# 6                    0.763158   0.619048   0.891892
# 7                    0.828571   0.694391   0.942857
# 8                    0.852941   0.724138   0.968750
# 9                    0.870968   0.741935   0.969697
# 10                   0.862069   0.724138   0.967742
# 11                   0.888889   0.750000   1.000000
# 12                   0.923077   0.807692   1.000000
# 13                   0.920000   0.800000   1.000000
# 14                   0.916667   0.789474   1.000000
# 15                   0.913043   0.777778   1.000000
# 16                   0.909091   0.772727   1.000000
# 17                   0.900000   0.750000   1.000000
# 18                   1.000000   1.000000   1.000000
# 19                   1.000000   1.000000   1.000000
# 20                   1.000000   1.000000   1.000000
# 21                   1.000000   1.000000   1.000000
# 22                   1.000000   1.000000   1.000000
# 23                   1.000000   1.000000   1.000000
# 24                   1.000000   1.000000   1.000000
# 25                   1.000000   1.000000   1.000000
# 26                   1.000000   0.000000   1.000000
# 27                   0.000000   0.000000   0.000000

# %% [markdown]
# Get Other Values

# %%
print('Num positive cases: ', np.count_nonzero(data_df['one_hot_status']))
print('Num total cases: ', np.count_nonzero(data_df.index))
# Out:
# Num positive cases:  17
# Num total cases:  45
